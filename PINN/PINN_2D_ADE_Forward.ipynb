# %% [markdown]
# <a href="https://colab.research.google.com/github/KetilIversen/ADE-PINN-Masters-Thesis-Code/blob/main/PINN/PINN_2D_ADE_Forward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyDOE
# Out:
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.4.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=56f58f2df40f4d273429b3c8edc258b596042c3e7cf219abcf0db395ceb9982e
#   Stored in directory: /root/.cache/pip/wheels/83/ce/8a/87b25c685bfeca1872d13b8dc101e087a9c6e3fb5ebb47022a
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
#@title Imports forward
import sys
import os
import time
from datetime import datetime
import tensorflow as tf
import numpy as np
import scipy.io
import tensorflow_probability as tfp
from pyDOE import lhs

import matplotlib
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.interpolate import griddata
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Imports related to animations
import matplotlib.animation
from IPython.display import HTML

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
#@title Prep data forward
def prep_data(path, N_u=None, N_f=None, ub=None, lb=None, noise=0.0):
    # Reading external data
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['timesteps'].flatten()[:,None] # T x 1
    y = data['y'].flatten()[:,None] # N x 1
    x = data['x'].flatten()[:,None] # N x 1
    

    # Keeping the 2D data for the solution data (real() is maybe to make it float by default, in case of zeroes)
    #Exact_u = np.real(data['usol']).T # T x N
    #Exact_u = np.real(data['u']).T # T x N x N
    Exact_u = np.real(data['u']) # T x N x N

    # Meshing x and t in 2D (100,100,100)
    X, Y, T = np.meshgrid(x,y,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array, as X_star
    X_star = np.hstack((X.flatten()[:,None], Y.flatten()[:,None], T.flatten()[:,None]))
    
    # Preparing the testing u_star
    u_star = np.swapaxes(Exact_u,0,1)
    u_star = u_star.flatten()[:,None]

    # Noiseless data TODO: add support for noisy data    
    idx = np.random.choice(X_star.shape[0], N_u, replace=False)
    X_u_train = X_star[idx,:]
    u_train = u_star[idx,:]

    # Domain bounds (lowerbounds upperbounds) [x, y, t]
    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0) 
    # Getting the initial conditions (t=0)
    xx1 = np.hstack((X[:,:,0:1].flatten()[:,None], Y[:,:,0:1].flatten()[:,None], T[:,:,0:1].flatten()[:,None]))
    uu1 = Exact_u[:,:,0:1].flatten()[:,None]
    # Getting the lowest boundary conditions (x=0) 
    xx2 = np.hstack((X[0:1,:,:].flatten()[:,None], Y[0:1,:,:].flatten()[:,None], T[0:1,:,:].flatten()[:,None]))
    uu2 = Exact_u[0:1,:,:].flatten()[:,None]
    # Getting the highest boundary conditions (x=1) 
    xx3 = np.hstack((X[-1:,:,:].flatten()[:,None], Y[-1:,:,:].flatten()[:,None], T[-1:,:,:].flatten()[:,None]))
    uu3 = Exact_u[-1:,:,:].flatten()[:,None]
    # Getting the lowest boundary conditions (y=0) 
    xx4 = np.hstack((X[:,0:1,:].flatten()[:,None], Y[:,0:1,:].flatten()[:,None], T[:,0:1,:].flatten()[:,None]))
    uu4 = Exact_u[:,0:1,:].flatten()[:,None]
    # Getting the highest boundary conditions (y=1) 
    xx5 = np.hstack((X[:,-1:,:].flatten()[:,None], Y[:,-1:,:].flatten()[:,None], T[:,-1:,:].flatten()[:,None]))
    uu5 = Exact_u[:,-1:,:].flatten()[:,None]
    # Stacking them in multidimensional tensors for training (X_u_train is for now the continuous boundaries)
    X_u_train = np.vstack([xx1, xx2, xx3, xx4, xx5])
    u_train = np.vstack([uu1, uu2, uu3, uu4, uu5])

    # Generating the x and t collocation points for f, with each having a N_f size
    # We pointwise add and multiply to spread the LHS over the 3D domain
    X_f_train = lb + (ub-lb)*lhs(3, N_f)

    # Generating a uniform random sample from ints between 0, and the size of x_u_train, of size N_u (initial data size) and without replacement (unique)
    idx = np.random.choice(X_u_train.shape[0], N_u, replace=False)
    # Getting the corresponding X_u_train (which is now scarce boundary/initial coordinates)
    X_u_train = X_u_train[idx,:]
    # Getting the corresponding u_train
    u_train = u_train[idx,:]

    return x, y, t, X, Y, T, X_star, u_star, X_u_train, u_train, X_f_train, ub, lb

# %%
#@title Extract data from PINN
def ExtractData(pinn, X_star, X_u_train, u_star):

  # Getting the model predictions, over dense (x,y,t) domain
  X_star_batches = np.array_split(X_star,100)
  u_pred, _ = pinn.predict(X_star_batches[0])
  for i in range(len(X_star_batches)-1):
    u_pred_batch, _ = pinn.predict(X_star_batches[i+1])
    u_pred = np.vstack((u_pred,u_pred_batch))

  # Getting the model prediction, over training (x,y,t)
  X_u_train_batches = np.array_split(X_u_train,100)
  u_train_pred, _ = pinn.predict(X_u_train_batches[0])
  for i in range(len(X_u_train_batches)-1):
    u_train_batch, _ = pinn.predict(X_u_train_batches[i+1])
    u_train_pred = np.vstack((u_train_pred,u_train_batch))

  u_train_pred = u_train_pred.flatten()[:,None] 
  
  N_x = x.shape[0]
  N_y = y.shape[0]
  N_t = t.shape[0]

  X_plot = X_star.reshape(N_x,N_y,N_t,3)
  u_plot = u_pred.reshape(N_x,N_y,N_t)
  u_star_plot = u_star.reshape(N_x,N_y,N_t)
  X_test = X_plot[:,:,0,0]
  Y_test = X_plot[:,:,0,1]

  trained_weights = pinn.get_weights()

  return X_test, Y_test, u_star_plot, u_plot, u_train_pred, trained_weights

# %%
#@title Discrete plotter
def DiscretePlotter(t,X_test,Y_test,u_plot,ub,zmax=0.3,zmin=0.0,cmap='rainbow'):

    def figsize(scale, nplots = 1):
        fig_width_pt = 390.0                          # Get this from LaTeX using \the\textwidth
        inches_per_pt = 1.0/72.27                       # Convert pt to inch
        golden_mean = (np.sqrt(5.0)-1.0)/2.0            # Aesthetic ratio (you could change this)
        fig_width = fig_width_pt*inches_per_pt*scale    # width in inches
        fig_height = nplots*fig_width*golden_mean              # height in inches
        fig_size = [fig_width,fig_height]
        return fig_size

    # I make my own newfig and savefig functions
    def newfig(width, nplots = 1):
        fig = plt.figure(figsize=figsize(width, nplots))
        ax = fig.add_subplot(111)
        return fig, ax

    N_t = t.shape[0]
    Lt = ub[2]
    t0 = 0; t1 = Lt/5; t2 = 2*Lt/5; t3 = 3*Lt/5; t4 = 4*Lt/5; t5 = 5*Lt/5;
    N0 = np.int(np.ceil((t0*N_t)/Lt))
    N1 = np.int(np.ceil((t1*N_t)/Lt))
    N2 = np.int(np.ceil((t2*N_t)/Lt))
    N3 = np.int(np.ceil((t3*N_t)/Lt))
    N4 = np.int(np.ceil((t4*N_t)/Lt))
    N5 = np.int(np.floor((t5*N_t-1)/Lt))

    fig, ax = newfig(3.0, 3.0)
    ####### Row 1: u(t,x) slices ##################    
    gs1 = gridspec.GridSpec(2, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)

    ax = plt.subplot(gs1[0, 0])
    ax.pcolor(X_test, Y_test, u_plot[:,:,N0], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')    
    ax.set_title('$t = 0.0$', fontsize = 10)
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[0, 1])      
    ax.pcolor(X_test, Y_test, u_plot[:,:,N1], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])
    ax.set_title('$t = 0.2$', fontsize = 10)

    ax = plt.subplot(gs1[0, 2])       
    ax.pcolor(X_test, Y_test, u_plot[:,:,N2], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])    
    ax.set_title('$t = 0.4$', fontsize = 10)

    ax = plt.subplot(gs1[1, 0])
    ax.pcolor(X_test, Y_test, u_plot[:,:,N3], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')    
    ax.set_title('$t = 0.6$', fontsize = 10)
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[1, 1])      
    ax.pcolor(X_test, Y_test, u_plot[:,:,N4], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])
    ax.set_title('$t = 0.8$', fontsize = 10)

    ax = plt.subplot(gs1[1, 2])       
    ax.pcolor(X_test, Y_test, u_plot[:,:,N5], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])    
    ax.set_title('$t = 1.0$', fontsize = 10)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)

    plt.show()

# %%
#@title Training data plotter forward
def TrainingDataPlotterForward(X_u_train, X_f, ub, lb):

    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    ax.scatter(X_f[:,0],X_f[:,1],X_f[:,2], s=0.2, marker='x')
    ax.scatter(X_u_train[:,0],X_u_train[:,1],X_u_train[:,2], s=0.2, marker='o', alpha=0.8)

    ax.set_xlabel('x')
    ax.set_ylabel('y ')
    ax.set_zlabel('t ')

    plt.show()


    fig = plt.figure()
    ax = fig.add_subplot()

    ax.scatter(X_f[:,0],X_f[:,1], s=0.2, marker='x')
    ax.scatter(X_u_train[:,0],X_u_train[:,1], s=0.2, marker='o', alpha=0.8)

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_xlim(lb[0], ub[0])
    ax.set_ylim(lb[1], ub[1])

    plt.show()

    print('Amount of training data: ' + str(X_u_train.shape[0] + X_f.shape[0]))

# %%
#@title Logger class
class Logger(object):
    def __init__(self, frequency=10):
        print("TensorFlow version: {}".format(tf.__version__))
        print("Eager execution: {}".format(tf.executing_eagerly()))
        print("GPU-accerelated: {}".format(tf.test.is_gpu_available()))

        self.start_time = time.time()
        self.frequency = frequency

    def __get_elapsed(self):
        return datetime.fromtimestamp(time.time() - self.start_time).strftime("%H:%M:%S")

    def __get_error_u(self):
        return self.error_fn()

    def set_error_fn(self, error_fn):
        self.error_fn = error_fn

    def log_train_start(self, model):
        print("\nTraining started")
        print("================")
        self.model = model
        print(self.model.summary())
    
    def log_train_epoch(self, epoch, loss, current_best_loss, custom=""):
        if epoch % self.frequency == 0:
            print(f"{'tf_epoch'} = {epoch:6d}  elapsed = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)

    def log_train_opt(self, name):
        print(f"—— Starting {name} optimization ——")

    def log_train_end(self, epoch, loss, current_best_loss, custom=""):
        print("==================")
        print(f"Training finished (epoch {epoch}): duration = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)
        print('Applying the weights at the best epoch to the model...')

# %%
#@title Loss and parameter plotter
def LossParameterPlotterForward(loss_history):
    plt.figure(figsize=(18,6))
    plt.suptitle('Training Metrics')

    plt.ylabel("Loss", fontsize=14)
    plt.xlabel("Epoch", fontsize=14)
    plt.semilogy(loss_history)

    plt.show()

# %%
#@title LBFGS 
# Adapted from https://github.com/yaroslavvb/stuff/blob/master/eager_lbfgs/eager_lbfgs.py

import tensorflow as tf
import numpy as np
import time

# Time tracking functions
global_time_list = []
global_last_time = 0
def reset_time():
    global global_time_list, global_last_time
    global_time_list = []
    global_last_time = time.perf_counter()

def record_time():
    global global_last_time, global_time_list
    new_time = time.perf_counter()
    global_time_list.append(new_time - global_last_time)
    global_last_time = time.perf_counter()
    #print("step: %.2f"%(global_time_list[-1]*1000))

def last_time():
    """Returns last interval records in millis."""
    global global_last_time, global_time_list
    if global_time_list:
        return 1000 * global_time_list[-1]
    else:
        return 0

def dot(a, b):
    """Dot product function since TensorFlow doesn't have one."""
    return tf.reduce_sum(a*b)

def verbose_func(s):
    print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, config, state, do_verbose, log_fn):
    """port of lbfgs.lua, using TensorFlow eager mode.
    """

    if config.maxIter == 0:
        return

    global final_loss, times

    maxIter = config.maxIter
    maxEval = config.maxEval or maxIter*1.25
    tolFun = config.tolFun or 1e-5
    tolX = config.tolX or 1e-19
    nCorrection = config.nCorrection or 100
    lineSearch = config.lineSearch
    lineSearchOpts = config.lineSearchOptions
    learningRate = config.learningRate or 1
    isverbose = config.verbose or False

    # verbose function
    if isverbose:
        verbose = verbose_func
    else:
        verbose = lambda x: None

    # evaluate initial f(x) and df/dx
    f, g = opfunc(x)

    f_hist = [f]
    currentFuncEval = 1
    state.funcEval = state.funcEval + 1
    p = g.shape[0]

    # check optimality of initial point
    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <= tolFun:
        verbose("optimality condition below tolFun")
        return x, f_hist

    # optimize for a max of maxIter iterations
    nIter = 0
    times = []
    while nIter < maxIter:
        start_time = time.time()

        # keep track of nb of iterations
        nIter = nIter + 1
        state.nIter = state.nIter + 1

        ############################################################
        ## compute gradient descent direction
        ############################################################
        if state.nIter == 1:
            d = -g
            old_dirs = []
            old_stps = []
            Hdiag = 1
        else:
            # do lbfgs update (update memory)
            y = g - g_old
            s = d*t
            ys = dot(y, s)

            if ys > 1e-10:
                # updating memory
                if len(old_dirs) == nCorrection:
                    # shift history by one (limited-memory)
                    del old_dirs[0]
                    del old_stps[0]

                # store new direction/step
                old_dirs.append(s)
                old_stps.append(y)

                # update scale of initial Hessian approximation
                Hdiag = ys/dot(y, y)

            # compute the approximate (L-BFGS) inverse Hessian 
            # multiplied by the gradient
            k = len(old_dirs)

            # need to be accessed element-by-element, so don't re-type tensor:
            ro = [0]*nCorrection
            for i in range(k):
                ro[i] = 1/dot(old_stps[i], old_dirs[i])


            # iteration in L-BFGS loop collapsed to use just one buffer
            # need to be accessed element-by-element, so don't re-type tensor:
            al = [0]*nCorrection

            q = -g
            for i in range(k-1, -1, -1):
                al[i] = dot(old_dirs[i], q) * ro[i]
                q = q - al[i]*old_stps[i]

            # multiply by initial Hessian
            r = q*Hdiag
            for i in range(k):
                be_i = dot(old_stps[i], r) * ro[i]
                r += (al[i]-be_i)*old_dirs[i]

            d = r
            # final direction is in r/d (same object)

        g_old = g
        f_old = f

        ############################################################
        ## compute step length
        ############################################################
        # directional derivative
        gtd = dot(g, d)

        # check that progress can be made along that direction
        if gtd > -tolX:
            verbose("Can not make progress along direction.")
            break

        # reset initial guess for step size
        if state.nIter == 1:
            tmp1 = tf.abs(g)
            t = min(1, 1/tf.reduce_sum(tmp1))
        else:
            t = learningRate


        # optional line search: user function
        lsFuncEval = 0
        if lineSearch and isinstance(lineSearch) == types.FunctionType:
            # perform line search, using user function
            f,g,x,t,lsFuncEval = lineSearch(opfunc,x,t,d,f,g,gtd,lineSearchOpts)
            f_hist.append(f)
        else:
            # no line search, simply move with fixed-step
            x += t*d

            if nIter != maxIter:
                # re-evaluate function only if not in last iteration
                # the reason we do this: in a stochastic setting,
                # no use to re-evaluate that function here
                f, g = opfunc(x)
                lsFuncEval = 1
                f_hist.append(f)


        # update func eval
        currentFuncEval = currentFuncEval + lsFuncEval
        state.funcEval = state.funcEval + lsFuncEval

        ############################################################
        ## check conditions
        ############################################################
        if nIter == maxIter:
            break

        if currentFuncEval >= maxEval:
            # max nb of function evals
            verbose('max nb of function evals')
            break

        tmp1 = tf.abs(g)
        if tf.reduce_sum(tmp1) <=tolFun:
            # check optimality
            verbose('optimality condition below tolFun')
            break

        tmp1 = tf.abs(d*t)
        if tf.reduce_sum(tmp1) <= tolX:
            # step size below tolX
            verbose('step size below tolX')
            break

        if tf.abs(f-f_old) < tolX:
            # function value changing less than tolX
            verbose('function value changing less than tolX'+str(tf.abs(f-f_old)))
            break

        if do_verbose:
            log_fn(nIter, f.numpy(), True)
            #print("Step %3d loss %6.5f msec %6.3f"%(nIter, f.numpy(), last_time()))
            record_time()
            times.append(last_time())

        if nIter == maxIter - 1:
            final_loss = f.numpy()


    # save state
    state.old_dirs = old_dirs
    state.old_stps = old_stps
    state.Hdiag = Hdiag
    state.g_old = g_old
    state.f_old = f_old
    state.t = t
    state.d = d

    return x, f_hist, currentFuncEval

# %%
#@title LBFGS structs
# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
    pass

class Struct(dummy):
    def __getattribute__(self, key):
        if key == '__dict__':
            return super(dummy, self).__getattribute__('__dict__')
        return self.__dict__.get(key, 0)

# %%
#@title LBFGS v2
def dot(a, b):
  """Dot product function since TensorFlow doesn't have one."""
  return tf.reduce_sum(a*b)

def verbose_func(s):
  print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, state, maxIter = 100, learningRate = 1, do_verbose = True):
  """port of lbfgs.lua, using TensorFlow eager mode.
  """

  global final_loss, times
  
  maxEval = maxIter*1.25
  tolFun = 1e-5
  tolX = 1e-9
  nCorrection = 50
  isverbose = False

  # verbose function
  if isverbose:
    verbose = verbose_func
  else:
    verbose = lambda x: None
    
  f, g = opfunc(x)

  f_hist = [f]
  currentFuncEval = 1
  state.funcEval = state.funcEval + 1
  p = g.shape[0]

  # check optimality of initial point
  tmp1 = tf.abs(g)
  if tf.reduce_sum(tmp1) <= tolFun:
    verbose("optimality condition below tolFun")
    return x, f_hist

  # optimize for a max of maxIter iterations
  nIter = 0
  times = []
  while nIter < maxIter:
    start_time = time.time()
    
    # keep track of nb of iterations
    nIter = nIter + 1
    state.nIter = state.nIter + 1

    ############################################################
    ## compute gradient descent direction
    ############################################################
    if state.nIter == 1:
      d = -g
      old_dirs = []
      old_stps = []
      Hdiag = 1
    else:
      # do lbfgs update (update memory)
      y = g - g_old
      s = d*t
      ys = dot(y, s)
      
      if ys > 1e-10:
        # updating memory
        if len(old_dirs) == nCorrection:
          # shift history by one (limited-memory)
          del old_dirs[0]
          del old_stps[0]

        # store new direction/step
        old_dirs.append(s)
        old_stps.append(y)

        # update scale of initial Hessian approximation
        Hdiag = ys/dot(y, y)

      # compute the approximate (L-BFGS) inverse Hessian 
      # multiplied by the gradient
      k = len(old_dirs)

      # need to be accessed element-by-element, so don't re-type tensor:
      ro = [0]*nCorrection
      for i in range(k):
        ro[i] = 1/dot(old_stps[i], old_dirs[i])
        

      # iteration in L-BFGS loop collapsed to use just one buffer
      # need to be accessed element-by-element, so don't re-type tensor:
      al = [0]*nCorrection

      q = -g
      for i in range(k-1, -1, -1):
        al[i] = dot(old_dirs[i], q) * ro[i]
        q = q - al[i]*old_stps[i]

      # multiply by initial Hessian
      r = q*Hdiag
      for i in range(k):
        be_i = dot(old_stps[i], r) * ro[i]
        r += (al[i]-be_i)*old_dirs[i]
        
      d = r
      # final direction is in r/d (same object)

    g_old = g
    f_old = f
    
    ############################################################
    ## compute step length
    ############################################################
    # directional derivative
    gtd = dot(g, d)

    # check that progress can be made along that direction
    if gtd > -tolX:
      verbose("Can not make progress along direction.")
      break

    # reset initial guess for step size
    if state.nIter == 1:
      tmp1 = tf.abs(g)
      t = min(1, 1/tf.reduce_sum(tmp1))
    else:
      t = learningRate



    x += t*d

    if nIter != maxIter:
    # re-evaluate function only if not in last iteration
    # the reason we do this: in a stochastic setting,
    # no use to re-evaluate that function here
      f, g = opfunc(x)

    lsFuncEval = 1
    f_hist.append(f)


    # update func eval
    currentFuncEval = currentFuncEval + lsFuncEval
    state.funcEval = state.funcEval + lsFuncEval

    ############################################################
    ## check conditions
    ############################################################
    if nIter == maxIter:
      break

    if currentFuncEval >= maxEval:
      # max nb of function evals
      print('max nb of function evals')
      break

    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <=tolFun:
      # check optimality
      print('optimality condition below tolFun')
      break
    
    tmp1 = tf.abs(d*t)
    if tf.reduce_sum(tmp1) <= tolX:
      # step size below tolX
      print('step size below tolX')
      break
    
    if tf.abs(f,f_old) < tolX:
      # function value changing less than tolX
      print('function value changing less than tolX'+str(tf.abs(f-f_old)))
      break

    if do_verbose:
      if nIter % 10 == 0:
        print("Step %3d loss %6.5f "%(nIter, f.numpy()))


    if nIter == maxIter - 1:
      final_loss = f.numpy()


  # save state
  state.old_dirs = old_dirs
  state.old_stps = old_stps
  state.Hdiag = Hdiag
  state.g_old = g_old
  state.f_old = f_old
  state.t = t
  state.d = d

  return x, f_hist, currentFuncEval

# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
  pass

class Struct(dummy):
  def __getattribute__(self, key):
    if key == '__dict__':
      return super(dummy, self).__getattribute__('__dict__')
    return self.__dict__.get(key, 0)

# %%
#@title PINN forward w/ Adaptive param (Adaptive weights disabled)
class PhysicsInformedNN(object):
    def __init__(self, layers, optimizer, logger, ub, lb, f_param, u_param, activation_func=tf.keras.activations.tanh):
        # Descriptive Keras model [3, 20, …, 20, 1]
        self.u_model = tf.keras.Sequential()
        self.u_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.u_model.add(tf.keras.layers.Lambda(
          lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:-1]:
            self.u_model.add(tf.keras.layers.Dense(
              width, activation=activation_func,
              kernel_initializer='glorot_normal'))
        self.u_model.add(tf.keras.layers.Dense(
              layers[-1], activation=tf.keras.activations.linear,
              kernel_initializer='glorot_normal'))
        
        self.dtype = tf.float32
        self.loss_history = []
        self.f_param = f_param
        self.u_param = u_param
        self.current_best_loss = 1e10
        self.current_best_weights = []

        # Computing the sizes of weights/biases for future decomposition
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))
                

        self.optimizer = optimizer
        self.logger = logger

        self.beta = 0.01 # Default 0.1
        self.adaptive_param = 1.0
        self.adaptive_param_hat = 1.0
        self.adaptive_param_history = []

    # The actual PINN
    def __f_model(self, X_f):

        # Separating the collocation coordinates
        x_f = tf.convert_to_tensor(X_f[:, 0:1], dtype=self.dtype)
        y_f = tf.convert_to_tensor(X_f[:, 1:2], dtype=self.dtype)
        t_f = tf.convert_to_tensor(X_f[:, 2:3], dtype=self.dtype)

        # Using the new GradientTape paradigm of TF2.0,
        # which keeps track of operations to get the gradient at runtime
        with tf.GradientTape(persistent=True) as tape:
            # Watching the two inputs we’ll need later, x and t
            tape.watch(x_f)
            tape.watch(y_f)
            tape.watch(t_f)
            # Packing together the inputs
            X_f = tf.stack([x_f[:,0], y_f[:,0], t_f[:,0]], axis=1)

            # Getting the prediction
            u = self.u_model(X_f)
            # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
            u_x = tape.gradient(u, x_f)
            u_y = tape.gradient(u, y_f)

        # Getting the other derivatives
        u_xx = tape.gradient(u_x, x_f)
        u_yy = tape.gradient(u_y, y_f)
        u_t = tape.gradient(u, t_f)

        # Letting the tape go
        del tape
        
        PDE = u_t + 2.0*u_x + (3.0*tf.math.cos(3.0*np.pi*t_f)+1.0)*u_y - 0.2*u_xx - 0.2*u_yy - 1.0*tf.math.exp(-4.0*(tf.math.square(x_f + 1.4)+tf.math.square(y_f + 1.0)))
        # Buidling the PINNs
        return PDE

    def __loss(self, X_f, X_u, u, u_pred):
        f_pred = self.__f_model(X_f)
        loss_f = tf.reduce_mean(tf.square(f_pred))
        loss_u = tf.reduce_mean(tf.square(u - u_pred))
        return loss_u, loss_f
        
    def __grad(self, X_f, X_u, u):
        with tf.GradientTape() as tape:
            loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
            loss_value = self.adaptive_param*loss_u + 1.0*loss_f                          # Use adaptive param
        return loss_value, tape.gradient(loss_value, self.__wrap_training_variables())

    def __adaptive_param(self, X_f, X_u, u):
        with tf.GradientTape(persistent=True) as tape:
            loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
            grad_u = tape.gradient(self.adaptive_param*loss_u, self.__wrap_training_variables(), unconnected_gradients=tf.UnconnectedGradients.ZERO)
            grad_f = tape.gradient(loss_f, self.__wrap_training_variables(), unconnected_gradients=tf.UnconnectedGradients.ZERO)
        del tape

        grad_f_flatten = []
        grad_u_flatten = []
        for g in grad_f:
            grad_f_flatten.append(tf.reshape(g,[-1]))
        grad_f_flatten = tf.concat(grad_f_flatten,0)
        for g in grad_u:
            grad_u_flatten.append(tf.reshape(g,[-1]))
        grad_u_flatten = tf.concat(grad_u_flatten,0)        


        max_grad_f = tf.reduce_max(tf.abs(grad_f_flatten))
        mean_grad_u = tf.reduce_mean(tf.abs(grad_u_flatten))
        self.adaptive_param_hat = max_grad_f / mean_grad_u
        self.adaptive_param = self.adaptive_param * (1.0 - self.beta) + self.beta * self.adaptive_param_hat    # As implemented in paper
        self.adaptive_param_history.append(self.adaptive_param)
    
    def __wrap_training_variables(self):
        var = self.u_model.trainable_variables
        return var

    def get_loss_and_flat_grad(self, X_f, X_u, u):
        def loss_and_flat_grad(w):
            with tf.GradientTape() as tape:
                self.set_weights(w)
                loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
                loss_value = self.adaptive_param*loss_u + 1.0*loss_f
            grad = tape.gradient(loss_value, self.__wrap_training_variables())
            grad_flat = []
            for g in grad:
                grad_flat.append(tf.reshape(g, [-1]))
            grad_flat = tf.concat(grad_flat, 0)
            return loss_value, grad_flat
        return loss_and_flat_grad

    def get_weights(self):
        w = []
        for layer in self.u_model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        return tf.convert_to_tensor(w, dtype=self.dtype)
    
    def set_weights(self, w):
        for i, layer in enumerate(self.u_model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)

    def summary(self):
        return self.u_model.summary()

    def mini_batch(self, X_f, X_u, u, batch_size):

        idx_u = np.random.randint(0, tf.shape(X_u).numpy()[0], batch_size)
        idx_f = np.random.randint(0, tf.shape(X_f).numpy()[0], batch_size)

        X_f_batch = tf.gather(X_f, idx_f)
        X_u_batch = tf.gather(X_u, idx_u)
        u_batch   = tf.gather(u, idx_u)

        return X_f_batch, X_u_batch, u_batch

    # The training function
    def fit(self, X_f, X_u, u, tf_epochs, batch_size=512):
        self.logger.log_train_start(self)
        
        # Creating the tensors
        X_u = tf.convert_to_tensor(X_u, dtype=self.dtype)
        X_f = tf.convert_to_tensor(X_f, dtype=self.dtype)
        u = tf.convert_to_tensor(u, dtype=self.dtype)

        iter_per_epoch = np.int(np.floor((tf.shape(X_f).numpy()[0] + tf.shape(X_u).numpy()[0])/batch_size))

        def log_train_epoch(epoch, loss):
            custom = f"adaptive_param = {self.adaptive_param:4f}"
            self.logger.log_train_epoch(epoch, loss, self.current_best_loss, custom)
        
        self.logger.log_train_opt("Adam")
        for epoch in range(tf_epochs):

            for index in range(iter_per_epoch):

                X_f_batch, X_u_batch, u_batch = self.mini_batch(X_f, X_u, u, batch_size)
                
                #self.__adaptive_param(X_f_batch, X_u_batch, u_batch)    # Enable/disable adaptive param

                # Optimization step
                loss_value, grads = self.__grad(X_f_batch, X_u_batch, u_batch)
                self.optimizer.apply_gradients(
                zip(grads, self.__wrap_training_variables()))

            #loss_value, _ = self.__grad(X_f, X_u, u)
            loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
            loss_value = loss_u + loss_f

            if loss_value < self.current_best_loss:
              self.current_best_loss = loss_value
              self.current_best_weights = self.get_weights()

            log_train_epoch(epoch, loss_value)
            
            self.loss_history.append(loss_value.numpy())

        #l-bfgs-b optimization
        print("Starting L-BFGS training")

        loss_and_flat_grad = self.get_loss_and_flat_grad(X_f, X_u, u)

        lbfgs_weights, lbfgs_history, _ = lbfgs(loss_and_flat_grad, self.get_weights(), Struct(), maxIter=8000, learningRate=0.8)

        if lbfgs_history[-1] < self.current_best_loss:
            self.current_best_loss = lbfgs_history[-1]
            self.current_best_weights = lbfgs_weights
        
        for i in lbfgs_history:
            self.loss_history.append(i.numpy())

        self.set_weights(self.current_best_weights)
        self.logger.log_train_end(tf_epochs, loss_value, self.current_best_loss)
        return self.loss_history, self.adaptive_param_history
    
    def predict(self, X_star):
        u_star = self.u_model(X_star)
        f_star = self.__f_model(X_star)
        return u_star.numpy(), f_star.numpy()

# %%
#@title Error forward
def error():
    return 1.0

# %%
# Data size on the solution u
N_u = 10000 # was 15k as low as 10k works
# Collocation points size, where we’ll check for f = 0
N_f = 40000 # Was 90k as low as 40k works
# DeepNN topology (3-sized input [x y t], 8 hidden layer of 20-width, 1-sized output [u]
layers = [3, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Activation function
activation_func = tf.keras.activations.tanh

# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
tf_epochs = 10000 # Was 500
tf_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) # Was 0.0005
batch_size = 50000 # Was 512

f_param = 1.0
u_param = 1.0

noise = 0.00 # Default 0.05

path = os.path.join("/content/drive/MyDrive/Colab Notebooks/Data/ADE_strong_diagv5withVelocityMat.mat")


x, y, t, X, Y, T, X_star, u_star, X_u_train, u_train, X_f, ub, lb = prep_data(path, N_u, N_f, noise)

TrainingDataPlotterForward(X_u_train, X_f, ub, lb)
# Out:
# Amount of training data: 50000

# %%
# Creating the model and training
logger = Logger(frequency=1)
logger.set_error_fn(error)
pinn = PhysicsInformedNN(layers, tf_optimizer, logger, ub, lb, f_param, u_param, activation_func)
# Out:
# TensorFlow version: 2.6.0
# Eager execution: True
# WARNING:tensorflow:From <ipython-input-7-c43d2762e351>:6: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True

# %%
loss_history, adaptive_param_history = pinn.fit(X_f, X_u_train, u_train, tf_epochs, batch_size)
# Out:
# Streaming output truncated to the last 5000 lines.
# tf_epoch =   5676  elapsed = 00:10:12  loss = 1.9776e-03  best loss = 1.9776e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5677  elapsed = 00:10:12  loss = 1.9961e-03  best loss = 1.9776e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5678  elapsed = 00:10:12  loss = 1.9969e-03  best loss = 1.9776e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5679  elapsed = 00:10:13  loss = 1.9654e-03  best loss = 1.9654e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5680  elapsed = 00:10:13  loss = 1.9772e-03  best loss = 1.9654e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5681  elapsed = 00:10:13  loss = 1.9741e-03  best loss = 1.9654e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5682  elapsed = 00:10:13  loss = 1.9793e-03  best loss = 1.9654e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5683  elapsed = 00:10:13  loss = 1.9607e-03  best loss = 1.9607e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5684  elapsed = 00:10:13  loss = 1.9601e-03  best loss = 1.9601e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5685  elapsed = 00:10:13  loss = 1.9558e-03  best loss = 1.9558e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5686  elapsed = 00:10:13  loss = 1.9622e-03  best loss = 1.9558e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5687  elapsed = 00:10:13  loss = 1.9612e-03  best loss = 1.9558e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5688  elapsed = 00:10:14  loss = 1.9499e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5689  elapsed = 00:10:14  loss = 1.9536e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5690  elapsed = 00:10:14  loss = 1.9656e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5691  elapsed = 00:10:14  loss = 1.9730e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5692  elapsed = 00:10:14  loss = 1.9781e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5693  elapsed = 00:10:14  loss = 1.9716e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5694  elapsed = 00:10:14  loss = 1.9499e-03  best loss = 1.9499e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5695  elapsed = 00:10:14  loss = 1.9368e-03  best loss = 1.9368e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5696  elapsed = 00:10:14  loss = 1.9445e-03  best loss = 1.9368e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5697  elapsed = 00:10:15  loss = 1.9451e-03  best loss = 1.9368e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5698  elapsed = 00:10:15  loss = 1.9342e-03  best loss = 1.9342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5699  elapsed = 00:10:15  loss = 1.9380e-03  best loss = 1.9342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5700  elapsed = 00:10:15  loss = 1.9413e-03  best loss = 1.9342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5701  elapsed = 00:10:15  loss = 1.9532e-03  best loss = 1.9342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5702  elapsed = 00:10:15  loss = 1.9367e-03  best loss = 1.9342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5703  elapsed = 00:10:15  loss = 1.9312e-03  best loss = 1.9312e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5704  elapsed = 00:10:15  loss = 1.9416e-03  best loss = 1.9312e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5705  elapsed = 00:10:15  loss = 1.9342e-03  best loss = 1.9312e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5706  elapsed = 00:10:16  loss = 1.9249e-03  best loss = 1.9249e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5707  elapsed = 00:10:16  loss = 1.9210e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5708  elapsed = 00:10:16  loss = 1.9293e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5709  elapsed = 00:10:16  loss = 1.9350e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5710  elapsed = 00:10:16  loss = 1.9239e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5711  elapsed = 00:10:16  loss = 1.9233e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5712  elapsed = 00:10:16  loss = 1.9453e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5713  elapsed = 00:10:16  loss = 1.9397e-03  best loss = 1.9210e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5714  elapsed = 00:10:16  loss = 1.9200e-03  best loss = 1.9200e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5715  elapsed = 00:10:16  loss = 1.9146e-03  best loss = 1.9146e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5716  elapsed = 00:10:17  loss = 1.9284e-03  best loss = 1.9146e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5717  elapsed = 00:10:17  loss = 1.9165e-03  best loss = 1.9146e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5718  elapsed = 00:10:17  loss = 1.9075e-03  best loss = 1.9075e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5719  elapsed = 00:10:17  loss = 1.9189e-03  best loss = 1.9075e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5720  elapsed = 00:10:17  loss = 1.9414e-03  best loss = 1.9075e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5721  elapsed = 00:10:17  loss = 1.9251e-03  best loss = 1.9075e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5722  elapsed = 00:10:17  loss = 1.9013e-03  best loss = 1.9013e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5723  elapsed = 00:10:17  loss = 1.9036e-03  best loss = 1.9013e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5724  elapsed = 00:10:17  loss = 1.9402e-03  best loss = 1.9013e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5725  elapsed = 00:10:18  loss = 1.9369e-03  best loss = 1.9013e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5726  elapsed = 00:10:18  loss = 1.9374e-03  best loss = 1.9013e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5727  elapsed = 00:10:18  loss = 1.9210e-03  best loss = 1.9013e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5728  elapsed = 00:10:18  loss = 1.9010e-03  best loss = 1.9010e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5729  elapsed = 00:10:18  loss = 1.9021e-03  best loss = 1.9010e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5730  elapsed = 00:10:18  loss = 1.8967e-03  best loss = 1.8967e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5731  elapsed = 00:10:18  loss = 1.9116e-03  best loss = 1.8967e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5732  elapsed = 00:10:18  loss = 1.9017e-03  best loss = 1.8967e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5733  elapsed = 00:10:18  loss = 1.8970e-03  best loss = 1.8967e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5734  elapsed = 00:10:19  loss = 1.8884e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5735  elapsed = 00:10:19  loss = 1.8999e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5736  elapsed = 00:10:19  loss = 1.9441e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5737  elapsed = 00:10:19  loss = 1.9350e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5738  elapsed = 00:10:19  loss = 1.9136e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5739  elapsed = 00:10:19  loss = 1.8933e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5740  elapsed = 00:10:19  loss = 1.8945e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5741  elapsed = 00:10:19  loss = 1.9052e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5742  elapsed = 00:10:19  loss = 1.9089e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5743  elapsed = 00:10:19  loss = 1.9065e-03  best loss = 1.8884e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5744  elapsed = 00:10:20  loss = 1.8762e-03  best loss = 1.8762e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5745  elapsed = 00:10:20  loss = 1.8753e-03  best loss = 1.8753e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5746  elapsed = 00:10:20  loss = 1.9069e-03  best loss = 1.8753e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5747  elapsed = 00:10:20  loss = 1.9281e-03  best loss = 1.8753e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5748  elapsed = 00:10:20  loss = 1.9469e-03  best loss = 1.8753e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5749  elapsed = 00:10:20  loss = 1.8921e-03  best loss = 1.8753e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5750  elapsed = 00:10:20  loss = 1.8611e-03  best loss = 1.8611e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5751  elapsed = 00:10:20  loss = 1.8866e-03  best loss = 1.8611e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5752  elapsed = 00:10:21  loss = 1.8885e-03  best loss = 1.8611e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5753  elapsed = 00:10:21  loss = 1.8806e-03  best loss = 1.8611e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5754  elapsed = 00:10:21  loss = 1.8619e-03  best loss = 1.8611e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5755  elapsed = 00:10:21  loss = 1.8607e-03  best loss = 1.8607e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5756  elapsed = 00:10:21  loss = 1.8621e-03  best loss = 1.8607e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5757  elapsed = 00:10:21  loss = 1.8612e-03  best loss = 1.8607e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5758  elapsed = 00:10:21  loss = 1.8549e-03  best loss = 1.8549e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5759  elapsed = 00:10:21  loss = 1.8535e-03  best loss = 1.8535e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5760  elapsed = 00:10:21  loss = 1.8743e-03  best loss = 1.8535e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5761  elapsed = 00:10:22  loss = 1.8834e-03  best loss = 1.8535e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5762  elapsed = 00:10:22  loss = 1.8516e-03  best loss = 1.8516e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5763  elapsed = 00:10:22  loss = 1.8451e-03  best loss = 1.8451e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5764  elapsed = 00:10:22  loss = 1.8723e-03  best loss = 1.8451e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5765  elapsed = 00:10:22  loss = 1.8854e-03  best loss = 1.8451e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5766  elapsed = 00:10:22  loss = 1.8569e-03  best loss = 1.8451e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5767  elapsed = 00:10:22  loss = 1.8403e-03  best loss = 1.8403e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5768  elapsed = 00:10:22  loss = 1.8557e-03  best loss = 1.8403e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5769  elapsed = 00:10:22  loss = 1.8798e-03  best loss = 1.8403e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5770  elapsed = 00:10:23  loss = 1.8879e-03  best loss = 1.8403e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5771  elapsed = 00:10:23  loss = 1.8474e-03  best loss = 1.8403e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5772  elapsed = 00:10:23  loss = 1.8342e-03  best loss = 1.8342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5773  elapsed = 00:10:23  loss = 1.8707e-03  best loss = 1.8342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5774  elapsed = 00:10:23  loss = 1.8574e-03  best loss = 1.8342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5775  elapsed = 00:10:23  loss = 1.8383e-03  best loss = 1.8342e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5776  elapsed = 00:10:23  loss = 1.8286e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5777  elapsed = 00:10:23  loss = 1.8510e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5778  elapsed = 00:10:23  loss = 1.8953e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5779  elapsed = 00:10:24  loss = 1.8816e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5780  elapsed = 00:10:24  loss = 1.8796e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5781  elapsed = 00:10:24  loss = 1.8640e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5782  elapsed = 00:10:24  loss = 1.8481e-03  best loss = 1.8286e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5783  elapsed = 00:10:24  loss = 1.8187e-03  best loss = 1.8187e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5784  elapsed = 00:10:24  loss = 1.8286e-03  best loss = 1.8187e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5785  elapsed = 00:10:24  loss = 1.8806e-03  best loss = 1.8187e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5786  elapsed = 00:10:24  loss = 1.8936e-03  best loss = 1.8187e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5787  elapsed = 00:10:24  loss = 1.8389e-03  best loss = 1.8187e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5788  elapsed = 00:10:24  loss = 1.8141e-03  best loss = 1.8141e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5789  elapsed = 00:10:25  loss = 1.8311e-03  best loss = 1.8141e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5790  elapsed = 00:10:25  loss = 1.8772e-03  best loss = 1.8141e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5791  elapsed = 00:10:25  loss = 1.9018e-03  best loss = 1.8141e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5792  elapsed = 00:10:25  loss = 1.8759e-03  best loss = 1.8141e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5793  elapsed = 00:10:25  loss = 1.8369e-03  best loss = 1.8141e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5794  elapsed = 00:10:25  loss = 1.8044e-03  best loss = 1.8044e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5795  elapsed = 00:10:25  loss = 1.8363e-03  best loss = 1.8044e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5796  elapsed = 00:10:25  loss = 1.8935e-03  best loss = 1.8044e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5797  elapsed = 00:10:25  loss = 1.9119e-03  best loss = 1.8044e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5798  elapsed = 00:10:26  loss = 1.8502e-03  best loss = 1.8044e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5799  elapsed = 00:10:26  loss = 1.7931e-03  best loss = 1.7931e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5800  elapsed = 00:10:26  loss = 1.7989e-03  best loss = 1.7931e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5801  elapsed = 00:10:26  loss = 1.8172e-03  best loss = 1.7931e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5802  elapsed = 00:10:26  loss = 1.8215e-03  best loss = 1.7931e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5803  elapsed = 00:10:26  loss = 1.8090e-03  best loss = 1.7931e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5804  elapsed = 00:10:26  loss = 1.7881e-03  best loss = 1.7881e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5805  elapsed = 00:10:26  loss = 1.7798e-03  best loss = 1.7798e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5806  elapsed = 00:10:26  loss = 1.7965e-03  best loss = 1.7798e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5807  elapsed = 00:10:26  loss = 1.8054e-03  best loss = 1.7798e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5808  elapsed = 00:10:27  loss = 1.7865e-03  best loss = 1.7798e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5809  elapsed = 00:10:27  loss = 1.7806e-03  best loss = 1.7798e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5810  elapsed = 00:10:27  loss = 1.7914e-03  best loss = 1.7798e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5811  elapsed = 00:10:27  loss = 1.7721e-03  best loss = 1.7721e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5812  elapsed = 00:10:27  loss = 1.7832e-03  best loss = 1.7721e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5813  elapsed = 00:10:27  loss = 1.7790e-03  best loss = 1.7721e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5814  elapsed = 00:10:27  loss = 1.7631e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5815  elapsed = 00:10:27  loss = 1.7717e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5816  elapsed = 00:10:27  loss = 1.7660e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5817  elapsed = 00:10:28  loss = 1.7677e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5818  elapsed = 00:10:28  loss = 1.7759e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5819  elapsed = 00:10:28  loss = 1.7738e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5820  elapsed = 00:10:28  loss = 1.7842e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5821  elapsed = 00:10:28  loss = 1.7780e-03  best loss = 1.7631e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5822  elapsed = 00:10:28  loss = 1.7620e-03  best loss = 1.7620e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5823  elapsed = 00:10:28  loss = 1.7655e-03  best loss = 1.7620e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5824  elapsed = 00:10:28  loss = 1.7529e-03  best loss = 1.7529e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5825  elapsed = 00:10:28  loss = 1.7533e-03  best loss = 1.7529e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5826  elapsed = 00:10:29  loss = 1.7481e-03  best loss = 1.7481e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5827  elapsed = 00:10:29  loss = 1.7606e-03  best loss = 1.7481e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5828  elapsed = 00:10:29  loss = 1.7445e-03  best loss = 1.7445e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5829  elapsed = 00:10:29  loss = 1.7475e-03  best loss = 1.7445e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5830  elapsed = 00:10:29  loss = 1.7453e-03  best loss = 1.7445e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5831  elapsed = 00:10:29  loss = 1.7509e-03  best loss = 1.7445e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5832  elapsed = 00:10:29  loss = 1.7438e-03  best loss = 1.7438e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5833  elapsed = 00:10:29  loss = 1.7398e-03  best loss = 1.7398e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5834  elapsed = 00:10:29  loss = 1.7458e-03  best loss = 1.7398e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5835  elapsed = 00:10:30  loss = 1.7377e-03  best loss = 1.7377e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5836  elapsed = 00:10:30  loss = 1.7389e-03  best loss = 1.7377e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5837  elapsed = 00:10:30  loss = 1.7437e-03  best loss = 1.7377e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5838  elapsed = 00:10:30  loss = 1.7676e-03  best loss = 1.7377e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5839  elapsed = 00:10:30  loss = 1.7678e-03  best loss = 1.7377e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5840  elapsed = 00:10:30  loss = 1.7520e-03  best loss = 1.7377e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5841  elapsed = 00:10:30  loss = 1.7322e-03  best loss = 1.7322e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5842  elapsed = 00:10:30  loss = 1.7371e-03  best loss = 1.7322e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5843  elapsed = 00:10:30  loss = 1.7432e-03  best loss = 1.7322e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5844  elapsed = 00:10:31  loss = 1.7433e-03  best loss = 1.7322e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5845  elapsed = 00:10:31  loss = 1.7214e-03  best loss = 1.7214e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5846  elapsed = 00:10:31  loss = 1.7277e-03  best loss = 1.7214e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5847  elapsed = 00:10:31  loss = 1.7197e-03  best loss = 1.7197e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5848  elapsed = 00:10:31  loss = 1.7202e-03  best loss = 1.7197e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5849  elapsed = 00:10:31  loss = 1.7184e-03  best loss = 1.7184e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5850  elapsed = 00:10:31  loss = 1.7110e-03  best loss = 1.7110e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5851  elapsed = 00:10:31  loss = 1.7128e-03  best loss = 1.7110e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5852  elapsed = 00:10:31  loss = 1.7071e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5853  elapsed = 00:10:32  loss = 1.7120e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5854  elapsed = 00:10:32  loss = 1.7156e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5855  elapsed = 00:10:32  loss = 1.7260e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5856  elapsed = 00:10:32  loss = 1.7169e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5857  elapsed = 00:10:32  loss = 1.7089e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5858  elapsed = 00:10:32  loss = 1.7155e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5859  elapsed = 00:10:32  loss = 1.7183e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5860  elapsed = 00:10:32  loss = 1.7241e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5861  elapsed = 00:10:32  loss = 1.7552e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5862  elapsed = 00:10:33  loss = 1.7966e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5863  elapsed = 00:10:33  loss = 1.7717e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5864  elapsed = 00:10:33  loss = 1.7238e-03  best loss = 1.7071e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5865  elapsed = 00:10:33  loss = 1.6951e-03  best loss = 1.6951e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5866  elapsed = 00:10:33  loss = 1.6844e-03  best loss = 1.6844e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5867  elapsed = 00:10:33  loss = 1.6985e-03  best loss = 1.6844e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5868  elapsed = 00:10:33  loss = 1.6987e-03  best loss = 1.6844e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5869  elapsed = 00:10:33  loss = 1.6928e-03  best loss = 1.6844e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5870  elapsed = 00:10:33  loss = 1.6875e-03  best loss = 1.6844e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5871  elapsed = 00:10:33  loss = 1.6809e-03  best loss = 1.6809e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5872  elapsed = 00:10:34  loss = 1.6987e-03  best loss = 1.6809e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5873  elapsed = 00:10:34  loss = 1.7150e-03  best loss = 1.6809e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5874  elapsed = 00:10:34  loss = 1.7052e-03  best loss = 1.6809e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5875  elapsed = 00:10:34  loss = 1.6775e-03  best loss = 1.6775e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5876  elapsed = 00:10:34  loss = 1.6695e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5877  elapsed = 00:10:34  loss = 1.6754e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5878  elapsed = 00:10:34  loss = 1.6899e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5879  elapsed = 00:10:34  loss = 1.7098e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5880  elapsed = 00:10:34  loss = 1.7083e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5881  elapsed = 00:10:35  loss = 1.7054e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5882  elapsed = 00:10:35  loss = 1.6967e-03  best loss = 1.6695e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5883  elapsed = 00:10:35  loss = 1.6623e-03  best loss = 1.6623e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5884  elapsed = 00:10:35  loss = 1.6597e-03  best loss = 1.6597e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5885  elapsed = 00:10:35  loss = 1.6789e-03  best loss = 1.6597e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5886  elapsed = 00:10:35  loss = 1.7327e-03  best loss = 1.6597e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5887  elapsed = 00:10:35  loss = 1.7861e-03  best loss = 1.6597e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5888  elapsed = 00:10:35  loss = 1.7446e-03  best loss = 1.6597e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5889  elapsed = 00:10:35  loss = 1.6853e-03  best loss = 1.6597e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5890  elapsed = 00:10:36  loss = 1.6490e-03  best loss = 1.6490e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5891  elapsed = 00:10:36  loss = 1.6682e-03  best loss = 1.6490e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5892  elapsed = 00:10:36  loss = 1.7106e-03  best loss = 1.6490e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5893  elapsed = 00:10:36  loss = 1.7257e-03  best loss = 1.6490e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5894  elapsed = 00:10:36  loss = 1.7049e-03  best loss = 1.6490e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5895  elapsed = 00:10:36  loss = 1.6574e-03  best loss = 1.6490e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5896  elapsed = 00:10:36  loss = 1.6411e-03  best loss = 1.6411e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5897  elapsed = 00:10:36  loss = 1.6504e-03  best loss = 1.6411e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5898  elapsed = 00:10:36  loss = 1.6683e-03  best loss = 1.6411e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5899  elapsed = 00:10:36  loss = 1.6732e-03  best loss = 1.6411e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5900  elapsed = 00:10:37  loss = 1.6648e-03  best loss = 1.6411e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5901  elapsed = 00:10:37  loss = 1.6493e-03  best loss = 1.6411e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5902  elapsed = 00:10:37  loss = 1.6302e-03  best loss = 1.6302e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5903  elapsed = 00:10:37  loss = 1.6365e-03  best loss = 1.6302e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5904  elapsed = 00:10:37  loss = 1.6349e-03  best loss = 1.6302e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5905  elapsed = 00:10:37  loss = 1.6260e-03  best loss = 1.6260e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5906  elapsed = 00:10:37  loss = 1.6346e-03  best loss = 1.6260e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5907  elapsed = 00:10:37  loss = 1.6264e-03  best loss = 1.6260e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5908  elapsed = 00:10:37  loss = 1.6228e-03  best loss = 1.6228e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5909  elapsed = 00:10:38  loss = 1.6227e-03  best loss = 1.6227e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5910  elapsed = 00:10:38  loss = 1.6188e-03  best loss = 1.6188e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5911  elapsed = 00:10:38  loss = 1.6196e-03  best loss = 1.6188e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5912  elapsed = 00:10:38  loss = 1.6193e-03  best loss = 1.6188e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5913  elapsed = 00:10:38  loss = 1.6198e-03  best loss = 1.6188e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5914  elapsed = 00:10:38  loss = 1.6316e-03  best loss = 1.6188e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5915  elapsed = 00:10:38  loss = 1.6283e-03  best loss = 1.6188e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5916  elapsed = 00:10:38  loss = 1.6073e-03  best loss = 1.6073e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5917  elapsed = 00:10:38  loss = 1.6146e-03  best loss = 1.6073e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5918  elapsed = 00:10:39  loss = 1.6369e-03  best loss = 1.6073e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5919  elapsed = 00:10:39  loss = 1.6377e-03  best loss = 1.6073e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5920  elapsed = 00:10:39  loss = 1.6158e-03  best loss = 1.6073e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5921  elapsed = 00:10:39  loss = 1.6051e-03  best loss = 1.6051e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5922  elapsed = 00:10:39  loss = 1.6178e-03  best loss = 1.6051e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5923  elapsed = 00:10:39  loss = 1.6163e-03  best loss = 1.6051e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5924  elapsed = 00:10:39  loss = 1.6081e-03  best loss = 1.6051e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5925  elapsed = 00:10:39  loss = 1.5935e-03  best loss = 1.5935e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5926  elapsed = 00:10:39  loss = 1.5915e-03  best loss = 1.5915e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5927  elapsed = 00:10:39  loss = 1.6006e-03  best loss = 1.5915e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5928  elapsed = 00:10:40  loss = 1.6001e-03  best loss = 1.5915e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5929  elapsed = 00:10:40  loss = 1.5951e-03  best loss = 1.5915e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5930  elapsed = 00:10:40  loss = 1.5850e-03  best loss = 1.5850e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5931  elapsed = 00:10:40  loss = 1.5822e-03  best loss = 1.5822e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5932  elapsed = 00:10:40  loss = 1.5791e-03  best loss = 1.5791e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5933  elapsed = 00:10:40  loss = 1.5900e-03  best loss = 1.5791e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5934  elapsed = 00:10:40  loss = 1.5959e-03  best loss = 1.5791e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5935  elapsed = 00:10:40  loss = 1.5929e-03  best loss = 1.5791e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5936  elapsed = 00:10:40  loss = 1.5879e-03  best loss = 1.5791e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5937  elapsed = 00:10:41  loss = 1.5711e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5938  elapsed = 00:10:41  loss = 1.5901e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5939  elapsed = 00:10:41  loss = 1.6268e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5940  elapsed = 00:10:41  loss = 1.6472e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5941  elapsed = 00:10:41  loss = 1.6328e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5942  elapsed = 00:10:41  loss = 1.6346e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5943  elapsed = 00:10:41  loss = 1.6510e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5944  elapsed = 00:10:41  loss = 1.6249e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5945  elapsed = 00:10:41  loss = 1.5866e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5946  elapsed = 00:10:42  loss = 1.5712e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5947  elapsed = 00:10:42  loss = 1.5877e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5948  elapsed = 00:10:42  loss = 1.6239e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5949  elapsed = 00:10:42  loss = 1.6177e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5950  elapsed = 00:10:42  loss = 1.5944e-03  best loss = 1.5711e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5951  elapsed = 00:10:42  loss = 1.5614e-03  best loss = 1.5614e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5952  elapsed = 00:10:42  loss = 1.5523e-03  best loss = 1.5523e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5953  elapsed = 00:10:42  loss = 1.5796e-03  best loss = 1.5523e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5954  elapsed = 00:10:42  loss = 1.6144e-03  best loss = 1.5523e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5955  elapsed = 00:10:42  loss = 1.6109e-03  best loss = 1.5523e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5956  elapsed = 00:10:43  loss = 1.5725e-03  best loss = 1.5523e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5957  elapsed = 00:10:43  loss = 1.5423e-03  best loss = 1.5423e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5958  elapsed = 00:10:43  loss = 1.5415e-03  best loss = 1.5415e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5959  elapsed = 00:10:43  loss = 1.5687e-03  best loss = 1.5415e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5960  elapsed = 00:10:43  loss = 1.6125e-03  best loss = 1.5415e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5961  elapsed = 00:10:43  loss = 1.6211e-03  best loss = 1.5415e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5962  elapsed = 00:10:43  loss = 1.5839e-03  best loss = 1.5415e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5963  elapsed = 00:10:43  loss = 1.5388e-03  best loss = 1.5388e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5964  elapsed = 00:10:43  loss = 1.5321e-03  best loss = 1.5321e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5965  elapsed = 00:10:44  loss = 1.5558e-03  best loss = 1.5321e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5966  elapsed = 00:10:44  loss = 1.5606e-03  best loss = 1.5321e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5967  elapsed = 00:10:44  loss = 1.5418e-03  best loss = 1.5321e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5968  elapsed = 00:10:44  loss = 1.5271e-03  best loss = 1.5271e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5969  elapsed = 00:10:44  loss = 1.5249e-03  best loss = 1.5249e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5970  elapsed = 00:10:44  loss = 1.5374e-03  best loss = 1.5249e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5971  elapsed = 00:10:44  loss = 1.5451e-03  best loss = 1.5249e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5972  elapsed = 00:10:44  loss = 1.5378e-03  best loss = 1.5249e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5973  elapsed = 00:10:44  loss = 1.5319e-03  best loss = 1.5249e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5974  elapsed = 00:10:44  loss = 1.5171e-03  best loss = 1.5171e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5975  elapsed = 00:10:45  loss = 1.5205e-03  best loss = 1.5171e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5976  elapsed = 00:10:45  loss = 1.5192e-03  best loss = 1.5171e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5977  elapsed = 00:10:45  loss = 1.5198e-03  best loss = 1.5171e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5978  elapsed = 00:10:45  loss = 1.5110e-03  best loss = 1.5110e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5979  elapsed = 00:10:45  loss = 1.5113e-03  best loss = 1.5110e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5980  elapsed = 00:10:45  loss = 1.5086e-03  best loss = 1.5086e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5981  elapsed = 00:10:45  loss = 1.5077e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5982  elapsed = 00:10:45  loss = 1.5106e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5983  elapsed = 00:10:45  loss = 1.5098e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5984  elapsed = 00:10:46  loss = 1.5134e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5985  elapsed = 00:10:46  loss = 1.5221e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5986  elapsed = 00:10:46  loss = 1.5134e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5987  elapsed = 00:10:46  loss = 1.5155e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5988  elapsed = 00:10:46  loss = 1.5191e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5989  elapsed = 00:10:46  loss = 1.5202e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5990  elapsed = 00:10:46  loss = 1.5269e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5991  elapsed = 00:10:46  loss = 1.5380e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5992  elapsed = 00:10:46  loss = 1.5328e-03  best loss = 1.5077e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5993  elapsed = 00:10:47  loss = 1.4907e-03  best loss = 1.4907e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5994  elapsed = 00:10:47  loss = 1.4893e-03  best loss = 1.4893e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5995  elapsed = 00:10:47  loss = 1.5038e-03  best loss = 1.4893e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5996  elapsed = 00:10:47  loss = 1.5121e-03  best loss = 1.4893e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5997  elapsed = 00:10:47  loss = 1.4862e-03  best loss = 1.4862e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5998  elapsed = 00:10:47  loss = 1.4824e-03  best loss = 1.4824e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5999  elapsed = 00:10:47  loss = 1.4970e-03  best loss = 1.4824e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6000  elapsed = 00:10:47  loss = 1.5020e-03  best loss = 1.4824e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6001  elapsed = 00:10:47  loss = 1.4890e-03  best loss = 1.4824e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6002  elapsed = 00:10:48  loss = 1.4713e-03  best loss = 1.4713e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6003  elapsed = 00:10:48  loss = 1.4760e-03  best loss = 1.4713e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6004  elapsed = 00:10:48  loss = 1.4905e-03  best loss = 1.4713e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6005  elapsed = 00:10:48  loss = 1.4856e-03  best loss = 1.4713e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6006  elapsed = 00:10:48  loss = 1.4802e-03  best loss = 1.4713e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6007  elapsed = 00:10:48  loss = 1.4929e-03  best loss = 1.4713e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6008  elapsed = 00:10:48  loss = 1.4701e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6009  elapsed = 00:10:48  loss = 1.4836e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6010  elapsed = 00:10:48  loss = 1.4961e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6011  elapsed = 00:10:48  loss = 1.5036e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6012  elapsed = 00:10:49  loss = 1.5364e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6013  elapsed = 00:10:49  loss = 1.5335e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6014  elapsed = 00:10:49  loss = 1.5207e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6015  elapsed = 00:10:49  loss = 1.4719e-03  best loss = 1.4701e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6016  elapsed = 00:10:49  loss = 1.4531e-03  best loss = 1.4531e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6017  elapsed = 00:10:49  loss = 1.4987e-03  best loss = 1.4531e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6018  elapsed = 00:10:49  loss = 1.5330e-03  best loss = 1.4531e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6019  elapsed = 00:10:49  loss = 1.5032e-03  best loss = 1.4531e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6020  elapsed = 00:10:49  loss = 1.4710e-03  best loss = 1.4531e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6021  elapsed = 00:10:50  loss = 1.4494e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6022  elapsed = 00:10:50  loss = 1.4567e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6023  elapsed = 00:10:50  loss = 1.4697e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6024  elapsed = 00:10:50  loss = 1.4908e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6025  elapsed = 00:10:50  loss = 1.5243e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6026  elapsed = 00:10:50  loss = 1.5173e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6027  elapsed = 00:10:50  loss = 1.4725e-03  best loss = 1.4494e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6028  elapsed = 00:10:50  loss = 1.4414e-03  best loss = 1.4414e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6029  elapsed = 00:10:50  loss = 1.4338e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6030  elapsed = 00:10:51  loss = 1.4409e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6031  elapsed = 00:10:51  loss = 1.4602e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6032  elapsed = 00:10:51  loss = 1.4805e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6033  elapsed = 00:10:51  loss = 1.4901e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6034  elapsed = 00:10:51  loss = 1.4898e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6035  elapsed = 00:10:51  loss = 1.4611e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6036  elapsed = 00:10:51  loss = 1.4707e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6037  elapsed = 00:10:51  loss = 1.5291e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6038  elapsed = 00:10:51  loss = 1.5709e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6039  elapsed = 00:10:51  loss = 1.4856e-03  best loss = 1.4338e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6040  elapsed = 00:10:52  loss = 1.4251e-03  best loss = 1.4251e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6041  elapsed = 00:10:52  loss = 1.4290e-03  best loss = 1.4251e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6042  elapsed = 00:10:52  loss = 1.4793e-03  best loss = 1.4251e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6043  elapsed = 00:10:52  loss = 1.4675e-03  best loss = 1.4251e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6044  elapsed = 00:10:52  loss = 1.4195e-03  best loss = 1.4195e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6045  elapsed = 00:10:52  loss = 1.4102e-03  best loss = 1.4102e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6046  elapsed = 00:10:52  loss = 1.4272e-03  best loss = 1.4102e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6047  elapsed = 00:10:52  loss = 1.4261e-03  best loss = 1.4102e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6048  elapsed = 00:10:52  loss = 1.4192e-03  best loss = 1.4102e-03  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   6049  elapsed = 00:10:53  loss = 1.4096e-03  best loss = 1.4096e-03  error = 1.0000e+00  adaptive_param = 1.000000
# ...
# Step 110 loss 0.00024
# Step 120 loss 0.00024
# Step 130 loss 0.00023
# Step 140 loss 0.00023
# Step 150 loss 0.00023
# Step 160 loss 0.00022
# Step 170 loss 0.00022
# Step 180 loss 0.00022
# Step 190 loss 0.00021
# Step 200 loss 0.00021
# Step 210 loss 0.00021
# Step 220 loss 0.00020
# Step 230 loss 0.00020
# Step 240 loss 0.00020
# Step 250 loss 0.00020
# Step 260 loss 0.00019
# Step 270 loss 0.00019
# Step 280 loss 0.00019
# Step 290 loss 0.00019
# Step 300 loss 0.00019
# Step 310 loss 0.00018
# Step 320 loss 0.00018
# Step 330 loss 0.00018
# Step 340 loss 0.00018
# Step 350 loss 0.00018
# Step 360 loss 0.00018
# Step 370 loss 0.00017
# Step 380 loss 0.00017
# Step 390 loss 0.00017
# Step 400 loss 0.00017
# Step 410 loss 0.00017
# Step 420 loss 0.00017
# Step 430 loss 0.00017
# Step 440 loss 0.00016
# Step 450 loss 0.00016
# Step 460 loss 0.00016
# Step 470 loss 0.00016
# Step 480 loss 0.00016
# Step 490 loss 0.00016
# Step 500 loss 0.00016
# Step 510 loss 0.00016
# Step 520 loss 0.00016
# Step 530 loss 0.00015
# Step 540 loss 0.00015
# Step 550 loss 0.00015
# Step 560 loss 0.00015
# Step 570 loss 0.00015
# Step 580 loss 0.00015
# Step 590 loss 0.00015
# Step 600 loss 0.00015
# Step 610 loss 0.00015
# Step 620 loss 0.00015
# Step 630 loss 0.00015
# Step 640 loss 0.00015
# Step 650 loss 0.00014
# Step 660 loss 0.00014
# Step 670 loss 0.00014
# Step 680 loss 0.00014
# Step 690 loss 0.00014
# Step 700 loss 0.00014
# Step 710 loss 0.00014
# Step 720 loss 0.00014
# Step 730 loss 0.00014
# Step 740 loss 0.00014
# Step 750 loss 0.00014
# Step 760 loss 0.00014
# Step 770 loss 0.00014
# Step 780 loss 0.00014
# Step 790 loss 0.00014
# Step 800 loss 0.00014
# Step 810 loss 0.00013
# Step 820 loss 0.00013
# Step 830 loss 0.00013
# Step 840 loss 0.00013
# Step 850 loss 0.00013
# Step 860 loss 0.00013
# Step 870 loss 0.00013
# Step 880 loss 0.00013
# Step 890 loss 0.00013
# Step 900 loss 0.00013
# Step 910 loss 0.00013
# Step 920 loss 0.00013
# Step 930 loss 0.00013
# Step 940 loss 0.00013
# Step 950 loss 0.00013
# Step 960 loss 0.00013
# Step 970 loss 0.00013
# Step 980 loss 0.00013
# Step 990 loss 0.00013
# Step 1000 loss 0.00012
# Step 1010 loss 0.00012
# Step 1020 loss 0.00012
# Step 1030 loss 0.00012
# Step 1040 loss 0.00012
# Step 1050 loss 0.00012
# Step 1060 loss 0.00012
# Step 1070 loss 0.00012
# Step 1080 loss 0.00012
# Step 1090 loss 0.00012
# Step 1100 loss 0.00012
# Step 1110 loss 0.00012
# Step 1120 loss 0.00012
# Step 1130 loss 0.00012
# Step 1140 loss 0.00012
# Step 1150 loss 0.00012
# Step 1160 loss 0.00012
# Step 1170 loss 0.00012
# Step 1180 loss 0.00012
# Step 1190 loss 0.00012
# Step 1200 loss 0.00012
# Step 1210 loss 0.00012
# Step 1220 loss 0.00012
# Step 1230 loss 0.00012
# Step 1240 loss 0.00012
# Step 1250 loss 0.00011
# Step 1260 loss 0.00011
# Step 1270 loss 0.00011
# Step 1280 loss 0.00011
# Step 1290 loss 0.00011
# Step 1300 loss 0.00011
# Step 1310 loss 0.00011
# Step 1320 loss 0.00011
# Step 1330 loss 0.00011
# Step 1340 loss 0.00011
# Step 1350 loss 0.00011
# Step 1360 loss 0.00011
# Step 1370 loss 0.00011
# Step 1380 loss 0.00011
# Step 1390 loss 0.00011
# Step 1400 loss 0.00011
# Step 1410 loss 0.00011
# Step 1420 loss 0.00011
# Step 1430 loss 0.00011
# Step 1440 loss 0.00011
# Step 1450 loss 0.00011
# Step 1460 loss 0.00011
# Step 1470 loss 0.00011
# Step 1480 loss 0.00011
# Step 1490 loss 0.00011
# Step 1500 loss 0.00011
# Step 1510 loss 0.00011
# Step 1520 loss 0.00011
# Step 1530 loss 0.00011
# Step 1540 loss 0.00011
# Step 1550 loss 0.00011
# Step 1560 loss 0.00011
# Step 1570 loss 0.00011
# Step 1580 loss 0.00011
# Step 1590 loss 0.00011
# Step 1600 loss 0.00011
# Step 1610 loss 0.00011
# Step 1620 loss 0.00011
# Step 1630 loss 0.00011
# Step 1640 loss 0.00011
# Step 1650 loss 0.00010
# Step 1660 loss 0.00010
# Step 1670 loss 0.00010
# Step 1680 loss 0.00010
# Step 1690 loss 0.00010
# Step 1700 loss 0.00010
# Step 1710 loss 0.00010
# Step 1720 loss 0.00010
# Step 1730 loss 0.00010
# Step 1740 loss 0.00010
# Step 1750 loss 0.00010
# Step 1760 loss 0.00010
# Step 1770 loss 0.00010
# Step 1780 loss 0.00010
# Step 1790 loss 0.00010
# Step 1800 loss 0.00010
# Step 1810 loss 0.00010
# Step 1820 loss 0.00010
# Step 1830 loss 0.00010
# Step 1840 loss 0.00010
# Step 1850 loss 0.00010
# Step 1860 loss 0.00010
# Step 1870 loss 0.00010
# Step 1880 loss 0.00010
# Step 1890 loss 0.00010
# Step 1900 loss 0.00010
# Step 1910 loss 0.00010
# Step 1920 loss 0.00010
# Step 1930 loss 0.00010
# Step 1940 loss 0.00010
# Step 1950 loss 0.00010
# Step 1960 loss 0.00010
# Step 1970 loss 0.00010
# Step 1980 loss 0.00010
# Step 1990 loss 0.00010
# Step 2000 loss 0.00010
# Step 2010 loss 0.00010
# Step 2020 loss 0.00010
# Step 2030 loss 0.00010
# Step 2040 loss 0.00010
# Step 2050 loss 0.00010
# Step 2060 loss 0.00010
# Step 2070 loss 0.00010
# Step 2080 loss 0.00010
# Step 2090 loss 0.00010
# Step 2100 loss 0.00010
# Step 2110 loss 0.00010
# Step 2120 loss 0.00010
# Step 2130 loss 0.00010
# Step 2140 loss 0.00010
# Step 2150 loss 0.00010
# Step 2160 loss 0.00010
# Step 2170 loss 0.00010
# Step 2180 loss 0.00010
# Step 2190 loss 0.00010
# Step 2200 loss 0.00010
# Step 2210 loss 0.00010
# Step 2220 loss 0.00010
# Step 2230 loss 0.00010
# Step 2240 loss 0.00010
# Step 2250 loss 0.00010
# Step 2260 loss 0.00010
# Step 2270 loss 0.00010
# Step 2280 loss 0.00010
# Step 2290 loss 0.00010
# Step 2300 loss 0.00010
# Step 2310 loss 0.00009
# Step 2320 loss 0.00009
# Step 2330 loss 0.00009
# Step 2340 loss 0.00009
# Step 2350 loss 0.00009
# Step 2360 loss 0.00009
# Step 2370 loss 0.00009
# Step 2380 loss 0.00009
# Step 2390 loss 0.00009
# Step 2400 loss 0.00009
# Step 2410 loss 0.00009
# Step 2420 loss 0.00009
# Step 2430 loss 0.00009
# Step 2440 loss 0.00009
# Step 2450 loss 0.00009
# Step 2460 loss 0.00009
# Step 2470 loss 0.00009
# Step 2480 loss 0.00009
# Step 2490 loss 0.00009
# Step 2500 loss 0.00009
# Step 2510 loss 0.00009
# Step 2520 loss 0.00009
# Step 2530 loss 0.00009
# Step 2540 loss 0.00009
# Step 2550 loss 0.00009
# Step 2560 loss 0.00009
# Step 2570 loss 0.00009
# Step 2580 loss 0.00009
# Step 2590 loss 0.00009
# Step 2600 loss 0.00009
# Step 2610 loss 0.00009
# Step 2620 loss 0.00009
# Step 2630 loss 0.00009
# Step 2640 loss 0.00009
# Step 2650 loss 0.00009
# Step 2660 loss 0.00009
# Step 2670 loss 0.00009
# Step 2680 loss 0.00009
# Step 2690 loss 0.00009
# Step 2700 loss 0.00009
# Step 2710 loss 0.00009
# Step 2720 loss 0.00009
# Step 2730 loss 0.00009
# Step 2740 loss 0.00009
# Step 2750 loss 0.00009
# Step 2760 loss 0.00009
# Step 2770 loss 0.00009
# Step 2780 loss 0.00009
# Step 2790 loss 0.00009
# Step 2800 loss 0.00009
# Step 2810 loss 0.00009
# Step 2820 loss 0.00009
# Step 2830 loss 0.00009
# Step 2840 loss 0.00009
# Step 2850 loss 0.00009
# Step 2860 loss 0.00009
# Step 2870 loss 0.00009
# Step 2880 loss 0.00009
# Step 2890 loss 0.00009
# Step 2900 loss 0.00009
# Step 2910 loss 0.00009
# Step 2920 loss 0.00009
# Step 2930 loss 0.00009
# Step 2940 loss 0.00009
# Step 2950 loss 0.00009
# Step 2960 loss 0.00009
# Step 2970 loss 0.00009
# Step 2980 loss 0.00009
# Step 2990 loss 0.00009
# Step 3000 loss 0.00009
# Step 3010 loss 0.00009
# Step 3020 loss 0.00009
# Step 3030 loss 0.00009
# Step 3040 loss 0.00009
# Step 3050 loss 0.00009
# Step 3060 loss 0.00009
# Step 3070 loss 0.00009
# Step 3080 loss 0.00009
# Step 3090 loss 0.00009
# Step 3100 loss 0.00009
# Step 3110 loss 0.00009
# Step 3120 loss 0.00009
# Step 3130 loss 0.00009
# Step 3140 loss 0.00009
# Step 3150 loss 0.00009
# Step 3160 loss 0.00009
# Step 3170 loss 0.00009
# Step 3180 loss 0.00009
# Step 3190 loss 0.00009
# Step 3200 loss 0.00009
# Step 3210 loss 0.00009
# Step 3220 loss 0.00009
# Step 3230 loss 0.00009
# Step 3240 loss 0.00009
# Step 3250 loss 0.00009
# Step 3260 loss 0.00008
# Step 3270 loss 0.00008
# Step 3280 loss 0.00008
# Step 3290 loss 0.00008
# Step 3300 loss 0.00008
# Step 3310 loss 0.00008
# Step 3320 loss 0.00008
# Step 3330 loss 0.00008
# Step 3340 loss 0.00008
# Step 3350 loss 0.00008
# Step 3360 loss 0.00008
# Step 3370 loss 0.00008
# Step 3380 loss 0.00008
# Step 3390 loss 0.00008
# Step 3400 loss 0.00008
# Step 3410 loss 0.00008
# Step 3420 loss 0.00008
# Step 3430 loss 0.00008
# Step 3440 loss 0.00008
# Step 3450 loss 0.00008
# Step 3460 loss 0.00008
# Step 3470 loss 0.00008
# Step 3480 loss 0.00008
# Step 3490 loss 0.00008
# Step 3500 loss 0.00008
# Step 3510 loss 0.00008
# Step 3520 loss 0.00008
# Step 3530 loss 0.00008
# Step 3540 loss 0.00008
# Step 3550 loss 0.00008
# Step 3560 loss 0.00008
# Step 3570 loss 0.00008
# Step 3580 loss 0.00008
# Step 3590 loss 0.00008
# Step 3600 loss 0.00008
# Step 3610 loss 0.00008
# Step 3620 loss 0.00008
# Step 3630 loss 0.00008
# Step 3640 loss 0.00008
# Step 3650 loss 0.00008
# Step 3660 loss 0.00008
# Step 3670 loss 0.00008
# Step 3680 loss 0.00008
# Step 3690 loss 0.00008
# Step 3700 loss 0.00008
# Step 3710 loss 0.00008
# Step 3720 loss 0.00008
# Step 3730 loss 0.00008
# Step 3740 loss 0.00008
# Step 3750 loss 0.00008
# Step 3760 loss 0.00008
# Step 3770 loss 0.00008
# Step 3780 loss 0.00008
# Step 3790 loss 0.00008
# Step 3800 loss 0.00008
# Step 3810 loss 0.00008
# Step 3820 loss 0.00008
# Step 3830 loss 0.00008
# Step 3840 loss 0.00008
# Step 3850 loss 0.00008
# Step 3860 loss 0.00008
# Step 3870 loss 0.00008
# Step 3880 loss 0.00008
# Step 3890 loss 0.00008
# Step 3900 loss 0.00008
# Step 3910 loss 0.00008
# Step 3920 loss 0.00008
# Step 3930 loss 0.00008
# Step 3940 loss 0.00008
# Step 3950 loss 0.00008
# Step 3960 loss 0.00008
# Step 3970 loss 0.00008
# Step 3980 loss 0.00008
# Step 3990 loss 0.00008
# Step 4000 loss 0.00008
# Step 4010 loss 0.00008
# Step 4020 loss 0.00008
# Step 4030 loss 0.00008
# Step 4040 loss 0.00008
# Step 4050 loss 0.00007
# Step 4060 loss 0.00007
# Step 4070 loss 0.00007
# Step 4080 loss 0.00007
# Step 4090 loss 0.00007
# Step 4100 loss 0.00007
# Step 4110 loss 0.00007
# Step 4120 loss 0.00007
# Step 4130 loss 0.00007
# Step 4140 loss 0.00007
# Step 4150 loss 0.00007
# Step 4160 loss 0.00007
# Step 4170 loss 0.00007
# Step 4180 loss 0.00007
# Step 4190 loss 0.00007
# Step 4200 loss 0.00007
# Step 4210 loss 0.00006
# Step 4220 loss 0.00006
# Step 4230 loss 0.00006
# Step 4240 loss 0.00006
# Step 4250 loss 0.00006
# Step 4260 loss 0.00006
# Step 4270 loss 0.00006
# Step 4280 loss 0.00006
# Step 4290 loss 0.00006
# Step 4300 loss 0.00006
# Step 4310 loss 0.00006
# Step 4320 loss 0.00005
# Step 4330 loss 0.00005
# Step 4340 loss 0.00005
# Step 4350 loss 0.00005
# Step 4360 loss 0.00005
# Step 4370 loss 0.00005
# Step 4380 loss 0.00005
# Step 4390 loss 0.00005
# Step 4400 loss 0.00005
# Step 4410 loss 0.00005
# Step 4420 loss 0.00005
# Step 4430 loss 0.00005
# Step 4440 loss 0.00005
# Step 4450 loss 0.00005
# Step 4460 loss 0.00005
# Step 4470 loss 0.00005
# Step 4480 loss 0.00005
# Step 4490 loss 0.00005
# Step 4500 loss 0.00004
# Step 4510 loss 0.00004
# Step 4520 loss 0.00004
# Step 4530 loss 0.00004
# Step 4540 loss 0.00004
# Step 4550 loss 0.00004
# Step 4560 loss 0.00004
# Step 4570 loss 0.00004
# Step 4580 loss 0.00004
# Step 4590 loss 0.00004
# Step 4600 loss 0.00004
# Step 4610 loss 0.00004
# Step 4620 loss 0.00004
# Step 4630 loss 0.00004
# Step 4640 loss 0.00004
# Step 4650 loss 0.00004
# Step 4660 loss 0.00004
# Step 4670 loss 0.00004
# Step 4680 loss 0.00004
# Step 4690 loss 0.00004
# Step 4700 loss 0.00004
# Step 4710 loss 0.00004
# Step 4720 loss 0.00004
# Step 4730 loss 0.00004
# Step 4740 loss 0.00004
# Step 4750 loss 0.00004
# Step 4760 loss 0.00004
# Step 4770 loss 0.00004
# Step 4780 loss 0.00004
# Step 4790 loss 0.00004
# Step 4800 loss 0.00004
# Step 4810 loss 0.00004
# Step 4820 loss 0.00004
# Step 4830 loss 0.00004
# Step 4840 loss 0.00004
# Step 4850 loss 0.00004
# Step 4860 loss 0.00004
# Step 4870 loss 0.00004
# Step 4880 loss 0.00004
# Step 4890 loss 0.00004
# Step 4900 loss 0.00004
# Step 4910 loss 0.00004
# Step 4920 loss 0.00004
# Step 4930 loss 0.00004
# Step 4940 loss 0.00004
# Step 4950 loss 0.00003
# Step 4960 loss 0.00003
# Step 4970 loss 0.00003
# Step 4980 loss 0.00003
# Step 4990 loss 0.00003
# Step 5000 loss 0.00003
# Step 5010 loss 0.00003
# Step 5020 loss 0.00003
# Step 5030 loss 0.00003
# Step 5040 loss 0.00003
# Step 5050 loss 0.00003
# Step 5060 loss 0.00003
# Step 5070 loss 0.00003
# Step 5080 loss 0.00003
# Step 5090 loss 0.00003
# Step 5100 loss 0.00003
# Step 5110 loss 0.00003
# Step 5120 loss 0.00003
# Step 5130 loss 0.00003
# Step 5140 loss 0.00003
# Step 5150 loss 0.00003
# Step 5160 loss 0.00003
# Step 5170 loss 0.00003
# Step 5180 loss 0.00003
# Step 5190 loss 0.00003
# Step 5200 loss 0.00003
# Step 5210 loss 0.00003
# Step 5220 loss 0.00003
# Step 5230 loss 0.00003
# Step 5240 loss 0.00003
# Step 5250 loss 0.00003
# Step 5260 loss 0.00003
# Step 5270 loss 0.00003
# Step 5280 loss 0.00003
# Step 5290 loss 0.00003
# Step 5300 loss 0.00003
# Step 5310 loss 0.00003
# Step 5320 loss 0.00003
# Step 5330 loss 0.00003
# Step 5340 loss 0.00003
# Step 5350 loss 0.00003
# Step 5360 loss 0.00003
# Step 5370 loss 0.00003
# Step 5380 loss 0.00003
# Step 5390 loss 0.00003
# Step 5400 loss 0.00003
# Step 5410 loss 0.00003
# Step 5420 loss 0.00003
# Step 5430 loss 0.00003
# Step 5440 loss 0.00003
# Step 5450 loss 0.00003
# Step 5460 loss 0.00003
# Step 5470 loss 0.00003
# Step 5480 loss 0.00003
# Step 5490 loss 0.00003
# Step 5500 loss 0.00003
# Step 5510 loss 0.00003
# Step 5520 loss 0.00003
# Step 5530 loss 0.00003
# Step 5540 loss 0.00003
# Step 5550 loss 0.00003
# Step 5560 loss 0.00003
# Step 5570 loss 0.00003
# Step 5580 loss 0.00003
# Step 5590 loss 0.00003
# Step 5600 loss 0.00003
# Step 5610 loss 0.00003
# Step 5620 loss 0.00003
# Step 5630 loss 0.00003
# Step 5640 loss 0.00003
# Step 5650 loss 0.00003
# Step 5660 loss 0.00003
# Step 5670 loss 0.00003
# Step 5680 loss 0.00003
# Step 5690 loss 0.00003
# Step 5700 loss 0.00003
# Step 5710 loss 0.00003
# Step 5720 loss 0.00003
# Step 5730 loss 0.00003
# Step 5740 loss 0.00003
# Step 5750 loss 0.00003
# Step 5760 loss 0.00003
# Step 5770 loss 0.00003
# Step 5780 loss 0.00003
# Step 5790 loss 0.00003
# Step 5800 loss 0.00003
# Step 5810 loss 0.00003
# Step 5820 loss 0.00003
# Step 5830 loss 0.00003
# Step 5840 loss 0.00003
# Step 5850 loss 0.00003
# Step 5860 loss 0.00003
# Step 5870 loss 0.00003
# Step 5880 loss 0.00003
# Step 5890 loss 0.00003
# Step 5900 loss 0.00003
# Step 5910 loss 0.00003
# Step 5920 loss 0.00003
# Step 5930 loss 0.00003
# Step 5940 loss 0.00003
# Step 5950 loss 0.00003
# Step 5960 loss 0.00003
# Step 5970 loss 0.00003
# Step 5980 loss 0.00003
# Step 5990 loss 0.00003
# Step 6000 loss 0.00003
# Step 6010 loss 0.00003
# Step 6020 loss 0.00003
# Step 6030 loss 0.00003
# Step 6040 loss 0.00003
# Step 6050 loss 0.00003
# Step 6060 loss 0.00003
# Step 6070 loss 0.00003
# Step 6080 loss 0.00003
# Step 6090 loss 0.00003
# Step 6100 loss 0.00003
# Step 6110 loss 0.00003
# Step 6120 loss 0.00003
# Step 6130 loss 0.00003
# Step 6140 loss 0.00003
# Step 6150 loss 0.00003
# Step 6160 loss 0.00003
# Step 6170 loss 0.00003
# Step 6180 loss 0.00003
# Step 6190 loss 0.00003
# Step 6200 loss 0.00003
# Step 6210 loss 0.00003
# Step 6220 loss 0.00003
# Step 6230 loss 0.00003
# Step 6240 loss 0.00003
# Step 6250 loss 0.00003
# Step 6260 loss 0.00003
# Step 6270 loss 0.00003
# Step 6280 loss 0.00003
# Step 6290 loss 0.00003
# Step 6300 loss 0.00003
# Step 6310 loss 0.00003
# Step 6320 loss 0.00003
# Step 6330 loss 0.00003
# Step 6340 loss 0.00003
# Step 6350 loss 0.00003
# Step 6360 loss 0.00003
# Step 6370 loss 0.00003
# Step 6380 loss 0.00003
# Step 6390 loss 0.00003
# Step 6400 loss 0.00003
# Step 6410 loss 0.00003
# Step 6420 loss 0.00003
# Step 6430 loss 0.00003
# Step 6440 loss 0.00003
# Step 6450 loss 0.00003
# Step 6460 loss 0.00003
# Step 6470 loss 0.00003
# Step 6480 loss 0.00003
# Step 6490 loss 0.00003
# Step 6500 loss 0.00003
# Step 6510 loss 0.00003
# Step 6520 loss 0.00003
# Step 6530 loss 0.00003
# Step 6540 loss 0.00003
# Step 6550 loss 0.00003
# Step 6560 loss 0.00003
# Step 6570 loss 0.00003
# Step 6580 loss 0.00003
# Step 6590 loss 0.00003
# Step 6600 loss 0.00003
# Step 6610 loss 0.00003
# Step 6620 loss 0.00003
# Step 6630 loss 0.00003
# Step 6640 loss 0.00003
# Step 6650 loss 0.00003
# Step 6660 loss 0.00003
# Step 6670 loss 0.00003
# Step 6680 loss 0.00003
# Step 6690 loss 0.00003
# Step 6700 loss 0.00003
# Step 6710 loss 0.00003
# Step 6720 loss 0.00003
# ==================
# Training finished (epoch 10000): duration = 00:29:01  loss = 3.1036e-04  best loss = 2.6491e-05  error = 1.0000e+00
# Applying the weights at the best epoch to the model...

# %%
LossParameterPlotterForward(loss_history)

# %%
X_test, Y_test, u_star_plot, u_plot, u_train_pred, trained_weights = ExtractData(pinn, X_star, X_u_train, u_star)

# %%
#@title Error forward
def error_2():
    u_pred, _ = pinn.predict(X_f)
    u_starT = u_star.reshape(100,100,2000)
    u_starT = np.swapaxes(u_starT,0,1)
    u_starT = u_starT.flatten()[:,None]
    return np.linalg.norm(u_starT - u_pred, 2) / np.linalg.norm(u_starT, 2)

# %%
DiscretePlotter(t,X_test,Y_test,u_plot,ub,zmax=0.3,zmin=0.0,cmap='rainbow')
# Out:
# No handles with labels found to put in legend.

# %%
savemat('PINNresults2DForwardFullbatchLBFGSAdapt.mat', {'u_pred': u_plot, 'u_true': u_star_plot, 'loss_history': loss_history,
                           'X_f':X_f, 'X_u_train': X_u_train, 'u_train': u_train, 'u_train_pred': u_train_pred, 'X': X_test, 'Y': Y_test, 
                           'layers': layers, 'noise': noise, 'u_param': u_param, 'f_param': f_param, 'tf_epochs': tf_epochs, 'mini_batch_size': batch_size,
                           'adaptive_param': adaptive_param_history})
