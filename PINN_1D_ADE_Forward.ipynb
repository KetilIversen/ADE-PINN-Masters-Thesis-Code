# %% [markdown]
# <a href="https://colab.research.google.com/github/KetilIversen/ADE-PINN-Masters-Thesis-Code/blob/main/PINN_1D_ADE_Forward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyDOE
# Out:
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.4.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=4438f48a7a1fc63e3451e6345888f8e226579945d034b8659df1edc74cffa0de
#   Stored in directory: /root/.cache/pip/wheels/83/ce/8a/87b25c685bfeca1872d13b8dc101e087a9c6e3fb5ebb47022a
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
#@title Imports forward
import sys
import os
import time
from datetime import datetime
import tensorflow as tf
import numpy as np
import scipy.io
import tensorflow_probability as tfp
from pyDOE import lhs

import matplotlib
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.interpolate import griddata
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
#@title Prep data forward
def prep_data(path, N_u=None, N_f=None, ub=None, lb=None, noise=0.0):
    # Reading external data
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['t'].flatten()[:,None] # T x 1
    x = data['x'].flatten()[:,None] # N x 1
    
    # Keeping the 2D data for the solution data (real() is maybe to make it float by default, in case of zeroes)
    Exact_u = np.real(data['u']).T # T x N

    # Meshing x and t in 2D (100,100)
    X, T = np.meshgrid(x,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array, as X_star
    X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
    
    # Preparing the testing u_star
    #u_star = np.swapaxes(Exact_u,0,1)
    u_star = Exact_u.flatten()[:,None]

    # Domain bounds (lowerbounds upperbounds) [x, t]
    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0) 
    # Getting the initial conditions (t=0)
    xx1 = np.hstack((X[0:1,:].flatten()[:,None], T[0:1,:].flatten()[:,None]))
    uu1 = Exact_u[0:1,:].flatten()[:,None]
    # Getting the lowest boundary conditions (x=-1) 
    xx2 = np.hstack((X[:,0:1].flatten()[:,None], T[:,0:1].flatten()[:,None]))
    uu2 = Exact_u[:,0:1].flatten()[:,None]
    # Getting the highest boundary conditions (x=1) 
    xx3 = np.hstack((X[:,-1:].flatten()[:,None], T[:,-1:].flatten()[:,None]))
    uu3 = Exact_u[:,-1:].flatten()[:,None]
    # Stacking them in multidimensional tensors for training (X_u_train is for now the continuous boundaries)
    X_u_train = np.vstack([xx1, xx2, xx3])
    u_train = np.vstack([uu1, uu2, uu3])

    # Generating the x and t collocation points for f, with each having a N_f size
    # We pointwise add and multiply to spread the LHS over the 3D domain
    X_f_train = lb + (ub-lb)*lhs(2, N_f)

    # Generating a uniform random sample from ints between 0, and the size of x_u_train, of size N_u (initial data size) and without replacement (unique)
    idx = np.random.choice(X_u_train.shape[0], N_u, replace=False)

    # Getting the corresponding X_u_train (which is now scarce boundary/initial coordinates)
    X_u_train = X_u_train[idx,:]
    # Getting the corresponding u_train
    u_train = u_train[idx,:]

    # Noise       
    u_train = u_train + noise*np.std(u_train)*np.random.randn(u_train.shape[0], u_train.shape[1])
    u_star = u_star + noise*np.std(u_star)*np.random.randn(u_star.shape[0], u_star.shape[1])

    return x, t, X, T, X_star, u_star, X_u_train, u_train, X_f_train, ub, lb

# %%
#@title Discrete plotter
def DiscretePlotter(x,t,u_plot,u_star_plot,lb,ub):

    def figsize(scale, nplots = 1):
        fig_width_pt = 390.0                          # Get this from LaTeX using \the\textwidth
        inches_per_pt = 1.0/72.27                       # Convert pt to inch
        golden_mean = (np.sqrt(5.0)-1.0)/2.0            # Aesthetic ratio (you could change this)
        fig_width = fig_width_pt*inches_per_pt*scale    # width in inches
        fig_height = nplots*fig_width*golden_mean              # height in inches
        fig_size = [fig_width,fig_height]
        return fig_size

    # I make my own newfig and savefig functions
    def newfig(width, nplots = 1):
        fig = plt.figure(figsize=figsize(width, nplots))
        ax = fig.add_subplot(111)
        return fig, ax

    N_t = t.shape[0]
    Lt = ub[1] - lb[1]
    t0 = 0; t1 = Lt/5; t2 = 2*Lt/5; t3 = 3*Lt/5; t4 = 4*Lt/5; t5 = 5*Lt/5;
    N0 = np.int(np.ceil((t0*N_t)/Lt))
    N1 = np.int(np.ceil((t1*N_t)/Lt))
    N2 = np.int(np.ceil((t2*N_t)/Lt))
    N3 = np.int(np.ceil((t3*N_t)/Lt))
    N4 = np.int(np.ceil((t4*N_t)/Lt))
    N5 = np.int(np.floor((t5*N_t-1)/Lt))

    fig, ax = newfig(3.0, 3.0)  
    gs1 = gridspec.GridSpec(2, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)

    ax = plt.subplot(gs1[0, 0])
    ax.plot(x,u_star_plot[:,N0], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,u_plot[:,N0], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[0, 1])      
    ax.plot(x,u_star_plot[:,N1], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,u_plot[:,N1], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[0, 2])       
    ax.plot(x,u_star_plot[:,N2], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,u_plot[:,N2], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[1, 0])
    ax.plot(x,u_star_plot[:,N3], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,u_plot[:,N3], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[1, 1])      
    ax.plot(x,u_star_plot[:,N4], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,u_plot[:,N4], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[1, 2])       
    ax.plot(x,u_star_plot[:,N5], 'b-', linewidth = 2, label = 'Exact')
    ax.plot(x,u_plot[:,N5], 'r--', linewidth = 2, label = 'Prediction')
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')    
    ax.set_title('$t = 0.25$', fontsize = 10)
    ax.axis('square')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1])
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)

    plt.show()

# %%
#@title Extract data from PINN
def ExtractData(pinn, X_star, X_u_train, u_star):

  # Getting the model predictions, over dense (x,y,t) domain
  X_star_batches = np.array_split(X_star,100)
  u_pred, _ = pinn.predict(X_star_batches[0])
  for i in range(len(X_star_batches)-1):
    u_pred_batch, _ = pinn.predict(X_star_batches[i+1])
    u_pred = np.vstack((u_pred,u_pred_batch))

  # Getting the model prediction, over training (x,y,t)
  X_u_train_batches = np.array_split(X_u_train,100)
  u_train_pred, _ = pinn.predict(X_u_train_batches[0])
  for i in range(len(X_u_train_batches)-1):
    u_train_batch, _ = pinn.predict(X_u_train_batches[i+1])
    u_train_pred = np.vstack((u_train_pred,u_train_batch))

  u_train_pred = u_train_pred.flatten()[:,None] 
  
  N_x = x.shape[0]
  N_t = t.shape[0]

  #X_plot = X_star.reshape(N_t,N_x,2).T
  u_plot = u_pred.reshape(N_t,N_x).T
  u_star_plot = u_star.reshape(N_t,N_x).T
  #X_test = X_plot[:,:,0]


  trained_weights = pinn.get_weights()

  return u_star_plot, u_plot, u_train_pred, trained_weights

# %%
#@title Training data plotter forward
def TrainingDataPlotterForward(X_u_train, X_f, ub, lb):

    fig = plt.figure()
    ax = fig.add_subplot()

    ax.scatter(X_f[:,1],X_f[:,0], s=4.0, marker='x')
    ax.scatter(X_u_train[:,1],X_u_train[:,0], s=4.0, marker='o', alpha=1.0)

    ax.set_xlabel('t')
    ax.set_ylabel('x')
    ax.set_xlim(lb[1]-0.1, ub[1]+0.1)
    ax.set_ylim(lb[0]-0.1, ub[0]+0.1)

    plt.show()

    print('Amount of training data: ' + str(X_u_train.shape[0] + X_f.shape[0]))

# %%
#@title Logger class
class Logger(object):
    def __init__(self, frequency=10):
        print("TensorFlow version: {}".format(tf.__version__))
        print("Eager execution: {}".format(tf.executing_eagerly()))
        print("GPU-accerelated: {}".format(tf.test.is_gpu_available()))

        self.start_time = time.time()
        self.frequency = frequency

    def __get_elapsed(self):
        return datetime.fromtimestamp(time.time() - self.start_time).strftime("%H:%M:%S")

    def __get_error_u(self):
        return self.error_fn()

    def set_error_fn(self, error_fn):
        self.error_fn = error_fn

    def log_train_start(self, model):
        print("\nTraining started")
        print("================")
        self.model = model
        print(self.model.summary())
    
    def log_train_epoch(self, epoch, loss, current_best_loss, custom=""):
        if epoch % self.frequency == 0:
            print(f"{'tf_epoch'} = {epoch:6d}  elapsed = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)

    def log_train_opt(self, name):
        print(f"—— Starting {name} optimization ——")

    def log_train_end(self, epoch, loss, current_best_loss, custom=""):
        print("==================")
        print(f"Training finished (epoch {epoch}): duration = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)
        print('Applying the weights at the best epoch to the model...')
        return self.__get_elapsed()

# %%
#@title Loss and parameter plotter
def LossParameterPlotterForward(loss_history):
    plt.figure(figsize=(18,6))
    plt.suptitle('Training Metrics')

    plt.ylabel("Loss", fontsize=14)
    plt.xlabel("Epoch", fontsize=14)
    plt.semilogy(loss_history)

    plt.show()

# %%
#@title PINN forward
class PhysicsInformedNN(object):
    def __init__(self, layers, optimizer, logger, ub, lb, f_param, u_param, activation_func=tf.keras.activations.tanh):
        # Descriptive Keras model [2, 20, …, 20, 1]
        self.u_model = tf.keras.Sequential()
        self.u_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.u_model.add(tf.keras.layers.Lambda(
          lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:]:
            self.u_model.add(tf.keras.layers.Dense(
              width, activation=activation_func,
              kernel_initializer='glorot_normal'))

        self.dtype = tf.float32
        self.loss_history = []
        self.f_param = f_param
        self.u_param = u_param
        self.current_best_loss = 1e10
        self.current_best_weights = []

        # Computing the sizes of weights/biases for future decomposition
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))
                

        self.optimizer = optimizer
        self.logger = logger

    # The actual PINN
    def __f_model(self, X_f):

        # Separating the collocation coordinates
        x_f = tf.convert_to_tensor(X_f[:, 0:1], dtype=self.dtype)
        t_f = tf.convert_to_tensor(X_f[:, 1:2], dtype=self.dtype)

        # Using the new GradientTape paradigm of TF2.0,
        # which keeps track of operations to get the gradient at runtime
        with tf.GradientTape(persistent=True) as tape:
            # Watching the two inputs we’ll need later, x and t
            tape.watch(x_f)
            tape.watch(t_f)
            # Packing together the inputs
            X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)

            # Getting the prediction
            u = self.u_model(X_f)
            # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
            u_x = tape.gradient(u, x_f)

        # Getting the other derivatives
        u_xx = tape.gradient(u_x, x_f)
        u_t = tape.gradient(u, t_f)

        # Letting the tape go
        del tape
        
        PDE = u_t + 1.0*u_x - (0.25/np.pi)*u_xx - 5.0*tf.exp(-100*(x_f+0.8)**2)
        # Buidling the PINNs
        return PDE

    # Defining custom loss
    def __loss(self, X_f, X_u, u, u_pred):
        f_pred = self.__f_model(X_f)
        return self.u_param*tf.reduce_mean(tf.square(u - u_pred)) + self.f_param*tf.reduce_mean(tf.square(f_pred)) # was 10, 0.1
    
    def __grad(self, X_f, X_u, u):
        with tf.GradientTape() as tape:
            loss_value = self.__loss(X_f, X_u, u, self.u_model(X_u))
        return loss_value, tape.gradient(loss_value, self.__wrap_training_variables())
    
    def __wrap_training_variables(self):
        var = self.u_model.trainable_variables
        return var

    def get_weights(self):
        w = []
        for layer in self.u_model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        return tf.convert_to_tensor(w, dtype=self.dtype)
    
    def set_weights(self, w):
        for i, layer in enumerate(self.u_model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)

    def summary(self):
        return self.u_model.summary()

    def mini_batch(self, X_f, X_u, u, batch_size):

        idx_u = np.random.randint(0, tf.shape(X_u).numpy()[0], batch_size)
        idx_f = np.random.randint(0, tf.shape(X_f).numpy()[0], batch_size)

        X_f_batch = tf.gather(X_f, idx_f)
        X_u_batch = tf.gather(X_u, idx_u)
        u_batch   = tf.gather(u, idx_u)

        return X_f_batch, X_u_batch, u_batch

    # The training function
    def fit(self, X_f, X_u, u, tf_epochs, batch_size=512):
        self.logger.log_train_start(self)
        
        # Creating the tensors
        X_u = tf.convert_to_tensor(X_u, dtype=self.dtype)
        X_f = tf.convert_to_tensor(X_f, dtype=self.dtype)
        u = tf.convert_to_tensor(u, dtype=self.dtype)

        iter_per_epoch = np.int(np.floor(tf.shape(X_f).numpy()[0]/batch_size))

        def log_train_epoch(epoch, loss):
            self.logger.log_train_epoch(epoch, loss, self.current_best_loss)
        self.logger.log_train_opt("Adam")

        for epoch in range(tf_epochs):
            for index in range(iter_per_epoch):

                X_f_batch, X_u_batch, u_batch = self.mini_batch(X_f, X_u, u, batch_size)

                # Optimization step
                loss_value, grads = self.__grad(X_f_batch, X_u_batch, u_batch)
                self.optimizer.apply_gradients(zip(grads, self.__wrap_training_variables()))

            loss_value, _ = self.__grad(X_f, X_u, u)

            if loss_value < self.current_best_loss:
              self.current_best_loss = loss_value
              self.current_best_weights = self.get_weights()

            log_train_epoch(epoch, loss_value)
            
            self.loss_history.append(loss_value.numpy())

        self.set_weights(self.current_best_weights)
        elapsed_time = self.logger.log_train_end(tf_epochs, loss_value, self.current_best_loss)
        return self.loss_history, elapsed_time
    
    def predict(self, X_star):
        u_star = self.u_model(X_star)
        f_star = self.__f_model(X_star)
        return u_star.numpy(), f_star.numpy()

# %%
#@title LBFGS v2
def dot(a, b):
  """Dot product function since TensorFlow doesn't have one."""
  return tf.reduce_sum(a*b)

def verbose_func(s):
  print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, state, maxIter = 100, learningRate = 1, do_verbose = True):
  """port of lbfgs.lua, using TensorFlow eager mode.
  """

  global final_loss, times
  
  maxEval = maxIter*1.25
  tolFun = 1e-5
  tolX = 1e-9
  nCorrection = 50
  isverbose = False

  # verbose function
  if isverbose:
    verbose = verbose_func
  else:
    verbose = lambda x: None
    
  f, g = opfunc(x)

  f_hist = [f]
  currentFuncEval = 1
  state.funcEval = state.funcEval + 1
  p = g.shape[0]

  # check optimality of initial point
  tmp1 = tf.abs(g)
  if tf.reduce_sum(tmp1) <= tolFun:
    verbose("optimality condition below tolFun")
    return x, f_hist

  # optimize for a max of maxIter iterations
  nIter = 0
  times = []
  while nIter < maxIter:
    start_time = time.time()
    
    # keep track of nb of iterations
    nIter = nIter + 1
    state.nIter = state.nIter + 1

    ############################################################
    ## compute gradient descent direction
    ############################################################
    if state.nIter == 1:
      d = -g
      old_dirs = []
      old_stps = []
      Hdiag = 1
    else:
      # do lbfgs update (update memory)
      y = g - g_old
      s = d*t
      ys = dot(y, s)
      
      if ys > 1e-10:
        # updating memory
        if len(old_dirs) == nCorrection:
          # shift history by one (limited-memory)
          del old_dirs[0]
          del old_stps[0]

        # store new direction/step
        old_dirs.append(s)
        old_stps.append(y)

        # update scale of initial Hessian approximation
        Hdiag = ys/dot(y, y)

      # compute the approximate (L-BFGS) inverse Hessian 
      # multiplied by the gradient
      k = len(old_dirs)

      # need to be accessed element-by-element, so don't re-type tensor:
      ro = [0]*nCorrection
      for i in range(k):
        ro[i] = 1/dot(old_stps[i], old_dirs[i])
        

      # iteration in L-BFGS loop collapsed to use just one buffer
      # need to be accessed element-by-element, so don't re-type tensor:
      al = [0]*nCorrection

      q = -g
      for i in range(k-1, -1, -1):
        al[i] = dot(old_dirs[i], q) * ro[i]
        q = q - al[i]*old_stps[i]

      # multiply by initial Hessian
      r = q*Hdiag
      for i in range(k):
        be_i = dot(old_stps[i], r) * ro[i]
        r += (al[i]-be_i)*old_dirs[i]
        
      d = r
      # final direction is in r/d (same object)

    g_old = g
    f_old = f
    
    ############################################################
    ## compute step length
    ############################################################
    # directional derivative
    gtd = dot(g, d)

    # check that progress can be made along that direction
    if gtd > -tolX:
      verbose("Can not make progress along direction.")
      break

    # reset initial guess for step size
    if state.nIter == 1:
      tmp1 = tf.abs(g)
      t = min(1, 1/tf.reduce_sum(tmp1))
    else:
      t = learningRate



    x += t*d

    if nIter != maxIter:
    # re-evaluate function only if not in last iteration
    # the reason we do this: in a stochastic setting,
    # no use to re-evaluate that function here
      f, g = opfunc(x)

    lsFuncEval = 1
    f_hist.append(f)


    # update func eval
    currentFuncEval = currentFuncEval + lsFuncEval
    state.funcEval = state.funcEval + lsFuncEval

    ############################################################
    ## check conditions
    ############################################################
    if nIter == maxIter:
      break

    if currentFuncEval >= maxEval:
      # max nb of function evals
      print('max nb of function evals')
      break

    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <=tolFun:
      # check optimality
      print('optimality condition below tolFun')
      break
    
    tmp1 = tf.abs(d*t)
    if tf.reduce_sum(tmp1) <= tolX:
      # step size below tolX
      print('step size below tolX')
      break
    
    if tf.abs(f,f_old) < tolX:
      # function value changing less than tolX
      print('function value changing less than tolX'+str(tf.abs(f-f_old)))
      break

    if do_verbose:
      if nIter % 10 == 0:
        print("Step %3d loss %6.5f "%(nIter, f.numpy()))


    if nIter == maxIter - 1:
      final_loss = f.numpy()


  # save state
  state.old_dirs = old_dirs
  state.old_stps = old_stps
  state.Hdiag = Hdiag
  state.g_old = g_old
  state.f_old = f_old
  state.t = t
  state.d = d

  return x, f_hist, currentFuncEval

# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
  pass

class Struct(dummy):
  def __getattribute__(self, key):
    if key == '__dict__':
      return super(dummy, self).__getattribute__('__dict__')
    return self.__dict__.get(key, 0)

# %%
#@title PINN forward w/ Adaptive weights (Adaptive Weighting disabled)
class PhysicsInformedNN(object):
    def __init__(self, layers, optimizer, logger, ub, lb, f_param, u_param, activation_func=tf.keras.activations.tanh):
        # Descriptive Keras model [2, 20, …, 20, 1]
        self.u_model = tf.keras.Sequential()
        self.u_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.u_model.add(tf.keras.layers.Lambda(
          lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:-1]:
            self.u_model.add(tf.keras.layers.Dense(
              width, activation=activation_func,
              kernel_initializer='glorot_normal'))
        self.u_model.add(tf.keras.layers.Dense(
              layers[-1], activation=None,
              kernel_initializer='glorot_normal'))

        self.dtype = tf.float32
        self.loss_history = []
        self.f_param = f_param
        self.u_param = u_param
        self.current_best_loss = 1e10
        self.current_best_weights = []

        # Computing the sizes of weights/biases for future decomposition
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))
                

        self.optimizer = optimizer
        self.logger = logger

        self.beta = 0.1 # Default 0.1
        self.adaptive_param = 1.0
        self.adaptive_param_hat = 1.0
        self.adaptive_param_history = []

    # The actual PINN
    def __f_model(self, X_f):

        # Separating the collocation coordinates
        x_f = tf.convert_to_tensor(X_f[:, 0:1], dtype=self.dtype)
        t_f = tf.convert_to_tensor(X_f[:, 1:2], dtype=self.dtype)

        # Using the new GradientTape paradigm of TF2.0,
        # which keeps track of operations to get the gradient at runtime
        with tf.GradientTape(persistent=True) as tape:
            # Watching the two inputs we’ll need later, x and t
            tape.watch(x_f)
            tape.watch(t_f)
            # Packing together the inputs
            X_f = tf.stack([x_f[:,0], t_f[:,0]], axis=1)

            # Getting the prediction
            u = self.u_model(X_f)
            # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
            u_x = tape.gradient(u, x_f)

        # Getting the other derivatives
        u_xx = tape.gradient(u_x, x_f)
        u_t = tape.gradient(u, t_f)

        # Letting the tape go
        del tape
        
        PDE = u_t + 1.0*u_x - (0.25/np.pi)*u_xx - 5.0*tf.exp(-100*(x_f+0.8)**2)
        # Buidling the PINNs
        return PDE

    def __loss(self, X_f, X_u, u, u_pred):
        f_pred = self.__f_model(X_f)
        loss_f = tf.reduce_mean(tf.square(f_pred))
        loss_u = tf.reduce_mean(tf.square(u - u_pred))
        return loss_u, loss_f
        
    def __grad(self, X_f, X_u, u):
        with tf.GradientTape() as tape:
            loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
            loss_value = self.adaptive_param*loss_u + 1.0*loss_f
        return loss_value, tape.gradient(loss_value, self.__wrap_training_variables())

    def __adaptive_param(self, X_f, X_u, u):
        with tf.GradientTape(persistent=True) as tape:
            loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
            grad_u = tape.gradient(self.adaptive_param*loss_u, self.__wrap_training_variables())
            grad_f = tape.gradient(loss_f, self.__wrap_training_variables())
        del tape

        grad_f_flatten = []
        grad_u_flatten = []
        for g in grad_f:
            grad_f_flatten.append(tf.reshape(g,[-1]))
        grad_f_flatten = tf.concat(grad_f_flatten,0)
        for g in grad_u:
            grad_u_flatten.append(tf.reshape(g,[-1]))
        grad_u_flatten = tf.concat(grad_u_flatten,0)        

        max_grad_f = tf.reduce_max(tf.abs(grad_f_flatten))
        mean_grad_u = tf.reduce_mean(tf.abs(grad_u_flatten))
        self.adaptive_param_hat = max_grad_f / mean_grad_u
        self.adaptive_param = self.adaptive_param * (1.0 - self.beta) + self.beta * self.adaptive_param_hat    # As implemented in paper
        self.adaptive_param_history.append(self.adaptive_param)
    
    def __wrap_training_variables(self):
        var = self.u_model.trainable_variables
        return var

    def get_loss_and_flat_grad(self, X_f, X_u, u):
        def loss_and_flat_grad(w):
            with tf.GradientTape() as tape:
                self.set_weights(w)
                loss_u, loss_f = self.__loss(X_f, X_u, u, self.u_model(X_u))
                loss_value = self.adaptive_param*loss_u + 1.0*loss_f
            grad = tape.gradient(loss_value, self.__wrap_training_variables())
            grad_flat = []
            for g in grad:
                grad_flat.append(tf.reshape(g, [-1]))
            grad_flat = tf.concat(grad_flat, 0)
            return loss_value, grad_flat
        return loss_and_flat_grad

    def get_weights(self):
        w = []
        for layer in self.u_model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        return tf.convert_to_tensor(w, dtype=self.dtype)
    
    def set_weights(self, w):
        for i, layer in enumerate(self.u_model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)

    def summary(self):
        return self.u_model.summary()

    def mini_batch(self, X_f, X_u, u, batch_size):

        idx_u = np.random.randint(0, tf.shape(X_u).numpy()[0], batch_size)
        idx_f = np.random.randint(0, tf.shape(X_f).numpy()[0], batch_size)

        X_f_batch = tf.gather(X_f, idx_f)
        X_u_batch = tf.gather(X_u, idx_u)
        u_batch   = tf.gather(u, idx_u)

        return X_f_batch, X_u_batch, u_batch

    # The training function
    def fit(self, X_f, X_u, u, tf_epochs, batch_size=512):
        self.logger.log_train_start(self)
        
        # Creating the tensors
        X_u = tf.convert_to_tensor(X_u, dtype=self.dtype)
        X_f = tf.convert_to_tensor(X_f, dtype=self.dtype)
        u = tf.convert_to_tensor(u, dtype=self.dtype)

        iter_per_epoch = np.int((np.floor(tf.shape(X_f).numpy()[0] + np.floor(tf.shape(X_u).numpy()[0]))/batch_size))

        def log_train_epoch(epoch, loss):
            custom = f"adaptive_param = {self.adaptive_param:4f}"
            self.logger.log_train_epoch(epoch, loss, self.current_best_loss, custom)
        self.logger.log_train_opt("Adam")

        for epoch in range(tf_epochs):
            for index in range(iter_per_epoch):

                X_f_batch, X_u_batch, u_batch = self.mini_batch(X_f, X_u, u, batch_size)
                
                #self.__adaptive_param(X_f_batch, X_u_batch, u_batch)

                # Optimization step
                loss_value, grads = self.__grad(X_f_batch, X_u_batch, u_batch)
                self.optimizer.apply_gradients(zip(grads, self.__wrap_training_variables()))

            loss_value, _ = self.__grad(X_f, X_u, u)

            if loss_value < self.current_best_loss:
              self.current_best_loss = loss_value
              self.current_best_weights = self.get_weights()

            log_train_epoch(epoch, loss_value)
            
            self.loss_history.append(loss_value.numpy())

        #l-bfgs-b optimization
        print("Starting L-BFGS training")

        loss_and_flat_grad = self.get_loss_and_flat_grad(X_f, X_u, u)

        lbfgs_weights, lbfgs_history, _ = lbfgs(loss_and_flat_grad, self.get_weights(), Struct(), maxIter=5000, learningRate=0.8)

        if lbfgs_history[-1] < self.current_best_loss:
            self.current_best_loss = lbfgs_history[-1]
            self.current_best_weights = lbfgs_weights
        
        for i in lbfgs_history:
            self.loss_history.append(i.numpy())

        self.set_weights(self.current_best_weights)
        elapsed_time = self.logger.log_train_end(tf_epochs, loss_value, self.current_best_loss)
        return self.loss_history, elapsed_time, self.adaptive_param_history
    
    def predict(self, X_star):
        u_star = self.u_model(X_star)
        f_star = self.__f_model(X_star)
        return u_star.numpy(), f_star.numpy()

# %%
#@title Error forward
def error():
    return 1.0

# %%
############### USER INPUT ##################


# Data size on the solution u
N_u = 400
# Collocation points size, where we’ll check for f = 0
N_f = 5000 
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Activation function
activation_func = tf.keras.activations.tanh #tf.keras.activations.swish

# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
tf_epochs = 10000  # Epochs w/ ADAM
tf_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 
batch_size = 5400 # Full batch = N_u + N_f

f_param = 1.0
u_param = 1.0

noise = 0.0

path = os.path.join("/content/drive/MyDrive/Colab Notebooks/Data/ADE_High_diffusion_with_source.mat")


x, t, X, T, X_star, u_star, X_u_train, u_train, X_f, ub, lb = prep_data(path, N_u, N_f, noise)

TrainingDataPlotterForward(X_u_train, X_f, ub, lb)
# Out:
# Amount of training data: 5400

# %%
# Creating the model and training
logger = Logger(frequency=1)
logger.set_error_fn(error)
pinn = PhysicsInformedNN(layers, tf_optimizer, logger, ub, lb, f_param, u_param, activation_func)
# Out:
# TensorFlow version: 2.6.0
# Eager execution: True
# GPU-accerelated: True

# %%
#loss_history, elapsed_time = pinn.fit(X_f, X_u_train, u_train, tf_epochs, batch_size)
loss_history, elapsed_time, adaptive_param_history = pinn.fit(X_f, X_u_train, u_train, tf_epochs, batch_size)
# Out:
# Streaming output truncated to the last 5000 lines.
# tf_epoch =   5222  elapsed = 00:09:04  loss = 4.5022e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5223  elapsed = 00:09:04  loss = 2.3519e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5224  elapsed = 00:09:04  loss = 9.1431e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5225  elapsed = 00:09:04  loss = 1.1215e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5226  elapsed = 00:09:04  loss = 1.7917e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5227  elapsed = 00:09:04  loss = 2.3492e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5228  elapsed = 00:09:05  loss = 3.5596e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5229  elapsed = 00:09:05  loss = 3.3437e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5230  elapsed = 00:09:05  loss = 2.7801e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5231  elapsed = 00:09:05  loss = 1.9069e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5232  elapsed = 00:09:05  loss = 9.8793e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5233  elapsed = 00:09:05  loss = 6.0835e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5234  elapsed = 00:09:05  loss = 8.6924e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5235  elapsed = 00:09:05  loss = 1.5134e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5236  elapsed = 00:09:05  loss = 1.4968e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5237  elapsed = 00:09:05  loss = 1.4007e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5238  elapsed = 00:09:06  loss = 7.6042e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5239  elapsed = 00:09:06  loss = 6.4253e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5240  elapsed = 00:09:06  loss = 8.7234e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5241  elapsed = 00:09:06  loss = 1.2943e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5242  elapsed = 00:09:06  loss = 1.5962e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5243  elapsed = 00:09:06  loss = 1.5683e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5244  elapsed = 00:09:06  loss = 1.1044e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5245  elapsed = 00:09:06  loss = 8.2708e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5246  elapsed = 00:09:06  loss = 5.4049e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5247  elapsed = 00:09:06  loss = 7.7406e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5248  elapsed = 00:09:07  loss = 8.4665e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5249  elapsed = 00:09:07  loss = 1.1398e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5250  elapsed = 00:09:07  loss = 1.1434e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5251  elapsed = 00:09:07  loss = 9.2903e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5252  elapsed = 00:09:07  loss = 6.2916e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5253  elapsed = 00:09:07  loss = 5.9180e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5254  elapsed = 00:09:07  loss = 7.8250e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5255  elapsed = 00:09:07  loss = 9.3432e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5256  elapsed = 00:09:07  loss = 1.1902e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5257  elapsed = 00:09:08  loss = 1.3306e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5258  elapsed = 00:09:08  loss = 1.3983e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5259  elapsed = 00:09:08  loss = 9.1326e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5260  elapsed = 00:09:08  loss = 6.7034e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5261  elapsed = 00:09:08  loss = 5.6172e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5262  elapsed = 00:09:08  loss = 6.8902e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5263  elapsed = 00:09:08  loss = 1.0198e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5264  elapsed = 00:09:08  loss = 1.3903e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5265  elapsed = 00:09:08  loss = 1.5658e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5266  elapsed = 00:09:09  loss = 1.4565e-03  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5267  elapsed = 00:09:09  loss = 8.0544e-04  best loss = 5.3403e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5268  elapsed = 00:09:09  loss = 5.1815e-04  best loss = 5.1815e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5269  elapsed = 00:09:09  loss = 8.2591e-04  best loss = 5.1815e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5270  elapsed = 00:09:09  loss = 1.2256e-03  best loss = 5.1815e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5271  elapsed = 00:09:09  loss = 1.2406e-03  best loss = 5.1815e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5272  elapsed = 00:09:09  loss = 1.1403e-03  best loss = 5.1815e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5273  elapsed = 00:09:09  loss = 7.1762e-04  best loss = 5.1815e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5274  elapsed = 00:09:10  loss = 5.1781e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5275  elapsed = 00:09:10  loss = 6.8496e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5276  elapsed = 00:09:10  loss = 8.8479e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5277  elapsed = 00:09:10  loss = 8.9379e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5278  elapsed = 00:09:10  loss = 6.6301e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5279  elapsed = 00:09:10  loss = 5.3839e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5280  elapsed = 00:09:10  loss = 5.8838e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5281  elapsed = 00:09:10  loss = 6.6188e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5282  elapsed = 00:09:10  loss = 7.3729e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5283  elapsed = 00:09:10  loss = 8.1298e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5284  elapsed = 00:09:11  loss = 7.6679e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5285  elapsed = 00:09:11  loss = 7.0250e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5286  elapsed = 00:09:11  loss = 6.0771e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5287  elapsed = 00:09:11  loss = 5.3174e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5288  elapsed = 00:09:11  loss = 5.5229e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5289  elapsed = 00:09:11  loss = 5.5196e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5290  elapsed = 00:09:11  loss = 6.2860e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5291  elapsed = 00:09:11  loss = 6.5400e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5292  elapsed = 00:09:11  loss = 6.5437e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5293  elapsed = 00:09:11  loss = 5.6798e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5294  elapsed = 00:09:12  loss = 5.2983e-04  best loss = 5.1781e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5295  elapsed = 00:09:12  loss = 5.1436e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5296  elapsed = 00:09:12  loss = 5.1640e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5297  elapsed = 00:09:12  loss = 5.4739e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5298  elapsed = 00:09:12  loss = 5.5347e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5299  elapsed = 00:09:12  loss = 5.2568e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5300  elapsed = 00:09:12  loss = 5.2005e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5301  elapsed = 00:09:12  loss = 5.5873e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5302  elapsed = 00:09:12  loss = 5.2675e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5303  elapsed = 00:09:13  loss = 5.2321e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5304  elapsed = 00:09:13  loss = 5.1770e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5305  elapsed = 00:09:13  loss = 5.3032e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5306  elapsed = 00:09:13  loss = 5.1930e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5307  elapsed = 00:09:13  loss = 5.1438e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5308  elapsed = 00:09:13  loss = 5.2338e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5309  elapsed = 00:09:13  loss = 5.7427e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5310  elapsed = 00:09:13  loss = 5.2374e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5311  elapsed = 00:09:13  loss = 5.4147e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5312  elapsed = 00:09:13  loss = 5.6375e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5313  elapsed = 00:09:14  loss = 5.9422e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5314  elapsed = 00:09:14  loss = 5.4368e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5315  elapsed = 00:09:14  loss = 5.4697e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5316  elapsed = 00:09:14  loss = 5.6365e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5317  elapsed = 00:09:14  loss = 5.7811e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5318  elapsed = 00:09:14  loss = 5.4516e-04  best loss = 5.1436e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5319  elapsed = 00:09:14  loss = 5.0524e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5320  elapsed = 00:09:14  loss = 5.5282e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5321  elapsed = 00:09:14  loss = 5.6488e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5322  elapsed = 00:09:14  loss = 5.6094e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5323  elapsed = 00:09:15  loss = 5.5272e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5324  elapsed = 00:09:15  loss = 5.9036e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5325  elapsed = 00:09:15  loss = 5.3111e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5326  elapsed = 00:09:15  loss = 5.5161e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5327  elapsed = 00:09:15  loss = 5.3028e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5328  elapsed = 00:09:15  loss = 5.1974e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5329  elapsed = 00:09:15  loss = 5.3481e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5330  elapsed = 00:09:15  loss = 5.8678e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5331  elapsed = 00:09:15  loss = 5.8066e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5332  elapsed = 00:09:15  loss = 5.9016e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5333  elapsed = 00:09:16  loss = 5.8714e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5334  elapsed = 00:09:16  loss = 5.6682e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5335  elapsed = 00:09:16  loss = 5.5975e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5336  elapsed = 00:09:16  loss = 5.2588e-04  best loss = 5.0524e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5337  elapsed = 00:09:16  loss = 5.0501e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5338  elapsed = 00:09:16  loss = 5.2296e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5339  elapsed = 00:09:16  loss = 5.4136e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5340  elapsed = 00:09:16  loss = 5.4404e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5341  elapsed = 00:09:16  loss = 5.5437e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5342  elapsed = 00:09:17  loss = 5.5583e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5343  elapsed = 00:09:17  loss = 6.2063e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5344  elapsed = 00:09:17  loss = 6.0812e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5345  elapsed = 00:09:17  loss = 5.5409e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5346  elapsed = 00:09:17  loss = 5.8101e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5347  elapsed = 00:09:17  loss = 5.9286e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5348  elapsed = 00:09:17  loss = 5.5058e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5349  elapsed = 00:09:17  loss = 5.3531e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5350  elapsed = 00:09:17  loss = 5.3471e-04  best loss = 5.0501e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5351  elapsed = 00:09:17  loss = 5.0426e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5352  elapsed = 00:09:18  loss = 5.0846e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5353  elapsed = 00:09:18  loss = 5.2248e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5354  elapsed = 00:09:18  loss = 5.4045e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5355  elapsed = 00:09:18  loss = 5.6277e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5356  elapsed = 00:09:18  loss = 6.0762e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5357  elapsed = 00:09:18  loss = 7.0359e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5358  elapsed = 00:09:18  loss = 7.8132e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5359  elapsed = 00:09:18  loss = 7.2342e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5360  elapsed = 00:09:18  loss = 6.2940e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5361  elapsed = 00:09:18  loss = 5.3892e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5362  elapsed = 00:09:19  loss = 5.0773e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5363  elapsed = 00:09:19  loss = 5.1574e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5364  elapsed = 00:09:19  loss = 5.4664e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5365  elapsed = 00:09:19  loss = 6.1911e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5366  elapsed = 00:09:19  loss = 6.5502e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5367  elapsed = 00:09:19  loss = 6.8295e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5368  elapsed = 00:09:19  loss = 7.7494e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5369  elapsed = 00:09:19  loss = 7.6982e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5370  elapsed = 00:09:19  loss = 7.2798e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5371  elapsed = 00:09:19  loss = 6.9748e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5372  elapsed = 00:09:20  loss = 6.3666e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5373  elapsed = 00:09:20  loss = 6.4671e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5374  elapsed = 00:09:20  loss = 6.3310e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5375  elapsed = 00:09:20  loss = 6.0189e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5376  elapsed = 00:09:20  loss = 5.7455e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5377  elapsed = 00:09:20  loss = 5.3504e-04  best loss = 5.0426e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5378  elapsed = 00:09:20  loss = 5.0143e-04  best loss = 5.0143e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5379  elapsed = 00:09:20  loss = 5.0803e-04  best loss = 5.0143e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5380  elapsed = 00:09:20  loss = 5.0014e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5381  elapsed = 00:09:21  loss = 5.2027e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5382  elapsed = 00:09:21  loss = 6.2046e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5383  elapsed = 00:09:21  loss = 7.5105e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5384  elapsed = 00:09:21  loss = 8.4891e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5385  elapsed = 00:09:21  loss = 1.0528e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5386  elapsed = 00:09:21  loss = 1.2915e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5387  elapsed = 00:09:21  loss = 1.5728e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5388  elapsed = 00:09:21  loss = 1.3867e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5389  elapsed = 00:09:21  loss = 1.7149e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5390  elapsed = 00:09:22  loss = 2.7400e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5391  elapsed = 00:09:22  loss = 4.0400e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5392  elapsed = 00:09:22  loss = 3.5728e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5393  elapsed = 00:09:22  loss = 2.7392e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5394  elapsed = 00:09:22  loss = 2.5420e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5395  elapsed = 00:09:22  loss = 1.5767e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5396  elapsed = 00:09:22  loss = 1.0418e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5397  elapsed = 00:09:22  loss = 5.2897e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5398  elapsed = 00:09:22  loss = 6.2063e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5399  elapsed = 00:09:23  loss = 8.4859e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5400  elapsed = 00:09:23  loss = 1.4330e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5401  elapsed = 00:09:23  loss = 1.2535e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5402  elapsed = 00:09:23  loss = 1.6186e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5403  elapsed = 00:09:23  loss = 1.6215e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5404  elapsed = 00:09:23  loss = 1.6627e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5405  elapsed = 00:09:23  loss = 1.1167e-03  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5406  elapsed = 00:09:23  loss = 8.0469e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5407  elapsed = 00:09:23  loss = 5.3737e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5408  elapsed = 00:09:24  loss = 5.0053e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5409  elapsed = 00:09:24  loss = 5.9182e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5410  elapsed = 00:09:24  loss = 7.8683e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5411  elapsed = 00:09:24  loss = 9.3705e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5412  elapsed = 00:09:24  loss = 8.6319e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5413  elapsed = 00:09:24  loss = 7.6426e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5414  elapsed = 00:09:24  loss = 7.2067e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5415  elapsed = 00:09:24  loss = 6.5374e-04  best loss = 5.0014e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5416  elapsed = 00:09:24  loss = 4.9460e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5417  elapsed = 00:09:25  loss = 5.3177e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5418  elapsed = 00:09:25  loss = 5.9740e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5419  elapsed = 00:09:25  loss = 7.2835e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5420  elapsed = 00:09:25  loss = 7.5160e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5421  elapsed = 00:09:25  loss = 1.0352e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5422  elapsed = 00:09:25  loss = 1.3052e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5423  elapsed = 00:09:25  loss = 1.6941e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5424  elapsed = 00:09:25  loss = 1.3613e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5425  elapsed = 00:09:25  loss = 1.0187e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5426  elapsed = 00:09:26  loss = 5.7511e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5427  elapsed = 00:09:26  loss = 5.6749e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5428  elapsed = 00:09:26  loss = 9.3730e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5429  elapsed = 00:09:26  loss = 1.3691e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5430  elapsed = 00:09:26  loss = 2.4069e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5431  elapsed = 00:09:26  loss = 1.7420e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5432  elapsed = 00:09:26  loss = 1.0912e-03  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5433  elapsed = 00:09:26  loss = 6.9709e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5434  elapsed = 00:09:26  loss = 5.4006e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5435  elapsed = 00:09:26  loss = 7.1837e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5436  elapsed = 00:09:26  loss = 8.0968e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5437  elapsed = 00:09:27  loss = 7.3745e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5438  elapsed = 00:09:27  loss = 6.2336e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5439  elapsed = 00:09:27  loss = 5.6309e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5440  elapsed = 00:09:27  loss = 5.1494e-04  best loss = 4.9460e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5441  elapsed = 00:09:27  loss = 4.8722e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5442  elapsed = 00:09:27  loss = 5.2065e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5443  elapsed = 00:09:27  loss = 5.2931e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5444  elapsed = 00:09:27  loss = 5.6782e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5445  elapsed = 00:09:27  loss = 5.2326e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5446  elapsed = 00:09:28  loss = 4.8946e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5447  elapsed = 00:09:28  loss = 4.8858e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5448  elapsed = 00:09:28  loss = 5.3582e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5449  elapsed = 00:09:28  loss = 5.6349e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5450  elapsed = 00:09:28  loss = 6.3642e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5451  elapsed = 00:09:28  loss = 7.0624e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5452  elapsed = 00:09:28  loss = 7.8846e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5453  elapsed = 00:09:28  loss = 7.5664e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5454  elapsed = 00:09:28  loss = 6.9390e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5455  elapsed = 00:09:28  loss = 7.0945e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5456  elapsed = 00:09:29  loss = 7.6358e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5457  elapsed = 00:09:29  loss = 6.7484e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5458  elapsed = 00:09:29  loss = 5.3147e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5459  elapsed = 00:09:29  loss = 4.9603e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5460  elapsed = 00:09:29  loss = 6.5400e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5461  elapsed = 00:09:29  loss = 1.0365e-03  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5462  elapsed = 00:09:29  loss = 1.3891e-03  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5463  elapsed = 00:09:29  loss = 1.3329e-03  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5464  elapsed = 00:09:29  loss = 1.0911e-03  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5465  elapsed = 00:09:29  loss = 9.9197e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5466  elapsed = 00:09:29  loss = 8.4750e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5467  elapsed = 00:09:30  loss = 6.3158e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5468  elapsed = 00:09:30  loss = 5.2002e-04  best loss = 4.8722e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5469  elapsed = 00:09:30  loss = 4.8462e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5470  elapsed = 00:09:30  loss = 4.9564e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5471  elapsed = 00:09:30  loss = 5.8261e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5472  elapsed = 00:09:30  loss = 7.0988e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5473  elapsed = 00:09:30  loss = 1.0537e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5474  elapsed = 00:09:30  loss = 1.3667e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5475  elapsed = 00:09:30  loss = 1.2460e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5476  elapsed = 00:09:30  loss = 7.5454e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5477  elapsed = 00:09:31  loss = 4.9845e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5478  elapsed = 00:09:31  loss = 5.6767e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5479  elapsed = 00:09:31  loss = 8.0905e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5480  elapsed = 00:09:31  loss = 1.0406e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5481  elapsed = 00:09:31  loss = 1.7727e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5482  elapsed = 00:09:31  loss = 2.0831e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5483  elapsed = 00:09:31  loss = 1.8505e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5484  elapsed = 00:09:31  loss = 1.4059e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5485  elapsed = 00:09:31  loss = 8.0558e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5486  elapsed = 00:09:31  loss = 4.9369e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5487  elapsed = 00:09:32  loss = 6.8564e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5488  elapsed = 00:09:32  loss = 9.7005e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5489  elapsed = 00:09:32  loss = 1.0637e-03  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5490  elapsed = 00:09:32  loss = 7.4312e-04  best loss = 4.8462e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5491  elapsed = 00:09:32  loss = 4.8151e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5492  elapsed = 00:09:32  loss = 5.6455e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5493  elapsed = 00:09:32  loss = 8.8319e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5494  elapsed = 00:09:32  loss = 1.2451e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5495  elapsed = 00:09:32  loss = 1.6951e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5496  elapsed = 00:09:32  loss = 1.6872e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5497  elapsed = 00:09:33  loss = 1.9050e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5498  elapsed = 00:09:33  loss = 2.3000e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5499  elapsed = 00:09:33  loss = 1.8131e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5500  elapsed = 00:09:33  loss = 1.1688e-03  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5501  elapsed = 00:09:33  loss = 6.8120e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5502  elapsed = 00:09:33  loss = 6.1804e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5503  elapsed = 00:09:33  loss = 7.5235e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5504  elapsed = 00:09:33  loss = 7.3271e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5505  elapsed = 00:09:33  loss = 7.9117e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5506  elapsed = 00:09:33  loss = 7.5476e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5507  elapsed = 00:09:33  loss = 6.2556e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5508  elapsed = 00:09:34  loss = 5.6497e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5509  elapsed = 00:09:34  loss = 5.3149e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5510  elapsed = 00:09:34  loss = 7.4115e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5511  elapsed = 00:09:34  loss = 8.8031e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5512  elapsed = 00:09:34  loss = 6.7078e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5513  elapsed = 00:09:34  loss = 5.9972e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5514  elapsed = 00:09:34  loss = 7.3912e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5515  elapsed = 00:09:34  loss = 6.9194e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5516  elapsed = 00:09:34  loss = 8.4001e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5517  elapsed = 00:09:35  loss = 8.6522e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5518  elapsed = 00:09:35  loss = 8.4921e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5519  elapsed = 00:09:35  loss = 6.0839e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5520  elapsed = 00:09:35  loss = 5.1758e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5521  elapsed = 00:09:35  loss = 6.8566e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5522  elapsed = 00:09:35  loss = 6.5668e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5523  elapsed = 00:09:35  loss = 6.0190e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5524  elapsed = 00:09:35  loss = 5.6393e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5525  elapsed = 00:09:35  loss = 5.8911e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5526  elapsed = 00:09:36  loss = 5.6089e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5527  elapsed = 00:09:36  loss = 5.1110e-04  best loss = 4.8151e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5528  elapsed = 00:09:36  loss = 4.7586e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5529  elapsed = 00:09:36  loss = 5.3004e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5530  elapsed = 00:09:36  loss = 5.0885e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5531  elapsed = 00:09:36  loss = 4.9789e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5532  elapsed = 00:09:36  loss = 5.1640e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5533  elapsed = 00:09:36  loss = 5.6349e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5534  elapsed = 00:09:36  loss = 5.1666e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5535  elapsed = 00:09:36  loss = 5.3353e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5536  elapsed = 00:09:37  loss = 6.1402e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5537  elapsed = 00:09:37  loss = 7.3977e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5538  elapsed = 00:09:37  loss = 9.6609e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5539  elapsed = 00:09:37  loss = 1.2619e-03  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5540  elapsed = 00:09:37  loss = 1.2312e-03  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5541  elapsed = 00:09:37  loss = 9.8230e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5542  elapsed = 00:09:37  loss = 7.1016e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5543  elapsed = 00:09:37  loss = 5.5757e-04  best loss = 4.7586e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5544  elapsed = 00:09:37  loss = 4.5755e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5545  elapsed = 00:09:37  loss = 4.9366e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5546  elapsed = 00:09:38  loss = 6.0073e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5547  elapsed = 00:09:38  loss = 6.6415e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5548  elapsed = 00:09:38  loss = 5.9857e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5549  elapsed = 00:09:38  loss = 5.3704e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5550  elapsed = 00:09:38  loss = 4.8947e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5551  elapsed = 00:09:38  loss = 4.9154e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5552  elapsed = 00:09:38  loss = 4.7940e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5553  elapsed = 00:09:38  loss = 5.3140e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5554  elapsed = 00:09:38  loss = 6.4849e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5555  elapsed = 00:09:38  loss = 7.4119e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5556  elapsed = 00:09:39  loss = 6.5354e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5557  elapsed = 00:09:39  loss = 5.7958e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5558  elapsed = 00:09:39  loss = 5.6859e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5559  elapsed = 00:09:39  loss = 5.3348e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5560  elapsed = 00:09:39  loss = 5.4693e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5561  elapsed = 00:09:39  loss = 7.1858e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5562  elapsed = 00:09:39  loss = 6.2116e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5563  elapsed = 00:09:39  loss = 5.7640e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5564  elapsed = 00:09:39  loss = 5.2294e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5565  elapsed = 00:09:40  loss = 5.6928e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5566  elapsed = 00:09:40  loss = 5.0952e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5567  elapsed = 00:09:40  loss = 6.5630e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5568  elapsed = 00:09:40  loss = 8.7719e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5569  elapsed = 00:09:40  loss = 1.0534e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5570  elapsed = 00:09:40  loss = 9.3256e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5571  elapsed = 00:09:40  loss = 9.9284e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5572  elapsed = 00:09:40  loss = 8.6666e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5573  elapsed = 00:09:40  loss = 5.7423e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5574  elapsed = 00:09:41  loss = 4.9609e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5575  elapsed = 00:09:41  loss = 8.5140e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5576  elapsed = 00:09:41  loss = 1.2912e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5577  elapsed = 00:09:41  loss = 1.7725e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5578  elapsed = 00:09:41  loss = 1.5387e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5579  elapsed = 00:09:41  loss = 7.7986e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5580  elapsed = 00:09:41  loss = 5.8472e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5581  elapsed = 00:09:41  loss = 8.0155e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5582  elapsed = 00:09:41  loss = 1.4489e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5583  elapsed = 00:09:42  loss = 1.8454e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5584  elapsed = 00:09:42  loss = 1.5076e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5585  elapsed = 00:09:42  loss = 1.1289e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5586  elapsed = 00:09:42  loss = 1.0997e-03  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5587  elapsed = 00:09:42  loss = 7.8249e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5588  elapsed = 00:09:42  loss = 5.6396e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5589  elapsed = 00:09:42  loss = 4.9317e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5590  elapsed = 00:09:42  loss = 6.7589e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5591  elapsed = 00:09:42  loss = 6.5580e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5592  elapsed = 00:09:43  loss = 6.1554e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5593  elapsed = 00:09:43  loss = 5.8331e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5594  elapsed = 00:09:43  loss = 8.0051e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   5595  elapsed = 00:09:43  loss = 8.2764e-04  best loss = 4.5755e-04  error = 1.0000e+00  adaptive_param = 1.000000
# ...
# tf_epoch =   9917  elapsed = 00:17:13  loss = 1.6087e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9918  elapsed = 00:17:13  loss = 1.6386e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9919  elapsed = 00:17:13  loss = 1.6995e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9920  elapsed = 00:17:13  loss = 1.7305e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9921  elapsed = 00:17:13  loss = 1.7850e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9922  elapsed = 00:17:13  loss = 1.8760e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9923  elapsed = 00:17:14  loss = 2.1207e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9924  elapsed = 00:17:14  loss = 2.2663e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9925  elapsed = 00:17:14  loss = 2.8319e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9926  elapsed = 00:17:14  loss = 3.1812e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9927  elapsed = 00:17:14  loss = 2.5722e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9928  elapsed = 00:17:14  loss = 2.1758e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9929  elapsed = 00:17:14  loss = 2.0671e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9930  elapsed = 00:17:14  loss = 1.8990e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9931  elapsed = 00:17:14  loss = 1.7822e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9932  elapsed = 00:17:15  loss = 1.6695e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9933  elapsed = 00:17:15  loss = 1.7005e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9934  elapsed = 00:17:15  loss = 1.8778e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9935  elapsed = 00:17:15  loss = 2.0270e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9936  elapsed = 00:17:15  loss = 2.1817e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9937  elapsed = 00:17:15  loss = 2.2121e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9938  elapsed = 00:17:15  loss = 2.7381e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9939  elapsed = 00:17:15  loss = 3.3792e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9940  elapsed = 00:17:15  loss = 3.1552e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9941  elapsed = 00:17:16  loss = 3.2618e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9942  elapsed = 00:17:16  loss = 2.5947e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9943  elapsed = 00:17:16  loss = 2.7169e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9944  elapsed = 00:17:16  loss = 2.2350e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9945  elapsed = 00:17:16  loss = 1.8194e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9946  elapsed = 00:17:16  loss = 1.6749e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9947  elapsed = 00:17:16  loss = 2.0251e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9948  elapsed = 00:17:16  loss = 1.9882e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9949  elapsed = 00:17:17  loss = 1.8942e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9950  elapsed = 00:17:17  loss = 2.2572e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9951  elapsed = 00:17:17  loss = 2.2331e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9952  elapsed = 00:17:17  loss = 2.1077e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9953  elapsed = 00:17:17  loss = 1.7862e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9954  elapsed = 00:17:17  loss = 1.7223e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9955  elapsed = 00:17:17  loss = 1.7217e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9956  elapsed = 00:17:17  loss = 1.6216e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9957  elapsed = 00:17:17  loss = 1.6212e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9958  elapsed = 00:17:18  loss = 1.7936e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9959  elapsed = 00:17:18  loss = 1.8854e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9960  elapsed = 00:17:18  loss = 1.7660e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9961  elapsed = 00:17:18  loss = 1.7332e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9962  elapsed = 00:17:18  loss = 1.7644e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9963  elapsed = 00:17:18  loss = 1.7798e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9964  elapsed = 00:17:18  loss = 1.7306e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9965  elapsed = 00:17:18  loss = 1.7235e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9966  elapsed = 00:17:18  loss = 1.7696e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9967  elapsed = 00:17:18  loss = 1.8682e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9968  elapsed = 00:17:19  loss = 1.9848e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9969  elapsed = 00:17:19  loss = 1.9952e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9970  elapsed = 00:17:19  loss = 1.9143e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9971  elapsed = 00:17:19  loss = 1.8493e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9972  elapsed = 00:17:19  loss = 1.7711e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9973  elapsed = 00:17:19  loss = 1.7620e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9974  elapsed = 00:17:19  loss = 1.6692e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9975  elapsed = 00:17:19  loss = 1.6947e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9976  elapsed = 00:17:19  loss = 1.6992e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9977  elapsed = 00:17:19  loss = 1.7927e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9978  elapsed = 00:17:20  loss = 1.7498e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9979  elapsed = 00:17:20  loss = 1.8082e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9980  elapsed = 00:17:20  loss = 2.3201e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9981  elapsed = 00:17:20  loss = 2.6603e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9982  elapsed = 00:17:20  loss = 3.2972e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9983  elapsed = 00:17:20  loss = 4.7282e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9984  elapsed = 00:17:20  loss = 7.5330e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9985  elapsed = 00:17:20  loss = 1.1873e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9986  elapsed = 00:17:20  loss = 1.2953e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9987  elapsed = 00:17:20  loss = 1.7430e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9988  elapsed = 00:17:21  loss = 1.8358e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9989  elapsed = 00:17:21  loss = 2.0091e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9990  elapsed = 00:17:21  loss = 2.5535e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9991  elapsed = 00:17:21  loss = 4.3031e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9992  elapsed = 00:17:21  loss = 7.3675e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9993  elapsed = 00:17:21  loss = 8.6072e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9994  elapsed = 00:17:21  loss = 5.6132e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9995  elapsed = 00:17:21  loss = 3.1556e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9996  elapsed = 00:17:21  loss = 1.2688e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9997  elapsed = 00:17:22  loss = 4.2269e-04  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9998  elapsed = 00:17:22  loss = 1.7207e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# tf_epoch =   9999  elapsed = 00:17:22  loss = 4.1593e-03  best loss = 1.6010e-04  error = 1.0000e+00  adaptive_param = 1.000000
# Starting L-BFGS training
# Step  10 loss 0.00019
# Step  20 loss 0.00016
# Step  30 loss 0.00015
# Step  40 loss 0.00015
# Step  50 loss 0.00015
# Step  60 loss 0.00015
# Step  70 loss 0.00014
# Step  80 loss 0.00013
# Step  90 loss 0.00012
# Step 100 loss 0.00011
# Step 110 loss 0.00011
# Step 120 loss 0.00010
# Step 130 loss 0.00010
# Step 140 loss 0.00010
# Step 150 loss 0.00009
# Step 160 loss 0.00008
# Step 170 loss 0.00008
# Step 180 loss 0.00008
# Step 190 loss 0.00008
# Step 200 loss 0.00008
# Step 210 loss 0.00007
# Step 220 loss 0.00007
# Step 230 loss 0.00007
# Step 240 loss 0.00007
# Step 250 loss 0.00007
# Step 260 loss 0.00006
# Step 270 loss 0.00006
# Step 280 loss 0.00006
# Step 290 loss 0.00006
# Step 300 loss 0.00006
# Step 310 loss 0.00006
# Step 320 loss 0.00005
# Step 330 loss 0.00005
# Step 340 loss 0.00005
# Step 350 loss 0.00005
# Step 360 loss 0.00005
# Step 370 loss 0.00005
# Step 380 loss 0.00004
# Step 390 loss 0.00004
# Step 400 loss 0.00004
# Step 410 loss 0.00004
# Step 420 loss 0.00004
# Step 430 loss 0.00004
# Step 440 loss 0.00004
# Step 450 loss 0.00004
# Step 460 loss 0.00003
# Step 470 loss 0.00003
# Step 480 loss 0.00003
# Step 490 loss 0.00003
# Step 500 loss 0.00003
# Step 510 loss 0.00003
# Step 520 loss 0.00003
# Step 530 loss 0.00003
# Step 540 loss 0.00003
# Step 550 loss 0.00003
# Step 560 loss 0.00003
# Step 570 loss 0.00003
# Step 580 loss 0.00003
# Step 590 loss 0.00003
# Step 600 loss 0.00003
# Step 610 loss 0.00003
# Step 620 loss 0.00002
# Step 630 loss 0.00002
# Step 640 loss 0.00002
# Step 650 loss 0.00002
# Step 660 loss 0.00002
# Step 670 loss 0.00002
# Step 680 loss 0.00002
# Step 690 loss 0.00002
# Step 700 loss 0.00002
# Step 710 loss 0.00002
# Step 720 loss 0.00002
# Step 730 loss 0.00002
# Step 740 loss 0.00002
# Step 750 loss 0.00002
# Step 760 loss 0.00002
# Step 770 loss 0.00002
# Step 780 loss 0.00002
# Step 790 loss 0.00002
# Step 800 loss 0.00002
# Step 810 loss 0.00002
# Step 820 loss 0.00002
# Step 830 loss 0.00002
# Step 840 loss 0.00002
# Step 850 loss 0.00002
# Step 860 loss 0.00002
# Step 870 loss 0.00002
# Step 880 loss 0.00002
# Step 890 loss 0.00002
# Step 900 loss 0.00002
# Step 910 loss 0.00002
# Step 920 loss 0.00002
# Step 930 loss 0.00002
# Step 940 loss 0.00002
# Step 950 loss 0.00002
# Step 960 loss 0.00002
# Step 970 loss 0.00002
# Step 980 loss 0.00002
# Step 990 loss 0.00002
# Step 1000 loss 0.00002
# Step 1010 loss 0.00002
# Step 1020 loss 0.00001
# Step 1030 loss 0.00001
# Step 1040 loss 0.00001
# Step 1050 loss 0.00001
# Step 1060 loss 0.00001
# Step 1070 loss 0.00001
# Step 1080 loss 0.00001
# Step 1090 loss 0.00001
# Step 1100 loss 0.00001
# Step 1110 loss 0.00001
# Step 1120 loss 0.00001
# Step 1130 loss 0.00001
# Step 1140 loss 0.00001
# Step 1150 loss 0.00001
# Step 1160 loss 0.00001
# Step 1170 loss 0.00001
# Step 1180 loss 0.00001
# Step 1190 loss 0.00001
# Step 1200 loss 0.00001
# Step 1210 loss 0.00001
# Step 1220 loss 0.00001
# Step 1230 loss 0.00001
# Step 1240 loss 0.00001
# Step 1250 loss 0.00001
# Step 1260 loss 0.00001
# Step 1270 loss 0.00001
# Step 1280 loss 0.00001
# Step 1290 loss 0.00001
# Step 1300 loss 0.00001
# Step 1310 loss 0.00001
# Step 1320 loss 0.00001
# Step 1330 loss 0.00001
# Step 1340 loss 0.00001
# Step 1350 loss 0.00001
# Step 1360 loss 0.00001
# Step 1370 loss 0.00001
# Step 1380 loss 0.00001
# Step 1390 loss 0.00001
# Step 1400 loss 0.00001
# Step 1410 loss 0.00001
# Step 1420 loss 0.00001
# Step 1430 loss 0.00001
# Step 1440 loss 0.00001
# Step 1450 loss 0.00001
# Step 1460 loss 0.00001
# Step 1470 loss 0.00001
# Step 1480 loss 0.00001
# Step 1490 loss 0.00001
# Step 1500 loss 0.00001
# Step 1510 loss 0.00001
# Step 1520 loss 0.00001
# Step 1530 loss 0.00001
# Step 1540 loss 0.00001
# Step 1550 loss 0.00001
# Step 1560 loss 0.00001
# Step 1570 loss 0.00001
# Step 1580 loss 0.00001
# Step 1590 loss 0.00001
# Step 1600 loss 0.00001
# Step 1610 loss 0.00001
# Step 1620 loss 0.00001
# Step 1630 loss 0.00001
# Step 1640 loss 0.00001
# Step 1650 loss 0.00001
# Step 1660 loss 0.00001
# Step 1670 loss 0.00001
# Step 1680 loss 0.00001
# Step 1690 loss 0.00001
# Step 1700 loss 0.00001
# Step 1710 loss 0.00001
# Step 1720 loss 0.00001
# Step 1730 loss 0.00001
# Step 1740 loss 0.00001
# Step 1750 loss 0.00001
# Step 1760 loss 0.00001
# Step 1770 loss 0.00001
# Step 1780 loss 0.00001
# Step 1790 loss 0.00001
# Step 1800 loss 0.00001
# Step 1810 loss 0.00001
# Step 1820 loss 0.00001
# Step 1830 loss 0.00001
# Step 1840 loss 0.00001
# Step 1850 loss 0.00001
# Step 1860 loss 0.00001
# Step 1870 loss 0.00001
# Step 1880 loss 0.00001
# Step 1890 loss 0.00001
# Step 1900 loss 0.00001
# Step 1910 loss 0.00001
# Step 1920 loss 0.00001
# Step 1930 loss 0.00001
# Step 1940 loss 0.00001
# Step 1950 loss 0.00001
# Step 1960 loss 0.00001
# Step 1970 loss 0.00001
# Step 1980 loss 0.00001
# Step 1990 loss 0.00001
# Step 2000 loss 0.00001
# Step 2010 loss 0.00001
# Step 2020 loss 0.00001
# Step 2030 loss 0.00001
# Step 2040 loss 0.00001
# Step 2050 loss 0.00001
# Step 2060 loss 0.00001
# Step 2070 loss 0.00001
# Step 2080 loss 0.00001
# Step 2090 loss 0.00001
# Step 2100 loss 0.00001
# Step 2110 loss 0.00001
# Step 2120 loss 0.00001
# Step 2130 loss 0.00001
# Step 2140 loss 0.00001
# Step 2150 loss 0.00001
# Step 2160 loss 0.00001
# Step 2170 loss 0.00001
# Step 2180 loss 0.00001
# ==================
# Training finished (epoch 10000): duration = 00:20:34  loss = 4.1593e-03  best loss = 6.0601e-06  error = 1.0000e+00
# Applying the weights at the best epoch to the model...

# %%
LossParameterPlotterForward(loss_history)

# %%
u_star_plot, u_plot, u_train_pred, trained_weights = ExtractData(pinn, X_star, X_u_train, u_star)

# %%
DiscretePlotter(x,t,u_plot,u_star_plot,lb,ub)

# %%
savemat('PINNresults1DForwardFullbatchLBFGS.mat', {'u_pred': u_plot, 'u_true': u_star_plot, 'loss_history': loss_history,
                          'X_u_train': X_u_train, 'u_train': u_train, 'u_train_pred': u_train_pred, 'X': X, 'T': T, 'X_star': X_star,
                          'x': x, 't': t, 'X_f': X_f, 'layers': layers, 'noise': noise, 'u_param': u_param, 'f_param': f_param})
