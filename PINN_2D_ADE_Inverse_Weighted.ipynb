# %% [markdown]
# <a href="https://colab.research.google.com/github/KetilIversen/ADE-PINN-Masters-Thesis-Code/blob/main/PINN_2D_ADE_Inverse_Weighted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2D ADE Inverse

# %% [markdown]
# Install needed for latin hypercube sampling (lhs)

# %%
# !pip install pyDOE
# Out:
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.4.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=24f61b29d594ba3935f80d2154ea7588e528d2b80231fa5b0c9917df6bb2c453
#   Stored in directory: /root/.cache/pip/wheels/83/ce/8a/87b25c685bfeca1872d13b8dc101e087a9c6e3fb5ebb47022a
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %% [markdown]
# All necessary imports

# %%
#@title Imports
# Imports related to preprocessing of data and tensorflow
import sys
import os
import time
from datetime import datetime
import tensorflow as tf
import numpy as np
import scipy.io
import tensorflow_probability as tfp
from pyDOE import lhs

# Imports related to plotting
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.interpolate import griddata
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Imports related to animations
import matplotlib.animation
from IPython.display import HTML

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# %% [markdown]
# The following two functions are for loading the data and preprocessing. Either through sparse measurements or dense measurements.

# %%
#@title Load data function
def LoadData(path, N_u, N_m, noise, inc_bounds, prcnt, sparse, random_pos, timestep, method):

  if sparse==False:
    # Getting the data with random distribution
    x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb = prep_data_dense(path, N_u, noise, inc_bounds, prcnt)
    return x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb
  else:
    # Getting the data with sparse distribution
    x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb = prep_data_sparse_measurements(path, N_m, random_pos, timestep, inc_bounds, prcnt, method, noise)
    return x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb

# %%
#@title Data prep sparse
def prep_data_sparse_measurements(path, N_m, random_pos, timestep, inc_bounds, prcnt, method, noise):
    # Reading external data
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['timesteps'].flatten()[:,None] # T x 1
    y = data['y'].flatten()[:,None] # N x 1
    x = data['x'].flatten()[:,None] # N x 1

    Nx = x.shape[0]
    Ny = y.shape[0]
    Nt = t.shape[0]

    if random_pos:
      rnd_points = np.random.choice(Nx*Ny, N_m, replace=False)
    else:
      if method == 1:
        rnd_points = np.linspace(0,Nx*Ny, N_m, endpoint=False, dtype=np.dtype(int))
      if method == 2:
        step = np.floor(Nx*Ny/(N_m+1))
        rnd_points = np.linspace(step, Nx*Ny-step, N_m, dtype=np.dtype(int))
      if method ==3:
        rnd_points = np.linspace(0, Nx*Ny-1, N_m, dtype=np.dtype(int))
    
    for i in range(N_m):
      next_points = np.arange(rnd_points[i]*Nt, rnd_points[i]*Nt + Nt, timestep)
      if i == 0:
        sample_idx = next_points
      else:  
        sample_idx = np.append(sample_idx, next_points)

    # Keeping the 3D data for the solution data (real() is maybe to make it float by default, in case of zeroes)
    Exact_u = np.real(data['u']) # T x N x N

    # Meshing x and t in 3D (100,100,2000)
    X, Y, T = np.meshgrid(x,y,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array, as X_star
    X_star = np.hstack((X.flatten()[:,None], Y.flatten()[:,None], T.flatten()[:,None]))

    # Preparing the testing u_star
    u_star = np.swapaxes(Exact_u,0,1)
    u_star = u_star.flatten()[:,None] 

    X_u_train = X_star[sample_idx,:]
    u_train = u_star[sample_idx,:]

    # Noise       
    u_train = u_train + noise*np.std(u_train)*np.random.randn(u_train.shape[0], u_train.shape[1])
    u_star = u_star + noise*np.std(u_star)*np.random.randn(u_star.shape[0], u_star.shape[1])

    if inc_bounds == True:
      # Getting the initial conditions (t=0)
      xx1 = np.hstack((X[:,:,0:1].flatten()[:,None], Y[:,:,0:1].flatten()[:,None], T[:,:,0:1].flatten()[:,None]))
      uu1 = Exact_u[:,:,0:1].flatten()[:,None]
      # Getting the lowest boundary conditions (x=0) 
      xx2 = np.hstack((X[0:1,:,:].flatten()[:,None], Y[0:1,:,:].flatten()[:,None], T[0:1,:,:].flatten()[:,None]))
      uu2 = Exact_u[0:1,:,:].flatten()[:,None]
      # Getting the highest boundary conditions (x=1) 
      xx3 = np.hstack((X[-1:,:,:].flatten()[:,None], Y[-1:,:,:].flatten()[:,None], T[-1:,:,:].flatten()[:,None]))
      uu3 = Exact_u[-1:,:,:].flatten()[:,None]
      # Getting the lowest boundary conditions (y=0) 
      xx4 = np.hstack((X[:,0:1,:].flatten()[:,None], Y[:,0:1,:].flatten()[:,None], T[:,0:1,:].flatten()[:,None]))
      uu4 = Exact_u[:,0:1,:].flatten()[:,None]
      # Getting the highest boundary conditions (y=1) 
      xx5 = np.hstack((X[:,-1:,:].flatten()[:,None], Y[:,-1:,:].flatten()[:,None], T[:,-1:,:].flatten()[:,None]))
      uu5 = Exact_u[:,-1:,:].flatten()[:,None]
      # Selecting random boundary points
      X_u_bounds = np.vstack([xx1, xx2, xx3, xx4, xx5])
      u_bounds = np.vstack([uu1, uu2, uu3, uu4, uu5])
      size = X_u_bounds.shape[0]
      samples = np.int(np.floor(X_u_bounds.shape[0]*prcnt))
      rnd_bounds = np.random.choice(size, samples, replace=False)
      X_u_bounds = X_u_bounds[rnd_bounds,:]
      u_bounds = u_bounds[rnd_bounds,:]
      # Stacking them in multidimensional tensors for training
      X_u_train = np.vstack([X_u_train, X_u_bounds])
      u_train = np.vstack([u_train, u_bounds])

    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0) 
    return x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb

# %%
#@title Data prep dense
def prep_data_dense(path, N_u, noise, inc_bounds, prcnt):
    # Reading external data
    data = scipy.io.loadmat(path)

    # Flatten makes [[]] into [], [:,None] makes it a column vector
    t = data['timesteps'].flatten()[:,None] # T x 1
    y = data['y'].flatten()[:,None] # N x 1
    x = data['x'].flatten()[:,None] # N x 1
    

    # Keeping the 2D data for the solution data (real() is maybe to make it float by default, in case of zeroes)
    Exact_u = np.real(data['u']) # T x N x N

    # Meshing x and t in 2D (100,100,100)
    X, Y, T = np.meshgrid(x,y,t)

    # Preparing the inputs x and t (meshed as X, T) for predictions in one single array, as X_star
    X_star = np.hstack((X.flatten()[:,None], Y.flatten()[:,None], T.flatten()[:,None]))
    
    # Preparing the testing u_star
    u_star = np.swapaxes(Exact_u,0,1)
    u_star = u_star.flatten()[:,None]

  
    idx = np.random.choice(X_star.shape[0], N_u, replace=False)
    X_u_train = X_star[idx,:]
    u_train = u_star[idx,:]

    # Noise       
    u_train = u_train + noise*np.std(u_train)*np.random.randn(u_train.shape[0], u_train.shape[1])
    u_star = u_star + noise*np.std(u_star)*np.random.randn(u_star.shape[0], u_star.shape[1])
    
    if inc_bounds == True:
      # Getting the initial conditions (t=0)
      xx1 = np.hstack((X[:,:,0:1].flatten()[:,None], Y[:,:,0:1].flatten()[:,None], T[:,:,0:1].flatten()[:,None]))
      uu1 = Exact_u[:,:,0:1].flatten()[:,None]
      # Getting the lowest boundary conditions (x=0) 
      xx2 = np.hstack((X[0:1,:,:].flatten()[:,None], Y[0:1,:,:].flatten()[:,None], T[0:1,:,:].flatten()[:,None]))
      uu2 = Exact_u[0:1,:,:].flatten()[:,None]
      # Getting the highest boundary conditions (x=1) 
      xx3 = np.hstack((X[-1:,:,:].flatten()[:,None], Y[-1:,:,:].flatten()[:,None], T[-1:,:,:].flatten()[:,None]))
      uu3 = Exact_u[-1:,:,:].flatten()[:,None]
      # Getting the lowest boundary conditions (y=0) 
      xx4 = np.hstack((X[:,0:1,:].flatten()[:,None], Y[:,0:1,:].flatten()[:,None], T[:,0:1,:].flatten()[:,None]))
      uu4 = Exact_u[:,0:1,:].flatten()[:,None]
      # Getting the highest boundary conditions (y=1) 
      xx5 = np.hstack((X[:,-1:,:].flatten()[:,None], Y[:,-1:,:].flatten()[:,None], T[:,-1:,:].flatten()[:,None]))
      uu5 = Exact_u[:,-1:,:].flatten()[:,None]
      # Selecting random boundary points
      X_u_bounds = np.vstack([xx1, xx2, xx3, xx4, xx5])
      u_bounds = np.vstack([uu1, uu2, uu3, uu4, uu5])
      size = X_u_bounds.shape[0]
      samples = np.int(np.floor(X_u_bounds.shape[0]*prcnt))
      rnd_bounds = np.random.choice(size, samples, replace=False)
      X_u_bounds = X_u_bounds[rnd_bounds,:]
      u_bounds = u_bounds[rnd_bounds,:]
      # Stacking them in multidimensional tensors for training
      X_u_train = np.vstack([X_u_train, X_u_bounds])
      u_train = np.vstack([u_train, u_bounds])

    lb = X_star.min(axis=0)
    ub = X_star.max(axis=0) 
    return x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb

# %%
#@title Logger class
class Logger(object):
    def __init__(self, frequency=10):
        print("TensorFlow version: {}".format(tf.__version__))
        print("Eager execution: {}".format(tf.executing_eagerly()))
        print("GPU-accerelated: {}".format(tf.test.is_gpu_available()))

        self.start_time = time.time()
        self.frequency = frequency

    def __get_elapsed(self):
        return datetime.fromtimestamp(time.time() - self.start_time).strftime("%H:%M:%S")

    def __get_error_u(self):
        return self.error_fn()

    def set_error_fn(self, error_fn):
        self.error_fn = error_fn

    def log_train_start(self, model):
        print("\nTraining started")
        print("================")
        self.model = model
        print(self.model.summary())
    
    def log_train_epoch(self, epoch, loss, current_best_loss, custom=""):
        if epoch % self.frequency == 0:
            print(f"{'tf_epoch'} = {epoch:6d}  elapsed = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)

    def log_train_opt(self, name):
        print(f"—— Starting {name} optimization ——")

    def log_train_end(self, epoch, loss, current_best_loss, custom=""):
        print("==================")
        print(f"Training finished (epoch {epoch}): duration = {self.__get_elapsed()}  loss = {loss:.4e}  best loss = {current_best_loss:.4e}  error = {self.__get_error_u():.4e}  " + custom)
        print('Applying the weights at the best epoch to the model...')
        return self.__get_elapsed()

# %%
#@title Extract data from PINN
def ExtractData(pinn, X_star, X_u_train):

  # Getting the model predictions, over dense (x,y,t) domain
  X_star_batches = np.array_split(X_star,1000)
  u_pred, _ = pinn.predict(X_star_batches[0])
  for i in range(len(X_star_batches)-1):
    u_pred_batch, _ = pinn.predict(X_star_batches[i+1])
    u_pred = np.vstack((u_pred,u_pred_batch))

  # Getting the model prediction, over training (x,y,t)
  X_u_train_batches = np.array_split(X_u_train,1000)
  u_train_pred, _ = pinn.predict(X_u_train_batches[0])
  for i in range(len(X_u_train_batches)-1):
    u_train_batch, _ = pinn.predict(X_u_train_batches[i+1])
    u_train_pred = np.vstack((u_train_pred,u_train_batch))

  u_train_pred = u_train_pred.flatten()[:,None] 
  
  N_x = x.shape[0]
  N_y = y.shape[0]
  N_t = t.shape[0]

  X_plot = X_star.reshape(N_x,N_y,N_t,3)
  u_plot = u_pred.reshape(N_x,N_y,N_t)
  u_star_plot = u_star.reshape(N_x,N_y,N_t)
  X_test = X_plot[:,:,0,0]
  Y_test = X_plot[:,:,0,1]

  trained_weights = pinn.get_weights()
  pred_params = pinn.get_params(numpy=True)

  return X_test, Y_test, u_star_plot, u_plot, u_train_pred, trained_weights, pred_params

# %%
#@title Error function
def error():
    l1, l2, l3 = pinn.get_params(numpy=True)
    l1_star, l2_star, l3_star = lambdas_star
    error_lambda_1 = np.abs(l1 - l1_star) #/ l1_star
    error_lambda_2 = np.abs(l2 - l2_star) #/ l2_star
    return (error_lambda_1 + error_lambda_2) / 2

# %%
#@title Training data plotter
def TrainingDataPlotter(X_u_train, ub, lb):

    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    ax.scatter(X_u_train[:,0],X_u_train[:,1],X_u_train[:,2], marker='o')

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('t')

    plt.show()


    fig = plt.figure()
    ax = fig.add_subplot()

    ax.scatter(X_u_train[:,0],X_u_train[:,1], marker='o')

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_xlim(lb[0], ub[0])
    ax.set_ylim(lb[1], ub[1])

    plt.show()

    print('Amount of training data: ' + str(X_u_train.shape[0]))

# %%
#@title Discrete plotter
def DiscretePlotter(t,X_test,Y_test,u_plot,ub,zmax=0.3,zmin=0.0,cmap='rainbow'):

    def figsize(scale, nplots = 1):
        fig_width_pt = 390.0                          # Get this from LaTeX using \the\textwidth
        inches_per_pt = 1.0/72.27                       # Convert pt to inch
        golden_mean = (np.sqrt(5.0)-1.0)/2.0            # Aesthetic ratio (you could change this)
        fig_width = fig_width_pt*inches_per_pt*scale    # width in inches
        fig_height = nplots*fig_width*golden_mean              # height in inches
        fig_size = [fig_width,fig_height]
        return fig_size

    # I make my own newfig and savefig functions
    def newfig(width, nplots = 1):
        fig = plt.figure(figsize=figsize(width, nplots))
        ax = fig.add_subplot(111)
        return fig, ax

    N_t = t.shape[0]
    Lt = ub[2]
    t0 = 0; t1 = Lt/5; t2 = 2*Lt/5; t3 = 3*Lt/5; t4 = 4*Lt/5; t5 = 5*Lt/5;
    N0 = np.int(np.ceil((t0*N_t)/Lt))
    N1 = np.int(np.ceil((t1*N_t)/Lt))
    N2 = np.int(np.ceil((t2*N_t)/Lt))
    N3 = np.int(np.ceil((t3*N_t)/Lt))
    N4 = np.int(np.ceil((t4*N_t)/Lt))
    N5 = np.int(np.floor((t5*N_t-1)/Lt))

    fig, ax = newfig(3.0, 3.0)
    ####### Row 1: u(t,x) slices ##################    
    gs1 = gridspec.GridSpec(2, 3)
    gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)

    ax = plt.subplot(gs1[0, 0])
    ax.pcolor(X_test, Y_test, u_plot[:,:,N0], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')    
    ax.set_title('$t = 0.0$', fontsize = 10)
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[0, 1])      
    ax.pcolor(X_test, Y_test, u_plot[:,:,N1], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])
    ax.set_title('$t = 0.2$', fontsize = 10)

    ax = plt.subplot(gs1[0, 2])       
    ax.pcolor(X_test, Y_test, u_plot[:,:,N2], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])    
    ax.set_title('$t = 0.4$', fontsize = 10)

    ax = plt.subplot(gs1[1, 0])
    ax.pcolor(X_test, Y_test, u_plot[:,:,N3], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')    
    ax.set_title('$t = 0.6$', fontsize = 10)
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])

    ax = plt.subplot(gs1[1, 1])      
    ax.pcolor(X_test, Y_test, u_plot[:,:,N4], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])
    ax.set_title('$t = 0.8$', fontsize = 10)

    ax = plt.subplot(gs1[1, 2])       
    ax.pcolor(X_test, Y_test, u_plot[:,:,N5], cmap='rainbow', vmin=zmin, vmax=zmax)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.axis('square')
    #ax.set_xlim([-1.1,1.1])
    #ax.set_ylim([-1.1,1.1])    
    ax.set_title('$t = 1.0$', fontsize = 10)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)

    plt.show()

# %%
#@title Loss and parameter plotter
def LossParameterPlotter(loss_history, l1_history, l2_history, l3_history):
    fig, axes = plt.subplots(2, sharex=True, figsize=(12, 12)) # Default plt.subplots(2, sharex=True, figsize=(12, 8))
    fig.suptitle('Training Metrics')

    axes[0].set_ylabel("Loss", fontsize=14)
    axes[0].set_xlabel("Epoch", fontsize=14)
    axes[0].semilogy(loss_history)

    axes[1].set_ylabel("l1,l2", fontsize=14)
    axes[1].set_xlabel("Epoch", fontsize=14)
    axes[1].plot(l1_history)
    axes[1].plot(l2_history)
    axes[1].plot(l3_history)
    axes[1].hlines(lambdas_star[0],0,len(l1_history),linestyles='dashed')
    axes[1].hlines(lambdas_star[1],0,len(l2_history),linestyles='dashed')
    axes[1].hlines(lambdas_star[2],0,len(l3_history),linestyles='dashed')

    plt.show()

# %%
#@title Parameter loader
def ParameterLoader(path):
    # Reading external data
    data = scipy.io.loadmat(path)

    Spread = np.real(data['Spread'])
    A  = np.real(data['A'])
    Sx = np.real(data['Sx'])
    Sy = np.real(data['Sy'])
    D  = np.real(data['D'])

    return A, D, Spread, Sx, Sy

# %%
#@title LBFGS v2
def dot(a, b):
  """Dot product function since TensorFlow doesn't have one."""
  return tf.reduce_sum(a*b)

def verbose_func(s):
  print(s)

final_loss = None
times = []
def lbfgs(opfunc, x, state, maxIter = 100, learningRate = 1, do_verbose = True):
  """port of lbfgs.lua, using TensorFlow eager mode.
  """

  global final_loss, times
  
  maxEval = maxIter*1.25
  tolFun = 1e-5
  tolX = 1e-9
  nCorrection = 50
  isverbose = False

  # verbose function
  if isverbose:
    verbose = verbose_func
  else:
    verbose = lambda x: None
    
  f, g = opfunc(x)

  f_hist = [f]
  currentFuncEval = 1
  state.funcEval = state.funcEval + 1
  p = g.shape[0]

  # check optimality of initial point
  tmp1 = tf.abs(g)
  if tf.reduce_sum(tmp1) <= tolFun:
    verbose("optimality condition below tolFun")
    return x, f_hist

  # optimize for a max of maxIter iterations
  nIter = 0
  times = []
  while nIter < maxIter:
    start_time = time.time()
    
    # keep track of nb of iterations
    nIter = nIter + 1
    state.nIter = state.nIter + 1

    ############################################################
    ## compute gradient descent direction
    ############################################################
    if state.nIter == 1:
      d = -g
      old_dirs = []
      old_stps = []
      Hdiag = 1
    else:
      # do lbfgs update (update memory)
      y = g - g_old
      s = d*t
      ys = dot(y, s)
      
      if ys > 1e-10:
        # updating memory
        if len(old_dirs) == nCorrection:
          # shift history by one (limited-memory)
          del old_dirs[0]
          del old_stps[0]

        # store new direction/step
        old_dirs.append(s)
        old_stps.append(y)

        # update scale of initial Hessian approximation
        Hdiag = ys/dot(y, y)

      # compute the approximate (L-BFGS) inverse Hessian 
      # multiplied by the gradient
      k = len(old_dirs)

      # need to be accessed element-by-element, so don't re-type tensor:
      ro = [0]*nCorrection
      for i in range(k):
        ro[i] = 1/dot(old_stps[i], old_dirs[i])
        

      # iteration in L-BFGS loop collapsed to use just one buffer
      # need to be accessed element-by-element, so don't re-type tensor:
      al = [0]*nCorrection

      q = -g
      for i in range(k-1, -1, -1):
        al[i] = dot(old_dirs[i], q) * ro[i]
        q = q - al[i]*old_stps[i]

      # multiply by initial Hessian
      r = q*Hdiag
      for i in range(k):
        be_i = dot(old_stps[i], r) * ro[i]
        r += (al[i]-be_i)*old_dirs[i]
        
      d = r
      # final direction is in r/d (same object)

    g_old = g
    f_old = f
    
    ############################################################
    ## compute step length
    ############################################################
    # directional derivative
    gtd = dot(g, d)

    # check that progress can be made along that direction
    if gtd > -tolX:
      verbose("Can not make progress along direction.")
      break

    # reset initial guess for step size
    if state.nIter == 1:
      tmp1 = tf.abs(g)
      t = min(1, 1/tf.reduce_sum(tmp1))
    else:
      t = learningRate



    x += t*d

    if nIter != maxIter:
    # re-evaluate function only if not in last iteration
    # the reason we do this: in a stochastic setting,
    # no use to re-evaluate that function here
      f, g = opfunc(x)

    lsFuncEval = 1
    f_hist.append(f)


    # update func eval
    currentFuncEval = currentFuncEval + lsFuncEval
    state.funcEval = state.funcEval + lsFuncEval

    ############################################################
    ## check conditions
    ############################################################
    if nIter == maxIter:
      break

    if currentFuncEval >= maxEval:
      # max nb of function evals
      print('max nb of function evals')
      break

    tmp1 = tf.abs(g)
    if tf.reduce_sum(tmp1) <=tolFun:
      # check optimality
      print('optimality condition below tolFun')
      break
    
    tmp1 = tf.abs(d*t)
    if tf.reduce_sum(tmp1) <= tolX:
      # step size below tolX
      print('step size below tolX')
      break
    
    if tf.abs(f,f_old) < tolX:
      # function value changing less than tolX
      print('function value changing less than tolX'+str(tf.abs(f-f_old)))
      break

    if do_verbose:
      if nIter % 10 == 0:
        print("Step %3d loss %6.5f "%(nIter, f.numpy()))


    if nIter == maxIter - 1:
      final_loss = f.numpy()


  # save state
  state.old_dirs = old_dirs
  state.old_stps = old_stps
  state.Hdiag = Hdiag
  state.g_old = g_old
  state.f_old = f_old
  state.t = t
  state.d = d

  return x, f_hist, currentFuncEval

# dummy/Struct gives Lua-like struct object with 0 defaults
class dummy(object):
  pass

class Struct(dummy):
  def __getattribute__(self, key):
    if key == '__dict__':
      return super(dummy, self).__getattribute__('__dict__')
    return self.__dict__.get(key, 0)

# %%
#@title PINN object Weighted
class PhysicsInformedNN(object):
    def __init__(self, layers, optimizer, logger, ub, lb, f_param, u_param, activation_func=tf.keras.activations.tanh):
        # Descriptive Keras model [3, 20, …, 20, 1]
        self.u_model = tf.keras.Sequential()
        self.u_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
        self.u_model.add(tf.keras.layers.Lambda(
          lambda X: 2.0*(X - lb)/(ub - lb) - 1.0))
        for width in layers[1:-1]:
            self.u_model.add(tf.keras.layers.Dense(
              width, activation=activation_func,
              kernel_initializer='glorot_normal'))
        self.u_model.add(tf.keras.layers.Dense(
              layers[-1], activation=None,
              kernel_initializer='glorot_normal'))

        self.dtype = tf.float32
        self.loss_history = []
        self.l1_history = []
        self.l2_history = []
        self.l3_history = []
        self.f_param = f_param
        self.u_param = u_param
        self.current_best_loss = 1e10
        self.current_best_weights = []

        # Defining the two additional trainable variables for identification
        self.lambda_1 = tf.Variable([0.0], dtype=self.dtype)
        self.lambda_2 = tf.Variable([0.0], dtype=self.dtype)
        self.lambda_3 = tf.Variable([0.5], dtype=self.dtype)

        self.optimizer = optimizer
        self.logger = logger
        
        # Computing the sizes of weights/biases for future decomposition
        self.sizes_w = []
        self.sizes_b = []
        for i, width in enumerate(layers):
            if i != 1:
                self.sizes_w.append(int(width * layers[1]))
                self.sizes_b.append(int(width if i != 0 else layers[1]))

    # The actual PINN
    def __f_model(self, X_u):
        l1, l2, l3 = self.get_params()
        # Separating the collocation coordinates
        x_f = tf.convert_to_tensor(X_u[:, 0:1], dtype=self.dtype)
        y_f = tf.convert_to_tensor(X_u[:, 1:2], dtype=self.dtype)
        t_f = tf.convert_to_tensor(X_u[:, 2:3], dtype=self.dtype)

        # Using the new GradientTape paradigm of TF2.0,
        # which keeps track of operations to get the gradient at runtime
        with tf.GradientTape(persistent=True) as tape:
            # Watching the two inputs we’ll need later, x and t
            tape.watch(x_f)
            tape.watch(y_f)
            tape.watch(t_f)
            # Packing together the inputs
            X_f = tf.stack([x_f[:,0], y_f[:,0], t_f[:,0]], axis=1)


            # Getting the prediction
            u = self.u_model(X_f)
            # Deriving INSIDE the tape (since we’ll need the x derivative of this later, u_xx)
            u_x = tape.gradient(u, x_f)
            u_y = tape.gradient(u, y_f)

        # Getting the other derivatives
        u_xx = tape.gradient(u_x, x_f)
        u_yy = tape.gradient(u_y, y_f)
        u_t = tape.gradient(u, t_f)

        # Letting the tape go
        del tape

        PDE = u_t + 2.0*u_x + (3.0*tf.math.cos(3.0*np.pi*t_f)+1.0)*u_y - 0.2*u_xx - 0.2*u_yy - l3*tf.math.exp(-4.0*tf.math.square(x_f - l1)-4.0*tf.math.square(y_f - l2))
        #Buidling the PINNs
        return PDE

    # Defining custom loss
    def __loss(self, X_u, u, u_pred):
        f_pred = self.__f_model(X_u)
        return self.u_param*tf.reduce_mean(tf.square(u - u_pred)) + self.f_param*tf.reduce_mean(tf.square(f_pred)) #10, 0.01
        
    def __grad(self, X, u):
        with tf.GradientTape() as tape:
            loss_value = self.__loss(X, u, self.u_model(X))
        return loss_value, tape.gradient(loss_value, self.__wrap_training_variables())

    def __wrap_training_variables(self):
        var = self.u_model.trainable_variables
        var.extend([self.lambda_1, self.lambda_2, self.lambda_3])
        return var

    def get_loss_and_flat_grad(self, X_u, u):
        def loss_and_flat_grad(w):
            with tf.GradientTape() as tape:
                self.set_weights(w)
                loss_value = self.__loss(X_u, u, self.u_model(X_u))
            grad = tape.gradient(loss_value, self.__wrap_training_variables())
            grad_flat = []
            for g in grad:
                grad_flat.append(tf.reshape(g, [-1]))
            grad_flat = tf.concat(grad_flat, 0)
            return loss_value, grad_flat
        return loss_and_flat_grad

    def get_weights(self):
        w = []
        for layer in self.u_model.layers[1:]:
            weights_biases = layer.get_weights()
            weights = weights_biases[0].flatten()
            biases = weights_biases[1]
            w.extend(weights)
            w.extend(biases)
        w.extend(self.lambda_1.numpy())
        w.extend(self.lambda_2.numpy())
        w.extend(self.lambda_3.numpy())
        return tf.convert_to_tensor(w, dtype=self.dtype)
    
    def set_weights(self, w):
        for i, layer in enumerate(self.u_model.layers[1:]):
            start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
            end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
            weights = w[start_weights:end_weights]
            w_div = int(self.sizes_w[i] / self.sizes_b[i])
            weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
            biases = w[end_weights:end_weights + self.sizes_b[i]]
            weights_biases = [weights, biases]
            layer.set_weights(weights_biases)
        self.lambda_1.assign([w[-3]])
        self.lambda_2.assign([w[-2]])
        self.lambda_3.assign([w[-1]])

    def get_params(self, numpy=False):
        l1 = self.lambda_1
        l2 = self.lambda_2
        l3 = self.lambda_3
        if numpy:
            return l1.numpy()[0], l2.numpy()[0], l3.numpy()[0]
        return l1, l2, l3

    def summary(self):
        return self.u_model.summary()

    def mini_batch(self, X_u, u, batch_size):

        idx_u = np.random.choice(tf.shape(X_u).numpy()[0], batch_size, replace=False) 

        X_u_batch = tf.gather(X_u, idx_u)
        u_batch   = tf.gather(u, idx_u)

        return X_u_batch, u_batch

    # The training function
    def fit(self, X_u, u, tf_epochs, batch_size=512):
        self.logger.log_train_start(self)
        
        # Creating the tensors
        X_u = tf.convert_to_tensor(X_u, dtype=self.dtype)
        u = tf.convert_to_tensor(u, dtype=self.dtype)

        iter_per_epoch = np.int(np.floor(tf.shape(X_u).numpy()[0]/batch_size))

        def log_train_epoch(epoch, loss):
            l1, l2, l3 = self.get_params(numpy=True)
            custom = f"l1 = {l1:4f} l2 = {l2:4f} l3 = {l3:4f}"
            self.logger.log_train_epoch(epoch, loss, self.current_best_loss, custom)
        self.logger.log_train_opt("Adam")

        for epoch in range(tf_epochs):
            for index in range(iter_per_epoch):

                X_u_batch, u_batch = self.mini_batch(X_u, u, batch_size)

                # Optimization step
                loss_value, grads = self.__grad(X_u_batch, u_batch)
                self.optimizer.apply_gradients(zip(grads, self.__wrap_training_variables()))

            loss_value, _ = self.__grad(X_u, u)

            if loss_value < self.current_best_loss:
                self.current_best_loss = loss_value
                self.current_best_weights = self.get_weights()

            log_train_epoch(epoch, loss_value)
            
            self.loss_history.append(loss_value.numpy())
            l1, l2, l3 = self.get_params(numpy=True)
            self.l1_history.append(l1)
            self.l2_history.append(l2)
            self.l3_history.append(l3)

        #l-bfgs-b optimization
        print("Starting L-BFGS training")

        loss_and_flat_grad = self.get_loss_and_flat_grad(X_u, u)
        lbfgs_weights, lbfgs_history, _ = lbfgs(loss_and_flat_grad, self.get_weights(), Struct(), maxIter=8000, learningRate=0.8)

        if lbfgs_history[-1] < self.current_best_loss:
            print("L-BFGS training was beneficial")
            self.current_best_loss = lbfgs_history[-1]
            self.current_best_weights = lbfgs_weights
        
        loss_value = self.__loss(X_u, u, self.u_model(X_u))
        l1, l2, l3 = self.get_params(numpy=True)

        for i in lbfgs_history:
            self.loss_history.append(i.numpy())
            self.l1_history.append(l1)
            self.l2_history.append(l2)
            self.l3_history.append(l3)
        
        self.set_weights(self.current_best_weights)
        elapsed_time = self.logger.log_train_end(tf_epochs, loss_value, self.current_best_loss, f"l1 = {l1:4f} l2 = {l2:4f} l3 = {l3:4f}")
        return self.loss_history, self.l1_history, self.l2_history, self.l3_history, elapsed_time

    def predict(self, X_star):
        u_star = self.u_model(X_star)
        f_star = self.__f_model(X_star)
        return u_star.numpy(), f_star.numpy()

# %%
# Data size on the solution u
N_u = 52000 # Default 52000 (for T=2) ONLY FOR DENSE DISTRIBUTION
# Amount of stationary measurement devices (for when using prep_data_sparse_measurement)
N_m = 26 # Default 26 
timestep = 1
# DeepNN topology (3-sized input [x y t], 8 hidden layer of 20-width, 1-sized output [u] works with 10 hidden layers too
layers = [3, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Activation function
activation_func = tf.keras.activations.tanh
# Setting up the TF SGD-based optimizer 
tf_epochs = 25000 # Default 20000
learning_rate = 0.001 # Default = 0.001
tf_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# True value for source location
lambdas_star = (-1.4, -1.0, 1.0) # Default -1.4, -1.0, 1.0

batch_size = 20530 # Full batch = N_m*2000 + 

f_param = 0.01 # Default 0.01
u_param = 10.0 # Default 10.0

inc_bounds = True
random_pos = False
sparse = True
noise = 0.05 # Default 0.05
prcnt = 0.013 # Default 0.013

path = os.path.join("/content/drive/MyDrive/Colab Notebooks/Data/ADE_strong_diagv5withVelocityMat.mat") 


x, y, t, X, Y, T, Exact_u, X_star, u_star, X_u_train, u_train, ub, lb = LoadData(path, N_u, N_m, noise, inc_bounds, prcnt, sparse, random_pos, timestep, method=2)

TrainingDataPlotter(X_u_train, ub, lb)
# Out:
# Amount of training data: 20530

# %%
# Creating the model and training
logger = Logger(frequency=1)
logger.set_error_fn(error)
pinn = PhysicsInformedNN(layers, tf_optimizer, logger, ub, lb, f_param, u_param, activation_func)
# Out:
# TensorFlow version: 2.7.0
# Eager execution: True
# GPU-accerelated: True

# %%
#loss_history, l1_history, l2_history, l3_history, elapsed_time = pinn.fit(X_u_train, u_train, tf_epochs, batch_size = batch_size)
loss_history, l1_history, l2_history, l3_history, elapsed_time, adaptive_param_history = pinn.fit(X_u_train, u_train, tf_epochs, batch_size = batch_size)
# Out:
# Streaming output truncated to the last 5000 lines.
# tf_epoch =  20105  elapsed = 01:04:32  loss = 8.3634e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777456 l2 = -0.487835 l3 = 0.418646 adaptive_param = 12.254963
# tf_epoch =  20106  elapsed = 01:04:32  loss = 8.9512e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777596 l2 = -0.487697 l3 = 0.418494 adaptive_param = 12.246981
# tf_epoch =  20107  elapsed = 01:04:32  loss = 9.8652e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777455 l2 = -0.487839 l3 = 0.418633 adaptive_param = 12.236633
# tf_epoch =  20108  elapsed = 01:04:32  loss = 9.9641e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777615 l2 = -0.487680 l3 = 0.418460 adaptive_param = 12.227842
# tf_epoch =  20109  elapsed = 01:04:33  loss = 1.0197e-04  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777474 l2 = -0.487823 l3 = 0.418598 adaptive_param = 12.216484
# tf_epoch =  20110  elapsed = 01:04:33  loss = 9.3109e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777634 l2 = -0.487663 l3 = 0.418425 adaptive_param = 12.206554
# tf_epoch =  20111  elapsed = 01:04:33  loss = 8.4662e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777516 l2 = -0.487783 l3 = 0.418540 adaptive_param = 12.193702
# tf_epoch =  20112  elapsed = 01:04:33  loss = 6.8549e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777649 l2 = -0.487651 l3 = 0.418396 adaptive_param = 12.182570
# tf_epoch =  20113  elapsed = 01:04:33  loss = 5.5658e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777576 l2 = -0.487725 l3 = 0.418464 adaptive_param = 12.168124
# tf_epoch =  20114  elapsed = 01:04:34  loss = 4.3732e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777655 l2 = -0.487648 l3 = 0.418376 adaptive_param = 12.156313
# tf_epoch =  20115  elapsed = 01:04:34  loss = 3.8017e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777638 l2 = -0.487667 l3 = 0.418386 adaptive_param = 12.140112
# tf_epoch =  20116  elapsed = 01:04:34  loss = 3.7467e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777653 l2 = -0.487653 l3 = 0.418364 adaptive_param = 12.130892
# tf_epoch =  20117  elapsed = 01:04:34  loss = 4.0968e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777687 l2 = -0.487620 l3 = 0.418321 adaptive_param = 12.123710
# tf_epoch =  20118  elapsed = 01:04:34  loss = 4.6602e-05  best loss = 3.7124e-05  error = 5.6735e-01  l1 = -0.777650 l2 = -0.487660 l3 = 0.418354 adaptive_param = 12.108250
# tf_epoch =  20119  elapsed = 01:04:34  loss = 5.0791e-05  best loss = 3.7124e-05  error = 5.6734e-01  l1 = -0.777719 l2 = -0.487592 l3 = 0.418276 adaptive_param = 12.097198
# tf_epoch =  20120  elapsed = 01:04:35  loss = 5.3317e-05  best loss = 3.7124e-05  error = 5.6734e-01  l1 = -0.777653 l2 = -0.487660 l3 = 0.418337 adaptive_param = 12.083752
# tf_epoch =  20121  elapsed = 01:04:35  loss = 5.1389e-05  best loss = 3.7124e-05  error = 5.6734e-01  l1 = -0.777733 l2 = -0.487582 l3 = 0.418249 adaptive_param = 12.074464
# tf_epoch =  20122  elapsed = 01:04:35  loss = 4.8172e-05  best loss = 3.7124e-05  error = 5.6734e-01  l1 = -0.777670 l2 = -0.487647 l3 = 0.418307 adaptive_param = 12.062502
# tf_epoch =  20123  elapsed = 01:04:35  loss = 4.2768e-05  best loss = 3.7124e-05  error = 5.6734e-01  l1 = -0.777733 l2 = -0.487586 l3 = 0.418236 adaptive_param = 12.056209
# tf_epoch =  20124  elapsed = 01:04:35  loss = 3.9056e-05  best loss = 3.7124e-05  error = 5.6734e-01  l1 = -0.777700 l2 = -0.487622 l3 = 0.418264 adaptive_param = 12.045052
# tf_epoch =  20125  elapsed = 01:04:36  loss = 3.6866e-05  best loss = 3.6866e-05  error = 5.6734e-01  l1 = -0.777724 l2 = -0.487599 l3 = 0.418232 adaptive_param = 12.044575
# tf_epoch =  20126  elapsed = 01:04:36  loss = 3.7081e-05  best loss = 3.6866e-05  error = 5.6734e-01  l1 = -0.777731 l2 = -0.487594 l3 = 0.418219 adaptive_param = 12.019613
# tf_epoch =  20127  elapsed = 01:04:36  loss = 3.9014e-05  best loss = 3.6866e-05  error = 5.6734e-01  l1 = -0.777716 l2 = -0.487612 l3 = 0.418229 adaptive_param = 11.998481
# tf_epoch =  20128  elapsed = 01:04:36  loss = 4.0933e-05  best loss = 3.6866e-05  error = 5.6734e-01  l1 = -0.777755 l2 = -0.487575 l3 = 0.418182 adaptive_param = 11.995572
# tf_epoch =  20129  elapsed = 01:04:36  loss = 4.2565e-05  best loss = 3.6866e-05  error = 5.6733e-01  l1 = -0.777714 l2 = -0.487618 l3 = 0.418218 adaptive_param = 11.986620
# tf_epoch =  20130  elapsed = 01:04:37  loss = 4.2278e-05  best loss = 3.6866e-05  error = 5.6733e-01  l1 = -0.777765 l2 = -0.487570 l3 = 0.418160 adaptive_param = 11.983243
# tf_epoch =  20131  elapsed = 01:04:37  loss = 4.1367e-05  best loss = 3.6866e-05  error = 5.6733e-01  l1 = -0.777724 l2 = -0.487613 l3 = 0.418196 adaptive_param = 11.974647
# tf_epoch =  20132  elapsed = 01:04:37  loss = 3.9268e-05  best loss = 3.6866e-05  error = 5.6733e-01  l1 = -0.777763 l2 = -0.487576 l3 = 0.418149 adaptive_param = 11.971456
# tf_epoch =  20133  elapsed = 01:04:37  loss = 3.7801e-05  best loss = 3.6866e-05  error = 5.6733e-01  l1 = -0.777740 l2 = -0.487602 l3 = 0.418167 adaptive_param = 11.960294
# tf_epoch =  20134  elapsed = 01:04:37  loss = 3.6710e-05  best loss = 3.6710e-05  error = 5.6733e-01  l1 = -0.777755 l2 = -0.487589 l3 = 0.418146 adaptive_param = 11.959167
# tf_epoch =  20135  elapsed = 01:04:38  loss = 3.6618e-05  best loss = 3.6618e-05  error = 5.6733e-01  l1 = -0.777755 l2 = -0.487591 l3 = 0.418140 adaptive_param = 11.931316
# tf_epoch =  20136  elapsed = 01:04:38  loss = 3.7246e-05  best loss = 3.6618e-05  error = 5.6733e-01  l1 = -0.777744 l2 = -0.487604 l3 = 0.418144 adaptive_param = 11.899755
# tf_epoch =  20137  elapsed = 01:04:38  loss = 3.7899e-05  best loss = 3.6618e-05  error = 5.6732e-01  l1 = -0.777763 l2 = -0.487588 l3 = 0.418119 adaptive_param = 11.901877
# tf_epoch =  20138  elapsed = 01:04:38  loss = 3.8623e-05  best loss = 3.6618e-05  error = 5.6732e-01  l1 = -0.777736 l2 = -0.487617 l3 = 0.418142 adaptive_param = 11.892824
# tf_epoch =  20139  elapsed = 01:04:38  loss = 3.8567e-05  best loss = 3.6618e-05  error = 5.6732e-01  l1 = -0.777761 l2 = -0.487595 l3 = 0.418110 adaptive_param = 11.891150
# tf_epoch =  20140  elapsed = 01:04:39  loss = 3.8344e-05  best loss = 3.6618e-05  error = 5.6732e-01  l1 = -0.777730 l2 = -0.487628 l3 = 0.418136 adaptive_param = 11.883575
# tf_epoch =  20141  elapsed = 01:04:39  loss = 3.7579e-05  best loss = 3.6618e-05  error = 5.6732e-01  l1 = -0.777749 l2 = -0.487611 l3 = 0.418110 adaptive_param = 11.882968
# tf_epoch =  20142  elapsed = 01:04:39  loss = 3.7031e-05  best loss = 3.6618e-05  error = 5.6732e-01  l1 = -0.777726 l2 = -0.487637 l3 = 0.418128 adaptive_param = 11.875293
# tf_epoch =  20143  elapsed = 01:04:39  loss = 3.6565e-05  best loss = 3.6565e-05  error = 5.6732e-01  l1 = -0.777730 l2 = -0.487635 l3 = 0.418118 adaptive_param = 11.880695
# tf_epoch =  20144  elapsed = 01:04:39  loss = 3.6482e-05  best loss = 3.6482e-05  error = 5.6732e-01  l1 = -0.777722 l2 = -0.487646 l3 = 0.418121 adaptive_param = 11.859238
# tf_epoch =  20145  elapsed = 01:04:39  loss = 3.6703e-05  best loss = 3.6482e-05  error = 5.6732e-01  l1 = -0.777710 l2 = -0.487660 l3 = 0.418127 adaptive_param = 11.825445
# tf_epoch =  20146  elapsed = 01:04:40  loss = 3.6923e-05  best loss = 3.6482e-05  error = 5.6731e-01  l1 = -0.777714 l2 = -0.487658 l3 = 0.418116 adaptive_param = 11.832486
# tf_epoch =  20147  elapsed = 01:04:40  loss = 3.7270e-05  best loss = 3.6482e-05  error = 5.6731e-01  l1 = -0.777691 l2 = -0.487683 l3 = 0.418134 adaptive_param = 11.821842
# tf_epoch =  20148  elapsed = 01:04:40  loss = 3.7225e-05  best loss = 3.6482e-05  error = 5.6731e-01  l1 = -0.777702 l2 = -0.487675 l3 = 0.418117 adaptive_param = 11.828231
# tf_epoch =  20149  elapsed = 01:04:40  loss = 3.7211e-05  best loss = 3.6482e-05  error = 5.6731e-01  l1 = -0.777677 l2 = -0.487703 l3 = 0.418137 adaptive_param = 11.821670
# tf_epoch =  20150  elapsed = 01:04:40  loss = 3.6868e-05  best loss = 3.6482e-05  error = 5.6731e-01  l1 = -0.777685 l2 = -0.487696 l3 = 0.418122 adaptive_param = 11.829483
# tf_epoch =  20151  elapsed = 01:04:41  loss = 3.6671e-05  best loss = 3.6482e-05  error = 5.6731e-01  l1 = -0.777666 l2 = -0.487718 l3 = 0.418137 adaptive_param = 11.820876
# tf_epoch =  20152  elapsed = 01:04:41  loss = 3.6433e-05  best loss = 3.6433e-05  error = 5.6731e-01  l1 = -0.777666 l2 = -0.487720 l3 = 0.418130 adaptive_param = 11.832447
# tf_epoch =  20153  elapsed = 01:04:41  loss = 3.6376e-05  best loss = 3.6376e-05  error = 5.6731e-01  l1 = -0.777656 l2 = -0.487733 l3 = 0.418135 adaptive_param = 11.803300
# tf_epoch =  20154  elapsed = 01:04:41  loss = 3.6424e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777646 l2 = -0.487745 l3 = 0.418139 adaptive_param = 11.891809
# tf_epoch =  20155  elapsed = 01:04:41  loss = 3.6489e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777645 l2 = -0.487748 l3 = 0.418134 adaptive_param = 11.911734
# tf_epoch =  20156  elapsed = 01:04:42  loss = 3.6652e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777628 l2 = -0.487768 l3 = 0.418146 adaptive_param = 11.892530
# tf_epoch =  20157  elapsed = 01:04:42  loss = 3.6654e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777631 l2 = -0.487767 l3 = 0.418136 adaptive_param = 11.901631
# tf_epoch =  20158  elapsed = 01:04:42  loss = 3.6744e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777611 l2 = -0.487789 l3 = 0.418151 adaptive_param = 11.887620
# tf_epoch =  20159  elapsed = 01:04:42  loss = 3.6623e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777615 l2 = -0.487787 l3 = 0.418140 adaptive_param = 11.893323
# tf_epoch =  20160  elapsed = 01:04:42  loss = 3.6608e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777596 l2 = -0.487808 l3 = 0.418154 adaptive_param = 11.878221
# tf_epoch =  20161  elapsed = 01:04:43  loss = 3.6446e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777597 l2 = -0.487809 l3 = 0.418146 adaptive_param = 11.884032
# tf_epoch =  20162  elapsed = 01:04:43  loss = 3.6396e-05  best loss = 3.6376e-05  error = 5.6730e-01  l1 = -0.777582 l2 = -0.487826 l3 = 0.418156 adaptive_param = 11.864013
# tf_epoch =  20163  elapsed = 01:04:43  loss = 3.6298e-05  best loss = 3.6298e-05  error = 5.6729e-01  l1 = -0.777579 l2 = -0.487831 l3 = 0.418153 adaptive_param = 11.874724
# tf_epoch =  20164  elapsed = 01:04:43  loss = 3.6273e-05  best loss = 3.6273e-05  error = 5.6729e-01  l1 = -0.777569 l2 = -0.487844 l3 = 0.418157 adaptive_param = 11.831277
# tf_epoch =  20165  elapsed = 01:04:43  loss = 3.6272e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777560 l2 = -0.487854 l3 = 0.418160 adaptive_param = 11.925303
# tf_epoch =  20166  elapsed = 01:04:44  loss = 3.6272e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777555 l2 = -0.487862 l3 = 0.418159 adaptive_param = 11.964466
# tf_epoch =  20167  elapsed = 01:04:44  loss = 3.6329e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777542 l2 = -0.487876 l3 = 0.418166 adaptive_param = 11.921982
# tf_epoch =  20168  elapsed = 01:04:44  loss = 3.6321e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777540 l2 = -0.487881 l3 = 0.418162 adaptive_param = 11.930557
# tf_epoch =  20169  elapsed = 01:04:44  loss = 3.6383e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777524 l2 = -0.487898 l3 = 0.418172 adaptive_param = 11.906637
# tf_epoch =  20170  elapsed = 01:04:44  loss = 3.6342e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777523 l2 = -0.487901 l3 = 0.418167 adaptive_param = 11.915524
# tf_epoch =  20171  elapsed = 01:04:45  loss = 3.6376e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777507 l2 = -0.487919 l3 = 0.418177 adaptive_param = 11.895934
# tf_epoch =  20172  elapsed = 01:04:45  loss = 3.6304e-05  best loss = 3.6272e-05  error = 5.6729e-01  l1 = -0.777506 l2 = -0.487922 l3 = 0.418172 adaptive_param = 11.906284
# tf_epoch =  20173  elapsed = 01:04:45  loss = 3.6309e-05  best loss = 3.6272e-05  error = 5.6728e-01  l1 = -0.777491 l2 = -0.487940 l3 = 0.418181 adaptive_param = 11.886077
# tf_epoch =  20174  elapsed = 01:04:45  loss = 3.6232e-05  best loss = 3.6232e-05  error = 5.6728e-01  l1 = -0.777488 l2 = -0.487944 l3 = 0.418177 adaptive_param = 11.897532
# tf_epoch =  20175  elapsed = 01:04:45  loss = 3.6225e-05  best loss = 3.6225e-05  error = 5.6728e-01  l1 = -0.777475 l2 = -0.487959 l3 = 0.418185 adaptive_param = 11.870955
# tf_epoch =  20176  elapsed = 01:04:46  loss = 3.6167e-05  best loss = 3.6167e-05  error = 5.6728e-01  l1 = -0.777470 l2 = -0.487966 l3 = 0.418184 adaptive_param = 11.885047
# tf_epoch =  20177  elapsed = 01:04:46  loss = 3.6158e-05  best loss = 3.6158e-05  error = 5.6728e-01  l1 = -0.777459 l2 = -0.487979 l3 = 0.418189 adaptive_param = 11.841456
# tf_epoch =  20178  elapsed = 01:04:46  loss = 3.6131e-05  best loss = 3.6131e-05  error = 5.6728e-01  l1 = -0.777452 l2 = -0.487988 l3 = 0.418190 adaptive_param = 11.872666
# tf_epoch =  20179  elapsed = 01:04:46  loss = 3.6122e-05  best loss = 3.6122e-05  error = 5.6728e-01  l1 = -0.777443 l2 = -0.487999 l3 = 0.418193 adaptive_param = 11.893444
# tf_epoch =  20180  elapsed = 01:04:46  loss = 3.6122e-05  best loss = 3.6122e-05  error = 5.6728e-01  l1 = -0.777434 l2 = -0.488010 l3 = 0.418196 adaptive_param = 11.959260
# tf_epoch =  20181  elapsed = 01:04:47  loss = 3.6112e-05  best loss = 3.6112e-05  error = 5.6728e-01  l1 = -0.777427 l2 = -0.488019 l3 = 0.418197 adaptive_param = 12.024420
# tf_epoch =  20182  elapsed = 01:04:47  loss = 3.6129e-05  best loss = 3.6112e-05  error = 5.6728e-01  l1 = -0.777416 l2 = -0.488032 l3 = 0.418202 adaptive_param = 11.992543
# tf_epoch =  20183  elapsed = 01:04:47  loss = 3.6114e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777411 l2 = -0.488040 l3 = 0.418201 adaptive_param = 12.006079
# tf_epoch =  20184  elapsed = 01:04:47  loss = 3.6141e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777398 l2 = -0.488054 l3 = 0.418207 adaptive_param = 11.963243
# tf_epoch =  20185  elapsed = 01:04:47  loss = 3.6118e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777394 l2 = -0.488060 l3 = 0.418206 adaptive_param = 11.973612
# tf_epoch =  20186  elapsed = 01:04:47  loss = 3.6150e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777381 l2 = -0.488075 l3 = 0.418213 adaptive_param = 11.940075
# tf_epoch =  20187  elapsed = 01:04:48  loss = 3.6119e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777377 l2 = -0.488081 l3 = 0.418210 adaptive_param = 11.950079
# tf_epoch =  20188  elapsed = 01:04:48  loss = 3.6153e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777363 l2 = -0.488097 l3 = 0.418218 adaptive_param = 11.921546
# tf_epoch =  20189  elapsed = 01:04:48  loss = 3.6117e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777361 l2 = -0.488102 l3 = 0.418215 adaptive_param = 11.932268
# tf_epoch =  20190  elapsed = 01:04:48  loss = 3.6149e-05  best loss = 3.6112e-05  error = 5.6727e-01  l1 = -0.777346 l2 = -0.488118 l3 = 0.418224 adaptive_param = 11.906950
# tf_epoch =  20191  elapsed = 01:04:48  loss = 3.6108e-05  best loss = 3.6108e-05  error = 5.6727e-01  l1 = -0.777344 l2 = -0.488122 l3 = 0.418220 adaptive_param = 11.918186
# tf_epoch =  20192  elapsed = 01:04:49  loss = 3.6140e-05  best loss = 3.6108e-05  error = 5.6727e-01  l1 = -0.777329 l2 = -0.488139 l3 = 0.418229 adaptive_param = 11.894630
# tf_epoch =  20193  elapsed = 01:04:49  loss = 3.6096e-05  best loss = 3.6096e-05  error = 5.6727e-01  l1 = -0.777326 l2 = -0.488144 l3 = 0.418225 adaptive_param = 11.905972
# tf_epoch =  20194  elapsed = 01:04:49  loss = 3.6127e-05  best loss = 3.6096e-05  error = 5.6726e-01  l1 = -0.777311 l2 = -0.488161 l3 = 0.418234 adaptive_param = 11.883622
# tf_epoch =  20195  elapsed = 01:04:49  loss = 3.6081e-05  best loss = 3.6081e-05  error = 5.6726e-01  l1 = -0.777309 l2 = -0.488165 l3 = 0.418230 adaptive_param = 11.895481
# tf_epoch =  20196  elapsed = 01:04:49  loss = 3.6112e-05  best loss = 3.6081e-05  error = 5.6726e-01  l1 = -0.777294 l2 = -0.488182 l3 = 0.418239 adaptive_param = 11.873728
# tf_epoch =  20197  elapsed = 01:04:50  loss = 3.6065e-05  best loss = 3.6065e-05  error = 5.6726e-01  l1 = -0.777292 l2 = -0.488186 l3 = 0.418235 adaptive_param = 11.886055
# tf_epoch =  20198  elapsed = 01:04:50  loss = 3.6098e-05  best loss = 3.6065e-05  error = 5.6726e-01  l1 = -0.777276 l2 = -0.488203 l3 = 0.418244 adaptive_param = 11.864751
# tf_epoch =  20199  elapsed = 01:04:50  loss = 3.6052e-05  best loss = 3.6052e-05  error = 5.6726e-01  l1 = -0.777275 l2 = -0.488207 l3 = 0.418240 adaptive_param = 11.877287
# tf_epoch =  20200  elapsed = 01:04:50  loss = 3.6086e-05  best loss = 3.6052e-05  error = 5.6726e-01  l1 = -0.777259 l2 = -0.488225 l3 = 0.418249 adaptive_param = 11.857155
# tf_epoch =  20201  elapsed = 01:04:50  loss = 3.6042e-05  best loss = 3.6042e-05  error = 5.6726e-01  l1 = -0.777258 l2 = -0.488228 l3 = 0.418245 adaptive_param = 11.869867
# tf_epoch =  20202  elapsed = 01:04:51  loss = 3.6082e-05  best loss = 3.6042e-05  error = 5.6726e-01  l1 = -0.777242 l2 = -0.488246 l3 = 0.418255 adaptive_param = 11.850871
# tf_epoch =  20203  elapsed = 01:04:51  loss = 3.6040e-05  best loss = 3.6040e-05  error = 5.6726e-01  l1 = -0.777241 l2 = -0.488249 l3 = 0.418249 adaptive_param = 11.863645
# tf_epoch =  20204  elapsed = 01:04:51  loss = 3.6088e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777224 l2 = -0.488267 l3 = 0.418260 adaptive_param = 11.846263
# tf_epoch =  20205  elapsed = 01:04:51  loss = 3.6049e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777224 l2 = -0.488270 l3 = 0.418254 adaptive_param = 11.858889
# tf_epoch =  20206  elapsed = 01:04:51  loss = 3.6111e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777207 l2 = -0.488289 l3 = 0.418265 adaptive_param = 11.843383
# tf_epoch =  20207  elapsed = 01:04:52  loss = 3.6077e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777208 l2 = -0.488290 l3 = 0.418258 adaptive_param = 11.855512
# tf_epoch =  20208  elapsed = 01:04:52  loss = 3.6160e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777189 l2 = -0.488311 l3 = 0.418270 adaptive_param = 11.842099
# tf_epoch =  20209  elapsed = 01:04:52  loss = 3.6136e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777191 l2 = -0.488310 l3 = 0.418261 adaptive_param = 11.853320
# tf_epoch =  20210  elapsed = 01:04:52  loss = 3.6254e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777171 l2 = -0.488333 l3 = 0.418276 adaptive_param = 11.842382
# tf_epoch =  20211  elapsed = 01:04:52  loss = 3.6252e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777176 l2 = -0.488330 l3 = 0.418265 adaptive_param = 11.852404
# tf_epoch =  20212  elapsed = 01:04:53  loss = 3.6429e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777153 l2 = -0.488355 l3 = 0.418282 adaptive_param = 11.843814
# tf_epoch =  20213  elapsed = 01:04:53  loss = 3.6473e-05  best loss = 3.6040e-05  error = 5.6725e-01  l1 = -0.777160 l2 = -0.488349 l3 = 0.418268 adaptive_param = 11.852639
# tf_epoch =  20214  elapsed = 01:04:53  loss = 3.6755e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777134 l2 = -0.488377 l3 = 0.418288 adaptive_param = 11.846207
# tf_epoch =  20215  elapsed = 01:04:53  loss = 3.6891e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777146 l2 = -0.488367 l3 = 0.418269 adaptive_param = 11.853703
# tf_epoch =  20216  elapsed = 01:04:53  loss = 3.7371e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777115 l2 = -0.488401 l3 = 0.418295 adaptive_param = 11.849136
# tf_epoch =  20217  elapsed = 01:04:54  loss = 3.7702e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777133 l2 = -0.488384 l3 = 0.418270 adaptive_param = 11.855319
# tf_epoch =  20218  elapsed = 01:04:54  loss = 3.8562e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777094 l2 = -0.488425 l3 = 0.418303 adaptive_param = 11.852268
# tf_epoch =  20219  elapsed = 01:04:54  loss = 3.9305e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777122 l2 = -0.488400 l3 = 0.418268 adaptive_param = 11.857302
# tf_epoch =  20220  elapsed = 01:04:54  loss = 4.0924e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777072 l2 = -0.488451 l3 = 0.418313 adaptive_param = 11.855372
# tf_epoch =  20221  elapsed = 01:04:54  loss = 4.2548e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777114 l2 = -0.488412 l3 = 0.418263 adaptive_param = 11.859337
# tf_epoch =  20222  elapsed = 01:04:54  loss = 4.5716e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777049 l2 = -0.488478 l3 = 0.418324 adaptive_param = 11.858200
# tf_epoch =  20223  elapsed = 01:04:55  loss = 4.9185e-05  best loss = 3.6040e-05  error = 5.6724e-01  l1 = -0.777111 l2 = -0.488419 l3 = 0.418254 adaptive_param = 11.861228
# tf_epoch =  20224  elapsed = 01:04:55  loss = 5.5505e-05  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777024 l2 = -0.488508 l3 = 0.418337 adaptive_param = 11.860518
# tf_epoch =  20225  elapsed = 01:04:55  loss = 6.2643e-05  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777115 l2 = -0.488419 l3 = 0.418236 adaptive_param = 11.862618
# tf_epoch =  20226  elapsed = 01:04:55  loss = 7.5032e-05  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.776998 l2 = -0.488538 l3 = 0.418351 adaptive_param = 11.861913
# tf_epoch =  20227  elapsed = 01:04:55  loss = 8.8461e-05  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777130 l2 = -0.488407 l3 = 0.418207 adaptive_param = 11.862979
# tf_epoch =  20228  elapsed = 01:04:56  loss = 1.1056e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.776975 l2 = -0.488564 l3 = 0.418361 adaptive_param = 11.861711
# tf_epoch =  20229  elapsed = 01:04:56  loss = 1.3074e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777159 l2 = -0.488382 l3 = 0.418164 adaptive_param = 11.861357
# tf_epoch =  20230  elapsed = 01:04:56  loss = 1.6088e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.776967 l2 = -0.488575 l3 = 0.418355 adaptive_param = 11.858624
# tf_epoch =  20231  elapsed = 01:04:56  loss = 1.7606e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777201 l2 = -0.488343 l3 = 0.418106 adaptive_param = 11.856122
# tf_epoch =  20232  elapsed = 01:04:56  loss = 1.9339e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.776997 l2 = -0.488548 l3 = 0.418309 adaptive_param = 11.850622
# tf_epoch =  20233  elapsed = 01:04:57  loss = 1.7529e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777247 l2 = -0.488300 l3 = 0.418044 adaptive_param = 11.845056
# tf_epoch =  20234  elapsed = 01:04:57  loss = 1.5095e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777085 l2 = -0.488462 l3 = 0.418203 adaptive_param = 11.835452
# tf_epoch =  20235  elapsed = 01:04:57  loss = 1.0084e-04  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777280 l2 = -0.488269 l3 = 0.417995 adaptive_param = 11.826067
# tf_epoch =  20236  elapsed = 01:04:57  loss = 6.2576e-05  best loss = 3.6040e-05  error = 5.6723e-01  l1 = -0.777218 l2 = -0.488332 l3 = 0.418052 adaptive_param = 11.811485
# tf_epoch =  20237  elapsed = 01:04:57  loss = 3.9167e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777297 l2 = -0.488254 l3 = 0.417963 adaptive_param = 11.796889
# tf_epoch =  20238  elapsed = 01:04:58  loss = 4.0927e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777346 l2 = -0.488207 l3 = 0.417907 adaptive_param = 11.767175
# tf_epoch =  20239  elapsed = 01:04:58  loss = 5.8540e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777313 l2 = -0.488241 l3 = 0.417933 adaptive_param = 11.764951
# tf_epoch =  20240  elapsed = 01:04:58  loss = 7.6474e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777431 l2 = -0.488125 l3 = 0.417805 adaptive_param = 11.754986
# tf_epoch =  20241  elapsed = 01:04:58  loss = 8.3633e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777348 l2 = -0.488210 l3 = 0.417884 adaptive_param = 11.742222
# tf_epoch =  20242  elapsed = 01:04:58  loss = 7.3211e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777470 l2 = -0.488091 l3 = 0.417753 adaptive_param = 11.729275
# tf_epoch =  20243  elapsed = 01:04:58  loss = 5.5855e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777408 l2 = -0.488155 l3 = 0.417811 adaptive_param = 11.713804
# tf_epoch =  20244  elapsed = 01:04:59  loss = 4.0036e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777478 l2 = -0.488088 l3 = 0.417733 adaptive_param = 11.701919
# tf_epoch =  20245  elapsed = 01:04:59  loss = 3.6502e-05  best loss = 3.6040e-05  error = 5.6722e-01  l1 = -0.777480 l2 = -0.488089 l3 = 0.417726 adaptive_param = 11.687178
# tf_epoch =  20246  elapsed = 01:04:59  loss = 4.3733e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777478 l2 = -0.488094 l3 = 0.417723 adaptive_param = 11.676530
# tf_epoch =  20247  elapsed = 01:04:59  loss = 5.2509e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777542 l2 = -0.488033 l3 = 0.417652 adaptive_param = 11.661075
# tf_epoch =  20248  elapsed = 01:04:59  loss = 5.7666e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777491 l2 = -0.488086 l3 = 0.417699 adaptive_param = 11.643737
# tf_epoch =  20249  elapsed = 01:05:00  loss = 5.2237e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777579 l2 = -0.488002 l3 = 0.417604 adaptive_param = 11.633640
# tf_epoch =  20250  elapsed = 01:05:00  loss = 4.4101e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777531 l2 = -0.488052 l3 = 0.417647 adaptive_param = 11.623257
# tf_epoch =  20251  elapsed = 01:05:00  loss = 3.7340e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777591 l2 = -0.487996 l3 = 0.417581 adaptive_param = 11.622659
# tf_epoch =  20252  elapsed = 01:05:00  loss = 3.6818e-05  best loss = 3.6040e-05  error = 5.6721e-01  l1 = -0.777589 l2 = -0.488001 l3 = 0.417578 adaptive_param = 11.683573
# tf_epoch =  20253  elapsed = 01:05:00  loss = 4.0956e-05  best loss = 3.6040e-05  error = 5.6720e-01  l1 = -0.777591 l2 = -0.488002 l3 = 0.417570 adaptive_param = 11.693778
# tf_epoch =  20254  elapsed = 01:05:01  loss = 4.5045e-05  best loss = 3.6040e-05  error = 5.6720e-01  l1 = -0.777640 l2 = -0.487956 l3 = 0.417515 adaptive_param = 11.674830
# tf_epoch =  20255  elapsed = 01:05:01  loss = 4.7093e-05  best loss = 3.6040e-05  error = 5.6720e-01  l1 = -0.777600 l2 = -0.487999 l3 = 0.417551 adaptive_param = 11.657541
# tf_epoch =  20256  elapsed = 01:05:01  loss = 4.3754e-05  best loss = 3.6040e-05  error = 5.6720e-01  l1 = -0.777671 l2 = -0.487931 l3 = 0.417473 adaptive_param = 11.652180
# tf_epoch =  20257  elapsed = 01:05:01  loss = 3.9787e-05  best loss = 3.6040e-05  error = 5.6720e-01  l1 = -0.777632 l2 = -0.487974 l3 = 0.417509 adaptive_param = 11.647161
# tf_epoch =  20258  elapsed = 01:05:01  loss = 3.6496e-05  best loss = 3.6040e-05  error = 5.6720e-01  l1 = -0.777678 l2 = -0.487931 l3 = 0.417456 adaptive_param = 11.657521
# tf_epoch =  20259  elapsed = 01:05:02  loss = 3.6334e-05  best loss = 3.6040e-05  error = 5.6719e-01  l1 = -0.777675 l2 = -0.487937 l3 = 0.417455 adaptive_param = 11.881042
# tf_epoch =  20260  elapsed = 01:05:02  loss = 3.8605e-05  best loss = 3.6040e-05  error = 5.6719e-01  l1 = -0.777671 l2 = -0.487945 l3 = 0.417454 adaptive_param = 11.884637
# tf_epoch =  20261  elapsed = 01:05:02  loss = 4.0932e-05  best loss = 3.6040e-05  error = 5.6719e-01  l1 = -0.777707 l2 = -0.487913 l3 = 0.417413 adaptive_param = 11.864885
# tf_epoch =  20262  elapsed = 01:05:02  loss = 4.2497e-05  best loss = 3.6040e-05  error = 5.6719e-01  l1 = -0.777666 l2 = -0.487956 l3 = 0.417450 adaptive_param = 11.847002
# tf_epoch =  20263  elapsed = 01:05:02  loss = 4.1520e-05  best loss = 3.6040e-05  error = 5.6719e-01  l1 = -0.777716 l2 = -0.487910 l3 = 0.417394 adaptive_param = 11.836663
# tf_epoch =  20264  elapsed = 01:05:03  loss = 3.9457e-05  best loss = 3.6040e-05  error = 5.6719e-01  l1 = -0.777673 l2 = -0.487957 l3 = 0.417434 adaptive_param = 11.828172
# tf_epoch =  20265  elapsed = 01:05:03  loss = 3.7031e-05  best loss = 3.6040e-05  error = 5.6718e-01  l1 = -0.777705 l2 = -0.487928 l3 = 0.417397 adaptive_param = 11.823252
# tf_epoch =  20266  elapsed = 01:05:03  loss = 3.5851e-05  best loss = 3.5851e-05  error = 5.6718e-01  l1 = -0.777686 l2 = -0.487951 l3 = 0.417412 adaptive_param = 11.820394
# tf_epoch =  20267  elapsed = 01:05:03  loss = 3.6061e-05  best loss = 3.5851e-05  error = 5.6718e-01  l1 = -0.777681 l2 = -0.487959 l3 = 0.417412 adaptive_param = 11.940091
# tf_epoch =  20268  elapsed = 01:05:03  loss = 3.6975e-05  best loss = 3.5851e-05  error = 5.6718e-01  l1 = -0.777692 l2 = -0.487952 l3 = 0.417397 adaptive_param = 11.942543
# tf_epoch =  20269  elapsed = 01:05:04  loss = 3.8278e-05  best loss = 3.5851e-05  error = 5.6718e-01  l1 = -0.777661 l2 = -0.487986 l3 = 0.417423 adaptive_param = 11.922500
# tf_epoch =  20270  elapsed = 01:05:04  loss = 3.8665e-05  best loss = 3.5851e-05  error = 5.6717e-01  l1 = -0.777686 l2 = -0.487965 l3 = 0.417394 adaptive_param = 11.909689
# tf_epoch =  20271  elapsed = 01:05:04  loss = 3.8718e-05  best loss = 3.5851e-05  error = 5.6717e-01  l1 = -0.777649 l2 = -0.488005 l3 = 0.417427 adaptive_param = 11.893373
# tf_epoch =  20272  elapsed = 01:05:04  loss = 3.7696e-05  best loss = 3.5851e-05  error = 5.6717e-01  l1 = -0.777671 l2 = -0.487986 l3 = 0.417400 adaptive_param = 11.880638
# tf_epoch =  20273  elapsed = 01:05:04  loss = 3.6785e-05  best loss = 3.5851e-05  error = 5.6717e-01  l1 = -0.777644 l2 = -0.488016 l3 = 0.417423 adaptive_param = 11.863843
# tf_epoch =  20274  elapsed = 01:05:04  loss = 3.5798e-05  best loss = 3.5798e-05  error = 5.6717e-01  l1 = -0.777651 l2 = -0.488013 l3 = 0.417411 adaptive_param = 11.852388
# tf_epoch =  20275  elapsed = 01:05:05  loss = 3.5508e-05  best loss = 3.5508e-05  error = 5.6717e-01  l1 = -0.777640 l2 = -0.488027 l3 = 0.417418 adaptive_param = 11.823453
# tf_epoch =  20276  elapsed = 01:05:05  loss = 3.5696e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777630 l2 = -0.488041 l3 = 0.417423 adaptive_param = 11.923044
# tf_epoch =  20277  elapsed = 01:05:05  loss = 3.6094e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777633 l2 = -0.488041 l3 = 0.417416 adaptive_param = 11.907341
# tf_epoch =  20278  elapsed = 01:05:05  loss = 3.6741e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777612 l2 = -0.488065 l3 = 0.417433 adaptive_param = 11.880942
# tf_epoch =  20279  elapsed = 01:05:05  loss = 3.6807e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777622 l2 = -0.488057 l3 = 0.417417 adaptive_param = 11.866369
# tf_epoch =  20280  elapsed = 01:05:06  loss = 3.6862e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777597 l2 = -0.488086 l3 = 0.417438 adaptive_param = 11.845494
# tf_epoch =  20281  elapsed = 01:05:06  loss = 3.6291e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777607 l2 = -0.488079 l3 = 0.417423 adaptive_param = 11.834903
# tf_epoch =  20282  elapsed = 01:05:06  loss = 3.5912e-05  best loss = 3.5508e-05  error = 5.6716e-01  l1 = -0.777585 l2 = -0.488104 l3 = 0.417441 adaptive_param = 11.817084
# tf_epoch =  20283  elapsed = 01:05:06  loss = 3.5487e-05  best loss = 3.5487e-05  error = 5.6715e-01  l1 = -0.777588 l2 = -0.488104 l3 = 0.417433 adaptive_param = 11.813601
# tf_epoch =  20284  elapsed = 01:05:06  loss = 3.5367e-05  best loss = 3.5367e-05  error = 5.6715e-01  l1 = -0.777574 l2 = -0.488120 l3 = 0.417442 adaptive_param = 11.828281
# tf_epoch =  20285  elapsed = 01:05:07  loss = 3.5474e-05  best loss = 3.5367e-05  error = 5.6715e-01  l1 = -0.777568 l2 = -0.488130 l3 = 0.417444 adaptive_param = 11.883733
# tf_epoch =  20286  elapsed = 01:05:07  loss = 3.5619e-05  best loss = 3.5367e-05  error = 5.6715e-01  l1 = -0.777565 l2 = -0.488135 l3 = 0.417441 adaptive_param = 11.863988
# tf_epoch =  20287  elapsed = 01:05:07  loss = 3.5926e-05  best loss = 3.5367e-05  error = 5.6715e-01  l1 = -0.777548 l2 = -0.488155 l3 = 0.417454 adaptive_param = 11.836242
# tf_epoch =  20288  elapsed = 01:05:07  loss = 3.5944e-05  best loss = 3.5367e-05  error = 5.6715e-01  l1 = -0.777554 l2 = -0.488152 l3 = 0.417443 adaptive_param = 11.827877
# tf_epoch =  20289  elapsed = 01:05:07  loss = 3.6005e-05  best loss = 3.5367e-05  error = 5.6715e-01  l1 = -0.777530 l2 = -0.488178 l3 = 0.417462 adaptive_param = 11.812807
# tf_epoch =  20290  elapsed = 01:05:08  loss = 3.5764e-05  best loss = 3.5367e-05  error = 5.6714e-01  l1 = -0.777537 l2 = -0.488174 l3 = 0.417450 adaptive_param = 11.809793
# tf_epoch =  20291  elapsed = 01:05:08  loss = 3.5617e-05  best loss = 3.5367e-05  error = 5.6714e-01  l1 = -0.777515 l2 = -0.488198 l3 = 0.417467 adaptive_param = 11.799287
# tf_epoch =  20292  elapsed = 01:05:08  loss = 3.5360e-05  best loss = 3.5360e-05  error = 5.6714e-01  l1 = -0.777516 l2 = -0.488199 l3 = 0.417460 adaptive_param = 11.808105
# tf_epoch =  20293  elapsed = 01:05:08  loss = 3.5266e-05  best loss = 3.5266e-05  error = 5.6714e-01  l1 = -0.777503 l2 = -0.488215 l3 = 0.417469 adaptive_param = 11.791629
# tf_epoch =  20294  elapsed = 01:05:08  loss = 3.5255e-05  best loss = 3.5255e-05  error = 5.6714e-01  l1 = -0.777495 l2 = -0.488225 l3 = 0.417471 adaptive_param = 11.847149
# tf_epoch =  20295  elapsed = 01:05:08  loss = 3.5298e-05  best loss = 3.5255e-05  error = 5.6714e-01  l1 = -0.777490 l2 = -0.488232 l3 = 0.417471 adaptive_param = 11.861479
# tf_epoch =  20296  elapsed = 01:05:09  loss = 3.5432e-05  best loss = 3.5255e-05  error = 5.6714e-01  l1 = -0.777474 l2 = -0.488251 l3 = 0.417482 adaptive_param = 11.838517
# tf_epoch =  20297  elapsed = 01:05:09  loss = 3.5452e-05  best loss = 3.5255e-05  error = 5.6714e-01  l1 = -0.777475 l2 = -0.488253 l3 = 0.417476 adaptive_param = 11.841613
# tf_epoch =  20298  elapsed = 01:05:09  loss = 3.5542e-05  best loss = 3.5255e-05  error = 5.6713e-01  l1 = -0.777455 l2 = -0.488275 l3 = 0.417491 adaptive_param = 11.826620
# tf_epoch =  20299  elapsed = 01:05:09  loss = 3.5446e-05  best loss = 3.5255e-05  error = 5.6713e-01  l1 = -0.777457 l2 = -0.488276 l3 = 0.417484 adaptive_param = 11.829693
# tf_epoch =  20300  elapsed = 01:05:09  loss = 3.5431e-05  best loss = 3.5255e-05  error = 5.6713e-01  l1 = -0.777438 l2 = -0.488297 l3 = 0.417498 adaptive_param = 11.813913
# tf_epoch =  20301  elapsed = 01:05:10  loss = 3.5291e-05  best loss = 3.5255e-05  error = 5.6713e-01  l1 = -0.777437 l2 = -0.488301 l3 = 0.417494 adaptive_param = 11.812601
# tf_epoch =  20302  elapsed = 01:05:10  loss = 3.5251e-05  best loss = 3.5251e-05  error = 5.6713e-01  l1 = -0.777423 l2 = -0.488317 l3 = 0.417503 adaptive_param = 11.786742
# tf_epoch =  20303  elapsed = 01:05:10  loss = 3.5169e-05  best loss = 3.5169e-05  error = 5.6713e-01  l1 = -0.777416 l2 = -0.488326 l3 = 0.417504 adaptive_param = 11.780635
# tf_epoch =  20304  elapsed = 01:05:10  loss = 3.5154e-05  best loss = 3.5154e-05  error = 5.6713e-01  l1 = -0.777407 l2 = -0.488337 l3 = 0.417508 adaptive_param = 11.731527
# tf_epoch =  20305  elapsed = 01:05:10  loss = 3.5159e-05  best loss = 3.5154e-05  error = 5.6713e-01  l1 = -0.777396 l2 = -0.488351 l3 = 0.417514 adaptive_param = 11.841039
# tf_epoch =  20306  elapsed = 01:05:11  loss = 3.5162e-05  best loss = 3.5154e-05  error = 5.6713e-01  l1 = -0.777390 l2 = -0.488359 l3 = 0.417514 adaptive_param = 11.891533
# tf_epoch =  20307  elapsed = 01:05:11  loss = 3.5216e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777377 l2 = -0.488374 l3 = 0.417523 adaptive_param = 11.876200
# tf_epoch =  20308  elapsed = 01:05:11  loss = 3.5199e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777373 l2 = -0.488381 l3 = 0.417521 adaptive_param = 11.875759
# tf_epoch =  20309  elapsed = 01:05:11  loss = 3.5255e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777359 l2 = -0.488398 l3 = 0.417531 adaptive_param = 11.845708
# tf_epoch =  20310  elapsed = 01:05:11  loss = 3.5206e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777355 l2 = -0.488403 l3 = 0.417529 adaptive_param = 11.841187
# tf_epoch =  20311  elapsed = 01:05:12  loss = 3.5234e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777340 l2 = -0.488421 l3 = 0.417539 adaptive_param = 11.812353
# tf_epoch =  20312  elapsed = 01:05:12  loss = 3.5164e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777336 l2 = -0.488427 l3 = 0.417538 adaptive_param = 11.807784
# tf_epoch =  20313  elapsed = 01:05:12  loss = 3.5161e-05  best loss = 3.5154e-05  error = 5.6712e-01  l1 = -0.777322 l2 = -0.488443 l3 = 0.417546 adaptive_param = 11.779387
# tf_epoch =  20314  elapsed = 01:05:12  loss = 3.5100e-05  best loss = 3.5100e-05  error = 5.6712e-01  l1 = -0.777317 l2 = -0.488451 l3 = 0.417546 adaptive_param = 11.775827
# tf_epoch =  20315  elapsed = 01:05:12  loss = 3.5087e-05  best loss = 3.5087e-05  error = 5.6712e-01  l1 = -0.777305 l2 = -0.488465 l3 = 0.417553 adaptive_param = 11.738856
# tf_epoch =  20316  elapsed = 01:05:13  loss = 3.5056e-05  best loss = 3.5056e-05  error = 5.6711e-01  l1 = -0.777297 l2 = -0.488475 l3 = 0.417555 adaptive_param = 11.749259
# tf_epoch =  20317  elapsed = 01:05:13  loss = 3.5044e-05  best loss = 3.5044e-05  error = 5.6711e-01  l1 = -0.777287 l2 = -0.488487 l3 = 0.417560 adaptive_param = 11.747930
# tf_epoch =  20318  elapsed = 01:05:13  loss = 3.5046e-05  best loss = 3.5044e-05  error = 5.6711e-01  l1 = -0.777278 l2 = -0.488499 l3 = 0.417565 adaptive_param = 11.837127
# tf_epoch =  20319  elapsed = 01:05:13  loss = 3.5034e-05  best loss = 3.5034e-05  error = 5.6711e-01  l1 = -0.777270 l2 = -0.488509 l3 = 0.417567 adaptive_param = 11.894754
# tf_epoch =  20320  elapsed = 01:05:13  loss = 3.5055e-05  best loss = 3.5034e-05  error = 5.6711e-01  l1 = -0.777258 l2 = -0.488523 l3 = 0.417573 adaptive_param = 11.874828
# tf_epoch =  20321  elapsed = 01:05:14  loss = 3.5039e-05  best loss = 3.5034e-05  error = 5.6711e-01  l1 = -0.777252 l2 = -0.488532 l3 = 0.417574 adaptive_param = 11.877505
# tf_epoch =  20322  elapsed = 01:05:14  loss = 3.5067e-05  best loss = 3.5034e-05  error = 5.6711e-01  l1 = -0.777239 l2 = -0.488547 l3 = 0.417582 adaptive_param = 11.839059
# tf_epoch =  20323  elapsed = 01:05:14  loss = 3.5043e-05  best loss = 3.5034e-05  error = 5.6711e-01  l1 = -0.777234 l2 = -0.488554 l3 = 0.417581 adaptive_param = 11.842456
# tf_epoch =  20324  elapsed = 01:05:14  loss = 3.5066e-05  best loss = 3.5034e-05  error = 5.6710e-01  l1 = -0.777220 l2 = -0.488570 l3 = 0.417590 adaptive_param = 11.811652
# tf_epoch =  20325  elapsed = 01:05:14  loss = 3.5031e-05  best loss = 3.5031e-05  error = 5.6710e-01  l1 = -0.777216 l2 = -0.488577 l3 = 0.417589 adaptive_param = 11.814287
# tf_epoch =  20326  elapsed = 01:05:15  loss = 3.5044e-05  best loss = 3.5031e-05  error = 5.6710e-01  l1 = -0.777202 l2 = -0.488593 l3 = 0.417597 adaptive_param = 11.783160
# tf_epoch =  20327  elapsed = 01:05:15  loss = 3.5003e-05  best loss = 3.5003e-05  error = 5.6710e-01  l1 = -0.777197 l2 = -0.488600 l3 = 0.417597 adaptive_param = 11.783175
# tf_epoch =  20328  elapsed = 01:05:15  loss = 3.5008e-05  best loss = 3.5003e-05  error = 5.6710e-01  l1 = -0.777184 l2 = -0.488615 l3 = 0.417604 adaptive_param = 11.747900
# tf_epoch =  20329  elapsed = 01:05:15  loss = 3.4967e-05  best loss = 3.4967e-05  error = 5.6710e-01  l1 = -0.777178 l2 = -0.488623 l3 = 0.417605 adaptive_param = 11.748557
# tf_epoch =  20330  elapsed = 01:05:15  loss = 3.4966e-05  best loss = 3.4966e-05  error = 5.6710e-01  l1 = -0.777167 l2 = -0.488637 l3 = 0.417611 adaptive_param = 11.705943
# tf_epoch =  20331  elapsed = 01:05:16  loss = 3.4933e-05  best loss = 3.4933e-05  error = 5.6710e-01  l1 = -0.777160 l2 = -0.488646 l3 = 0.417613 adaptive_param = 11.711234
# tf_epoch =  20332  elapsed = 01:05:16  loss = 3.4927e-05  best loss = 3.4927e-05  error = 5.6710e-01  l1 = -0.777149 l2 = -0.488659 l3 = 0.417618 adaptive_param = 11.672446
# tf_epoch =  20333  elapsed = 01:05:16  loss = 3.4907e-05  best loss = 3.4907e-05  error = 5.6709e-01  l1 = -0.777141 l2 = -0.488670 l3 = 0.417621 adaptive_param = 11.719128
# tf_epoch =  20334  elapsed = 01:05:16  loss = 3.4900e-05  best loss = 3.4900e-05  error = 5.6709e-01  l1 = -0.777131 l2 = -0.488681 l3 = 0.417625 adaptive_param = 11.739580
# tf_epoch =  20335  elapsed = 01:05:16  loss = 3.4894e-05  best loss = 3.4894e-05  error = 5.6709e-01  l1 = -0.777122 l2 = -0.488693 l3 = 0.417628 adaptive_param = 11.821921
# tf_epoch =  20336  elapsed = 01:05:17  loss = 3.4885e-05  best loss = 3.4885e-05  error = 5.6709e-01  l1 = -0.777114 l2 = -0.488703 l3 = 0.417631 adaptive_param = 11.905641
# tf_epoch =  20337  elapsed = 01:05:17  loss = 3.4889e-05  best loss = 3.4885e-05  error = 5.6709e-01  l1 = -0.777104 l2 = -0.488715 l3 = 0.417636 adaptive_param = 11.922473
# tf_epoch =  20338  elapsed = 01:05:17  loss = 3.4878e-05  best loss = 3.4878e-05  error = 5.6709e-01  l1 = -0.777096 l2 = -0.488726 l3 = 0.417638 adaptive_param = 11.966024
# tf_epoch =  20339  elapsed = 01:05:17  loss = 3.4891e-05  best loss = 3.4878e-05  error = 5.6709e-01  l1 = -0.777085 l2 = -0.488738 l3 = 0.417643 adaptive_param = 11.935658
# tf_epoch =  20340  elapsed = 01:05:17  loss = 3.4877e-05  best loss = 3.4877e-05  error = 5.6709e-01  l1 = -0.777078 l2 = -0.488748 l3 = 0.417645 adaptive_param = 11.948296
# tf_epoch =  20341  elapsed = 01:05:18  loss = 3.4898e-05  best loss = 3.4877e-05  error = 5.6709e-01  l1 = -0.777067 l2 = -0.488761 l3 = 0.417650 adaptive_param = 11.895141
# tf_epoch =  20342  elapsed = 01:05:18  loss = 3.4882e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777061 l2 = -0.488769 l3 = 0.417651 adaptive_param = 11.891632
# tf_epoch =  20343  elapsed = 01:05:18  loss = 3.4912e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777049 l2 = -0.488784 l3 = 0.417658 adaptive_param = 11.850589
# tf_epoch =  20344  elapsed = 01:05:18  loss = 3.4894e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777044 l2 = -0.488791 l3 = 0.417657 adaptive_param = 11.846813
# tf_epoch =  20345  elapsed = 01:05:18  loss = 3.4937e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777031 l2 = -0.488807 l3 = 0.417665 adaptive_param = 11.813279
# tf_epoch =  20346  elapsed = 01:05:18  loss = 3.4917e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777027 l2 = -0.488813 l3 = 0.417663 adaptive_param = 11.810575
# tf_epoch =  20347  elapsed = 01:05:19  loss = 3.4973e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777012 l2 = -0.488830 l3 = 0.417672 adaptive_param = 11.782805
# tf_epoch =  20348  elapsed = 01:05:19  loss = 3.4952e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.777010 l2 = -0.488835 l3 = 0.417669 adaptive_param = 11.780525
# tf_epoch =  20349  elapsed = 01:05:19  loss = 3.5023e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.776994 l2 = -0.488853 l3 = 0.417680 adaptive_param = 11.756884
# tf_epoch =  20350  elapsed = 01:05:19  loss = 3.5002e-05  best loss = 3.4877e-05  error = 5.6708e-01  l1 = -0.776993 l2 = -0.488856 l3 = 0.417675 adaptive_param = 11.754951
# tf_epoch =  20351  elapsed = 01:05:19  loss = 3.5092e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776975 l2 = -0.488876 l3 = 0.417687 adaptive_param = 11.734842
# tf_epoch =  20352  elapsed = 01:05:20  loss = 3.5073e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776976 l2 = -0.488878 l3 = 0.417681 adaptive_param = 11.733472
# tf_epoch =  20353  elapsed = 01:05:20  loss = 3.5183e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776956 l2 = -0.488899 l3 = 0.417695 adaptive_param = 11.716383
# tf_epoch =  20354  elapsed = 01:05:20  loss = 3.5169e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776959 l2 = -0.488899 l3 = 0.417687 adaptive_param = 11.715083
# tf_epoch =  20355  elapsed = 01:05:20  loss = 3.5307e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776938 l2 = -0.488922 l3 = 0.417702 adaptive_param = 11.700456
# tf_epoch =  20356  elapsed = 01:05:20  loss = 3.5303e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776942 l2 = -0.488920 l3 = 0.417692 adaptive_param = 11.699655
# tf_epoch =  20357  elapsed = 01:05:21  loss = 3.5479e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776919 l2 = -0.488946 l3 = 0.417710 adaptive_param = 11.687064
# tf_epoch =  20358  elapsed = 01:05:21  loss = 3.5491e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776926 l2 = -0.488941 l3 = 0.417697 adaptive_param = 11.686593
# tf_epoch =  20359  elapsed = 01:05:21  loss = 3.5721e-05  best loss = 3.4877e-05  error = 5.6707e-01  l1 = -0.776900 l2 = -0.488969 l3 = 0.417717 adaptive_param = 11.675691
# tf_epoch =  20360  elapsed = 01:05:21  loss = 3.5767e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776910 l2 = -0.488962 l3 = 0.417702 adaptive_param = 11.675310
# tf_epoch =  20361  elapsed = 01:05:21  loss = 3.6075e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776882 l2 = -0.488992 l3 = 0.417725 adaptive_param = 11.666067
# tf_epoch =  20362  elapsed = 01:05:21  loss = 3.6177e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776895 l2 = -0.488981 l3 = 0.417706 adaptive_param = 11.665857
# tf_epoch =  20363  elapsed = 01:05:22  loss = 3.6605e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776863 l2 = -0.489016 l3 = 0.417733 adaptive_param = 11.657956
# tf_epoch =  20364  elapsed = 01:05:22  loss = 3.6806e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776880 l2 = -0.489001 l3 = 0.417709 adaptive_param = 11.657733
# tf_epoch =  20365  elapsed = 01:05:22  loss = 3.7424e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776844 l2 = -0.489039 l3 = 0.417741 adaptive_param = 11.650999
# tf_epoch =  20366  elapsed = 01:05:22  loss = 3.7793e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776867 l2 = -0.489019 l3 = 0.417711 adaptive_param = 11.650774
# tf_epoch =  20367  elapsed = 01:05:22  loss = 3.8712e-05  best loss = 3.4877e-05  error = 5.6706e-01  l1 = -0.776824 l2 = -0.489063 l3 = 0.417749 adaptive_param = 11.645115
# tf_epoch =  20368  elapsed = 01:05:23  loss = 3.9364e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776855 l2 = -0.489036 l3 = 0.417712 adaptive_param = 11.644780
# tf_epoch =  20369  elapsed = 01:05:23  loss = 4.0776e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776805 l2 = -0.489088 l3 = 0.417757 adaptive_param = 11.639910
# tf_epoch =  20370  elapsed = 01:05:23  loss = 4.1906e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776844 l2 = -0.489051 l3 = 0.417710 adaptive_param = 11.639459
# tf_epoch =  20371  elapsed = 01:05:23  loss = 4.4108e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776785 l2 = -0.489112 l3 = 0.417766 adaptive_param = 11.635293
# tf_epoch =  20372  elapsed = 01:05:23  loss = 4.6007e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776837 l2 = -0.489063 l3 = 0.417706 adaptive_param = 11.634709
# tf_epoch =  20373  elapsed = 01:05:24  loss = 4.9450e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776765 l2 = -0.489137 l3 = 0.417775 adaptive_param = 11.631025
# tf_epoch =  20374  elapsed = 01:05:24  loss = 5.2506e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776833 l2 = -0.489072 l3 = 0.417699 adaptive_param = 11.630225
# tf_epoch =  20375  elapsed = 01:05:24  loss = 5.7763e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776746 l2 = -0.489161 l3 = 0.417783 adaptive_param = 11.626807
# tf_epoch =  20376  elapsed = 01:05:24  loss = 6.2300e-05  best loss = 3.4877e-05  error = 5.6705e-01  l1 = -0.776833 l2 = -0.489075 l3 = 0.417686 adaptive_param = 11.625730
# tf_epoch =  20377  elapsed = 01:05:24  loss = 6.9755e-05  best loss = 3.4877e-05  error = 5.6704e-01  l1 = -0.776729 l2 = -0.489182 l3 = 0.417788 adaptive_param = 11.622362
# tf_epoch =  20378  elapsed = 01:05:25  loss = 7.5472e-05  best loss = 3.4877e-05  error = 5.6704e-01  l1 = -0.776840 l2 = -0.489074 l3 = 0.417668 adaptive_param = 11.620851
# tf_epoch =  20379  elapsed = 01:05:25  loss = 8.4482e-05  best loss = 3.4877e-05  error = 5.6704e-01  l1 = -0.776719 l2 = -0.489197 l3 = 0.417786 adaptive_param = 11.617174
# tf_epoch =  20380  elapsed = 01:05:25  loss = 8.9380e-05  best loss = 3.4877e-05  error = 5.6704e-01  l1 = -0.776851 l2 = -0.489067 l3 = 0.417643 adaptive_param = 11.615029
# tf_epoch =  20381  elapsed = 01:05:25  loss = 9.6845e-05  best loss = 3.4877e-05  error = 5.6704e-01  l1 = -0.776720 l2 = -0.489200 l3 = 0.417773 adaptive_param = 11.610668
# ...
# tf_epoch =  24923  elapsed = 01:20:10  loss = 1.8804e-05  best loss = 1.8803e-05  error = 5.4832e-01  l1 = -0.766754 l2 = -0.536596 l3 = 0.421613 adaptive_param = 14.455378
# tf_epoch =  24924  elapsed = 01:20:10  loss = 1.8804e-05  best loss = 1.8803e-05  error = 5.4832e-01  l1 = -0.766752 l2 = -0.536611 l3 = 0.421616 adaptive_param = 14.439610
# tf_epoch =  24925  elapsed = 01:20:10  loss = 1.8804e-05  best loss = 1.8803e-05  error = 5.4831e-01  l1 = -0.766747 l2 = -0.536629 l3 = 0.421623 adaptive_param = 14.383193
# tf_epoch =  24926  elapsed = 01:20:10  loss = 1.8804e-05  best loss = 1.8803e-05  error = 5.4831e-01  l1 = -0.766746 l2 = -0.536643 l3 = 0.421625 adaptive_param = 14.357333
# tf_epoch =  24927  elapsed = 01:20:10  loss = 1.8805e-05  best loss = 1.8803e-05  error = 5.4830e-01  l1 = -0.766740 l2 = -0.536661 l3 = 0.421633 adaptive_param = 14.290790
# tf_epoch =  24928  elapsed = 01:20:11  loss = 1.8805e-05  best loss = 1.8803e-05  error = 5.4829e-01  l1 = -0.766739 l2 = -0.536675 l3 = 0.421635 adaptive_param = 14.258515
# tf_epoch =  24929  elapsed = 01:20:11  loss = 1.8806e-05  best loss = 1.8803e-05  error = 5.4829e-01  l1 = -0.766733 l2 = -0.536693 l3 = 0.421642 adaptive_param = 14.193413
# tf_epoch =  24930  elapsed = 01:20:11  loss = 1.8807e-05  best loss = 1.8803e-05  error = 5.4828e-01  l1 = -0.766733 l2 = -0.536707 l3 = 0.421644 adaptive_param = 14.160688
# tf_epoch =  24931  elapsed = 01:20:11  loss = 1.8808e-05  best loss = 1.8803e-05  error = 5.4827e-01  l1 = -0.766726 l2 = -0.536726 l3 = 0.421652 adaptive_param = 14.098864
# tf_epoch =  24932  elapsed = 01:20:11  loss = 1.8808e-05  best loss = 1.8803e-05  error = 5.4827e-01  l1 = -0.766726 l2 = -0.536739 l3 = 0.421654 adaptive_param = 14.073814
# tf_epoch =  24933  elapsed = 01:20:11  loss = 1.8811e-05  best loss = 1.8803e-05  error = 5.4826e-01  l1 = -0.766719 l2 = -0.536758 l3 = 0.421662 adaptive_param = 14.019437
# tf_epoch =  24934  elapsed = 01:20:12  loss = 1.8814e-05  best loss = 1.8803e-05  error = 5.4825e-01  l1 = -0.766719 l2 = -0.536771 l3 = 0.421663 adaptive_param = 14.014984
# tf_epoch =  24935  elapsed = 01:20:12  loss = 1.8823e-05  best loss = 1.8803e-05  error = 5.4825e-01  l1 = -0.766713 l2 = -0.536790 l3 = 0.421671 adaptive_param = 13.980824
# tf_epoch =  24936  elapsed = 01:20:12  loss = 1.8834e-05  best loss = 1.8803e-05  error = 5.4824e-01  l1 = -0.766713 l2 = -0.536803 l3 = 0.421673 adaptive_param = 14.018371
# tf_epoch =  24937  elapsed = 01:20:12  loss = 1.8858e-05  best loss = 1.8803e-05  error = 5.4824e-01  l1 = -0.766706 l2 = -0.536822 l3 = 0.421681 adaptive_param = 14.029372
# tf_epoch =  24938  elapsed = 01:20:12  loss = 1.8890e-05  best loss = 1.8803e-05  error = 5.4823e-01  l1 = -0.766707 l2 = -0.536834 l3 = 0.421682 adaptive_param = 14.109621
# tf_epoch =  24939  elapsed = 01:20:13  loss = 1.8948e-05  best loss = 1.8803e-05  error = 5.4822e-01  l1 = -0.766699 l2 = -0.536855 l3 = 0.421691 adaptive_param = 14.169216
# tf_epoch =  24940  elapsed = 01:20:13  loss = 1.9031e-05  best loss = 1.8803e-05  error = 5.4822e-01  l1 = -0.766701 l2 = -0.536866 l3 = 0.421690 adaptive_param = 14.217874
# tf_epoch =  24941  elapsed = 01:20:13  loss = 1.9174e-05  best loss = 1.8803e-05  error = 5.4821e-01  l1 = -0.766692 l2 = -0.536887 l3 = 0.421701 adaptive_param = 14.267247
# tf_epoch =  24942  elapsed = 01:20:13  loss = 1.9388e-05  best loss = 1.8803e-05  error = 5.4820e-01  l1 = -0.766696 l2 = -0.536896 l3 = 0.421698 adaptive_param = 14.295266
# tf_epoch =  24943  elapsed = 01:20:13  loss = 1.9753e-05  best loss = 1.8803e-05  error = 5.4820e-01  l1 = -0.766684 l2 = -0.536921 l3 = 0.421712 adaptive_param = 14.330502
# tf_epoch =  24944  elapsed = 01:20:14  loss = 2.0319e-05  best loss = 1.8803e-05  error = 5.4819e-01  l1 = -0.766692 l2 = -0.536926 l3 = 0.421705 adaptive_param = 14.350986
# tf_epoch =  24945  elapsed = 01:20:14  loss = 2.1286e-05  best loss = 1.8803e-05  error = 5.4819e-01  l1 = -0.766675 l2 = -0.536955 l3 = 0.421724 adaptive_param = 14.374610
# tf_epoch =  24946  elapsed = 01:20:14  loss = 2.2821e-05  best loss = 1.8803e-05  error = 5.4818e-01  l1 = -0.766690 l2 = -0.536954 l3 = 0.421710 adaptive_param = 14.388786
# tf_epoch =  24947  elapsed = 01:20:14  loss = 2.5439e-05  best loss = 1.8803e-05  error = 5.4817e-01  l1 = -0.766664 l2 = -0.536991 l3 = 0.421738 adaptive_param = 14.402516
# tf_epoch =  24948  elapsed = 01:20:14  loss = 2.9589e-05  best loss = 1.8803e-05  error = 5.4816e-01  l1 = -0.766691 l2 = -0.536980 l3 = 0.421712 adaptive_param = 14.410584
# tf_epoch =  24949  elapsed = 01:20:15  loss = 3.6501e-05  best loss = 1.8803e-05  error = 5.4816e-01  l1 = -0.766651 l2 = -0.537029 l3 = 0.421754 adaptive_param = 14.415930
# tf_epoch =  24950  elapsed = 01:20:15  loss = 4.6814e-05  best loss = 1.8803e-05  error = 5.4815e-01  l1 = -0.766696 l2 = -0.537001 l3 = 0.421710 adaptive_param = 14.417775
# tf_epoch =  24951  elapsed = 01:20:15  loss = 6.2478e-05  best loss = 1.8803e-05  error = 5.4815e-01  l1 = -0.766636 l2 = -0.537069 l3 = 0.421772 adaptive_param = 14.414928
# tf_epoch =  24952  elapsed = 01:20:15  loss = 8.1194e-05  best loss = 1.8803e-05  error = 5.4814e-01  l1 = -0.766708 l2 = -0.537017 l3 = 0.421701 adaptive_param = 14.409861
# tf_epoch =  24953  elapsed = 01:20:15  loss = 1.0155e-04  best loss = 1.8803e-05  error = 5.4814e-01  l1 = -0.766625 l2 = -0.537105 l3 = 0.421786 adaptive_param = 14.397447
# tf_epoch =  24954  elapsed = 01:20:15  loss = 1.0926e-04  best loss = 1.8803e-05  error = 5.4812e-01  l1 = -0.766722 l2 = -0.537031 l3 = 0.421689 adaptive_param = 14.382159
# tf_epoch =  24955  elapsed = 01:20:16  loss = 1.0081e-04  best loss = 1.8803e-05  error = 5.4812e-01  l1 = -0.766640 l2 = -0.537118 l3 = 0.421774 adaptive_param = 14.354490
# tf_epoch =  24956  elapsed = 01:20:16  loss = 7.2567e-05  best loss = 1.8803e-05  error = 5.4811e-01  l1 = -0.766722 l2 = -0.537057 l3 = 0.421692 adaptive_param = 14.317994
# tf_epoch =  24957  elapsed = 01:20:16  loss = 5.1354e-05  best loss = 1.8803e-05  error = 5.4810e-01  l1 = -0.766698 l2 = -0.537093 l3 = 0.421718 adaptive_param = 14.258569
# tf_epoch =  24958  elapsed = 01:20:16  loss = 5.3844e-05  best loss = 1.8803e-05  error = 5.4810e-01  l1 = -0.766683 l2 = -0.537119 l3 = 0.421733 adaptive_param = 14.182608
# tf_epoch =  24959  elapsed = 01:20:17  loss = 8.0303e-05  best loss = 1.8803e-05  error = 5.4809e-01  l1 = -0.766762 l2 = -0.537062 l3 = 0.421656 adaptive_param = 14.102777
# tf_epoch =  24960  elapsed = 01:20:17  loss = 1.0649e-04  best loss = 1.8803e-05  error = 5.4809e-01  l1 = -0.766624 l2 = -0.537200 l3 = 0.421795 adaptive_param = 14.031247
# tf_epoch =  24961  elapsed = 01:20:17  loss = 1.0553e-04  best loss = 1.8803e-05  error = 5.4807e-01  l1 = -0.766802 l2 = -0.537053 l3 = 0.421618 adaptive_param = 13.963422
# tf_epoch =  24962  elapsed = 01:20:17  loss = 8.1719e-05  best loss = 1.8803e-05  error = 5.4807e-01  l1 = -0.766632 l2 = -0.537219 l3 = 0.421788 adaptive_param = 13.896791
# tf_epoch =  24963  elapsed = 01:20:17  loss = 4.9005e-05  best loss = 1.8803e-05  error = 5.4806e-01  l1 = -0.766813 l2 = -0.537068 l3 = 0.421607 adaptive_param = 13.831127
# tf_epoch =  24964  elapsed = 01:20:18  loss = 3.1137e-05  best loss = 1.8803e-05  error = 5.4806e-01  l1 = -0.766734 l2 = -0.537151 l3 = 0.421685 adaptive_param = 13.766780
# tf_epoch =  24965  elapsed = 01:20:18  loss = 3.0278e-05  best loss = 1.8803e-05  error = 5.4805e-01  l1 = -0.766771 l2 = -0.537130 l3 = 0.421648 adaptive_param = 13.694703
# tf_epoch =  24966  elapsed = 01:20:18  loss = 3.6484e-05  best loss = 1.8803e-05  error = 5.4804e-01  l1 = -0.766846 l2 = -0.537074 l3 = 0.421572 adaptive_param = 13.652711
# tf_epoch =  24967  elapsed = 01:20:18  loss = 3.9509e-05  best loss = 1.8803e-05  error = 5.4804e-01  l1 = -0.766750 l2 = -0.537173 l3 = 0.421667 adaptive_param = 13.718869
# tf_epoch =  24968  elapsed = 01:20:18  loss = 3.7840e-05  best loss = 1.8803e-05  error = 5.4803e-01  l1 = -0.766891 l2 = -0.537057 l3 = 0.421524 adaptive_param = 13.687784
# tf_epoch =  24969  elapsed = 01:20:18  loss = 3.6103e-05  best loss = 1.8803e-05  error = 5.4802e-01  l1 = -0.766811 l2 = -0.537141 l3 = 0.421603 adaptive_param = 13.625154
# tf_epoch =  24970  elapsed = 01:20:19  loss = 3.4802e-05  best loss = 1.8803e-05  error = 5.4802e-01  l1 = -0.766869 l2 = -0.537101 l3 = 0.421544 adaptive_param = 13.555479
# tf_epoch =  24971  elapsed = 01:20:19  loss = 3.1207e-05  best loss = 1.8803e-05  error = 5.4801e-01  l1 = -0.766894 l2 = -0.537090 l3 = 0.421517 adaptive_param = 13.480348
# tf_epoch =  24972  elapsed = 01:20:19  loss = 2.5881e-05  best loss = 1.8803e-05  error = 5.4800e-01  l1 = -0.766858 l2 = -0.537133 l3 = 0.421552 adaptive_param = 13.452092
# tf_epoch =  24973  elapsed = 01:20:19  loss = 2.2278e-05  best loss = 1.8803e-05  error = 5.4799e-01  l1 = -0.766936 l2 = -0.537075 l3 = 0.421473 adaptive_param = 13.559002
# tf_epoch =  24974  elapsed = 01:20:19  loss = 2.3934e-05  best loss = 1.8803e-05  error = 5.4799e-01  l1 = -0.766898 l2 = -0.537121 l3 = 0.421511 adaptive_param = 13.578763
# tf_epoch =  24975  elapsed = 01:20:20  loss = 2.8858e-05  best loss = 1.8803e-05  error = 5.4798e-01  l1 = -0.766932 l2 = -0.537102 l3 = 0.421476 adaptive_param = 13.509909
# tf_epoch =  24976  elapsed = 01:20:20  loss = 3.0605e-05  best loss = 1.8803e-05  error = 5.4798e-01  l1 = -0.766946 l2 = -0.537100 l3 = 0.421461 adaptive_param = 13.441404
# tf_epoch =  24977  elapsed = 01:20:20  loss = 2.7601e-05  best loss = 1.8803e-05  error = 5.4797e-01  l1 = -0.766937 l2 = -0.537121 l3 = 0.421470 adaptive_param = 13.388175
# tf_epoch =  24978  elapsed = 01:20:20  loss = 2.1558e-05  best loss = 1.8803e-05  error = 5.4796e-01  l1 = -0.766972 l2 = -0.537100 l3 = 0.421433 adaptive_param = 13.366315
# tf_epoch =  24979  elapsed = 01:20:20  loss = 1.9085e-05  best loss = 1.8803e-05  error = 5.4796e-01  l1 = -0.766972 l2 = -0.537112 l3 = 0.421433 adaptive_param = 13.369267
# tf_epoch =  24980  elapsed = 01:20:21  loss = 2.1657e-05  best loss = 1.8803e-05  error = 5.4795e-01  l1 = -0.766981 l2 = -0.537116 l3 = 0.421424 adaptive_param = 13.312324
# tf_epoch =  24981  elapsed = 01:20:21  loss = 2.5393e-05  best loss = 1.8803e-05  error = 5.4794e-01  l1 = -0.767010 l2 = -0.537102 l3 = 0.421394 adaptive_param = 13.272676
# tf_epoch =  24982  elapsed = 01:20:21  loss = 2.5131e-05  best loss = 1.8803e-05  error = 5.4794e-01  l1 = -0.767003 l2 = -0.537120 l3 = 0.421402 adaptive_param = 13.245650
# tf_epoch =  24983  elapsed = 01:20:21  loss = 2.1642e-05  best loss = 1.8803e-05  error = 5.4793e-01  l1 = -0.767023 l2 = -0.537114 l3 = 0.421381 adaptive_param = 13.207668
# tf_epoch =  24984  elapsed = 01:20:21  loss = 1.9357e-05  best loss = 1.8803e-05  error = 5.4792e-01  l1 = -0.767042 l2 = -0.537109 l3 = 0.421362 adaptive_param = 13.156098
# tf_epoch =  24985  elapsed = 01:20:22  loss = 2.0004e-05  best loss = 1.8803e-05  error = 5.4792e-01  l1 = -0.767025 l2 = -0.537137 l3 = 0.421380 adaptive_param = 13.105613
# tf_epoch =  24986  elapsed = 01:20:22  loss = 2.1692e-05  best loss = 1.8803e-05  error = 5.4791e-01  l1 = -0.767062 l2 = -0.537116 l3 = 0.421343 adaptive_param = 13.220106
# tf_epoch =  24987  elapsed = 01:20:22  loss = 2.1979e-05  best loss = 1.8803e-05  error = 5.4791e-01  l1 = -0.767045 l2 = -0.537143 l3 = 0.421360 adaptive_param = 13.231808
# tf_epoch =  24988  elapsed = 01:20:22  loss = 2.1040e-05  best loss = 1.8803e-05  error = 5.4790e-01  l1 = -0.767045 l2 = -0.537156 l3 = 0.421360 adaptive_param = 13.189149
# tf_epoch =  24989  elapsed = 01:20:22  loss = 2.0126e-05  best loss = 1.8803e-05  error = 5.4789e-01  l1 = -0.767071 l2 = -0.537145 l3 = 0.421335 adaptive_param = 13.124763
# tf_epoch =  24990  elapsed = 01:20:23  loss = 1.9875e-05  best loss = 1.8803e-05  error = 5.4789e-01  l1 = -0.767036 l2 = -0.537189 l3 = 0.421371 adaptive_param = 13.075950
# tf_epoch =  24991  elapsed = 01:20:23  loss = 1.9758e-05  best loss = 1.8803e-05  error = 5.4788e-01  l1 = -0.767072 l2 = -0.537169 l3 = 0.421335 adaptive_param = 13.154074
# tf_epoch =  24992  elapsed = 01:20:23  loss = 1.9758e-05  best loss = 1.8803e-05  error = 5.4787e-01  l1 = -0.767058 l2 = -0.537195 l3 = 0.421350 adaptive_param = 13.256448
# tf_epoch =  24993  elapsed = 01:20:23  loss = 1.9942e-05  best loss = 1.8803e-05  error = 5.4787e-01  l1 = -0.767052 l2 = -0.537213 l3 = 0.421356 adaptive_param = 13.209889
# tf_epoch =  24994  elapsed = 01:20:23  loss = 2.0141e-05  best loss = 1.8803e-05  error = 5.4786e-01  l1 = -0.767079 l2 = -0.537201 l3 = 0.421330 adaptive_param = 13.148502
# tf_epoch =  24995  elapsed = 01:20:24  loss = 1.9854e-05  best loss = 1.8803e-05  error = 5.4786e-01  l1 = -0.767043 l2 = -0.537246 l3 = 0.421367 adaptive_param = 13.097818
# tf_epoch =  24996  elapsed = 01:20:24  loss = 1.9171e-05  best loss = 1.8803e-05  error = 5.4785e-01  l1 = -0.767074 l2 = -0.537231 l3 = 0.421336 adaptive_param = 13.079169
# tf_epoch =  24997  elapsed = 01:20:24  loss = 1.8800e-05  best loss = 1.8800e-05  error = 5.4784e-01  l1 = -0.767059 l2 = -0.537257 l3 = 0.421352 adaptive_param = 13.173235
# tf_epoch =  24998  elapsed = 01:20:24  loss = 1.9025e-05  best loss = 1.8800e-05  error = 5.4784e-01  l1 = -0.767054 l2 = -0.537274 l3 = 0.421358 adaptive_param = 13.145458
# tf_epoch =  24999  elapsed = 01:20:24  loss = 1.9453e-05  best loss = 1.8800e-05  error = 5.4783e-01  l1 = -0.767074 l2 = -0.537269 l3 = 0.421339 adaptive_param = 13.085520
# Starting L-BFGS training
# Step  10 loss 0.00002
# Step  20 loss 0.00002
# Step  30 loss 0.00002
# Step  40 loss 0.00002
# Step  50 loss 0.00002
# Step  60 loss 0.00002
# Step  70 loss 0.00002
# Step  80 loss 0.00002
# Step  90 loss 0.00002
# Step 100 loss 0.00002
# Step 110 loss 0.00002
# Step 120 loss 0.00002
# Step 130 loss 0.00002
# Step 140 loss 0.00002
# Step 150 loss 0.00001
# Step 160 loss 0.00001
# Step 170 loss 0.00001
# Step 180 loss 0.00001
# Step 190 loss 0.00001
# Step 200 loss 0.00001
# Step 210 loss 0.00001
# Step 220 loss 0.00001
# Step 230 loss 0.00001
# Step 240 loss 0.00001
# Step 250 loss 0.00001
# Step 260 loss 0.00001
# Step 270 loss 0.00001
# Step 280 loss 0.00001
# Step 290 loss 0.00001
# Step 300 loss 0.00001
# Step 310 loss 0.00001
# Step 320 loss 0.00001
# Step 330 loss 0.00001
# Step 340 loss 0.00001
# Step 350 loss 0.00001
# Step 360 loss 0.00001
# Step 370 loss 0.00001
# Step 380 loss 0.00001
# Step 390 loss 0.00001
# Step 400 loss 0.00001
# Step 410 loss 0.00001
# Step 420 loss 0.00001
# Step 430 loss 0.00001
# Step 440 loss 0.00001
# Step 450 loss 0.00001
# Step 460 loss 0.00001
# Step 470 loss 0.00001
# Step 480 loss 0.00001
# Step 490 loss 0.00001
# Step 500 loss 0.00001
# Step 510 loss 0.00001
# Step 520 loss 0.00001
# Step 530 loss 0.00001
# Step 540 loss 0.00001
# Step 550 loss 0.00001
# Step 560 loss 0.00001
# Step 570 loss 0.00001
# Step 580 loss 0.00001
# Step 590 loss 0.00001
# Step 600 loss 0.00001
# Step 610 loss 0.00001
# Step 620 loss 0.00001
# Step 630 loss 0.00001
# Step 640 loss 0.00001
# Step 650 loss 0.00001
# Step 660 loss 0.00001
# Step 670 loss 0.00001
# Step 680 loss 0.00001
# Step 690 loss 0.00001
# Step 700 loss 0.00001
# Step 710 loss 0.00001
# Step 720 loss 0.00001
# Step 730 loss 0.00001
# Step 740 loss 0.00001
# Step 750 loss 0.00001
# Step 760 loss 0.00001
# Step 770 loss 0.00001
# Step 780 loss 0.00001
# Step 790 loss 0.00001
# Step 800 loss 0.00001
# Step 810 loss 0.00001
# Step 820 loss 0.00001
# Step 830 loss 0.00001
# Step 840 loss 0.00001
# Step 850 loss 0.00001
# Step 860 loss 0.00001
# Step 870 loss 0.00001
# Step 880 loss 0.00001
# Step 890 loss 0.00001
# Step 900 loss 0.00001
# Step 910 loss 0.00001
# Step 920 loss 0.00001
# Step 930 loss 0.00001
# Step 940 loss 0.00001
# Step 950 loss 0.00001
# Step 960 loss 0.00001
# Step 970 loss 0.00001
# Step 980 loss 0.00001
# Step 990 loss 0.00001
# Step 1000 loss 0.00001
# L-BFGS training was beneficial
# ==================
# Training finished (epoch 25000): duration = 01:22:18  loss = 1.0124e-05  best loss = 1.0124e-05  error = 5.0489e-01  l1 = -0.789161 l2 = -0.601053 l3 = 0.422824 adaptive_param = 13.085520
# Applying the weights at the best epoch to the model...

# %%
LossParameterPlotter(loss_history, l1_history, l2_history, l3_history)

# %%
X_test, Y_test, u_star_plot, u_plot, u_train_pred, trained_weights, pred_params = ExtractData(pinn, X_star, X_u_train)

# %%
savemat('PINNresultsInverseWeightedNm=26.mat', {'u_pred': u_plot, 'u_true': u_star_plot, 'loss_history': loss_history, 'l1_history': l1_history, 'l2_history': l2_history, 'l3_history': l3_history, 
                           'X_u_train': X_u_train, 'u_train': u_train, 'u_train_pred': u_train_pred, 'X': X_test, 'Y': Y_test, 
                           'layers': layers, 'Nm': N_m, 'Nu': N_u, 'noise': noise, 'u_param': u_param, 'f_param': f_param, 'batch_size': batch_size, 'learning_rate': learning_rate})

# %%
DiscretePlotter(t,X_test,Y_test,u_plot,ub,zmax=0.3,zmin=0.0,cmap='rainbow')
# Out:
# No handles with labels found to put in legend.

# %%
DiscretePlotter(t,X_test,Y_test,u_star_plot,ub,zmax=0.3,zmin=0.0,cmap='rainbow')
# Out:
# No handles with labels found to put in legend.
